# %% [markdown]
# # Association Rules using Apriori and FP Growth

# %%
# (c) 2016 Everaldo Aguiar & Reid Johnson
#
# Modified from:
# Marcel Caraciolo (https://gist.github.com/marcelcaraciolo/1423287)
#
# Functions to compute and extract association rules from a given frequent itemset 
# generated by the Apriori algorithm.
#
# The Apriori algorithm is defined by Agrawal and Srikant in:
# Fast algorithms for mining association rules
# Proc. 20th int. conf. very large data bases, VLDB. Vol. 1215. 1994
import csv
import numpy as np

def load_dataset(filename):
    '''Loads an example of market basket transactions from a provided csv file.

    Returns: A list (database) of lists (transactions). Each element of a transaction is 
    an item.
    '''

    with open(filename,'r') as dest_f:
        data_iter = csv.reader(dest_f, delimiter = ',', quotechar = '"')
        data = [data for data in data_iter]
        data_array = np.asarray(data)
        
    return data_array

def apriori(dataset, min_support=0.5, verbose=False):
    """Implements the Apriori algorithm.

    The Apriori algorithm will iteratively generate new candidate 
    k-itemsets using the frequent (k-1)-itemsets found in the previous 
    iteration.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    Returns
    -------
    F : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.

    References
    ----------
    .. [1] R. Agrawal, R. Srikant, "Fast Algorithms for Mining Association 
           Rules", 1994.

    """
    C1 = create_candidates(dataset)
    D = list(map(set, dataset))
    F1, support_data = support_prune(D, C1, min_support, verbose=False) # prune candidate 1-itemsets
    F = [F1] # list of frequent itemsets; initialized to frequent 1-itemsets
    k = 2 # the itemset cardinality
    while (len(F[k - 2]) > 0):
        Ck = apriori_gen(F[k-2], k) # generate candidate itemsets
        Fk, supK = support_prune(D, Ck, min_support) # prune candidate itemsets
        support_data.update(supK) # update the support counts to reflect pruning
        F.append(Fk) # add the pruned candidate itemsets to the list of frequent itemsets
        k += 1

    if verbose:
        # Print a list of all the frequent itemsets.
        for kset in F:
            for item in kset:
                print("" \
                    + "{" \
                    + "".join(str(i) + ", " for i in iter(item)).rstrip(', ') \
                    + "}" \
                    + ":  sup = " + str(round(support_data[item], 3)))

    return F, support_data

def create_candidates(dataset, verbose=False):
    """Creates a list of candidate 1-itemsets from a list of transactions.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    Returns
    -------
    The list of candidate itemsets (c1) passed as a frozenset (a set that is 
    immutable and hashable).
    """
    c1 = [] # list of all items in the database of transactions
    for transaction in dataset:
        for item in transaction:
            if not [item] in c1:
                c1.append([item])
    c1.sort()

    if verbose:
        # Print a list of all the candidate items.
        print("" \
            + "{" \
            + "".join(str(i[0]) + ", " for i in iter(c1)).rstrip(', ') \
            + "}")

    # Map c1 to a frozenset because it will be the key of a dictionary.
    return list(map(frozenset, c1))

def support_prune(dataset, candidates, min_support, verbose=False):
    """Returns all candidate itemsets that meet a minimum support threshold.

    By the apriori principle, if an itemset is frequent, then all of its 
    subsets must also be frequent. As a result, we can perform support-based 
    pruning to systematically control the exponential growth of candidate 
    itemsets. Thus, itemsets that do not meet the minimum support level are 
    pruned from the input list of itemsets (dataset).

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    candidates : frozenset
        The list of candidate itemsets.

    min_support : float
        The minimum support threshold.

    Returns
    -------
    retlist : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.
    """
    sscnt = {} # set for support counts
    for tid in dataset:
        for can in candidates:
            if can.issubset(tid):
                sscnt.setdefault(can, 0)
                sscnt[can] += 1

    num_items = float(len(dataset)) # total number of transactions in the dataset
    retlist = [] # array for unpruned itemsets
    support_data = {} # set for support data for corresponding itemsets
    for key in sscnt:
        # Calculate the support of itemset key.
        support = sscnt[key] / num_items
        if support >= min_support:
            retlist.insert(0, key)
        support_data[key] = support

    # Print a list of the pruned itemsets.
    if verbose:
        for kset in retlist:
            for item in kset:
                print("{" + str(item) + "}")
        print("")
        for key in sscnt:
            print("" \
                + "{" \
                + "".join([str(i) + ", " for i in iter(key)]).rstrip(', ') \
                + "}" \
                + ":  sup = " + str(support_data[key]))

    return retlist, support_data

def apriori_gen(freq_sets, k):
    """Generates candidate itemsets (via the F_k-1 x F_k-1 method).

    This operation generates new candidate k-itemsets based on the frequent 
    (k-1)-itemsets found in the previous iteration. The candidate generation 
    procedure merges a pair of frequent (k-1)-itemsets only if their first k-2 
    items are identical.

    Parameters
    ----------
    freq_sets : list
        The list of frequent (k-1)-itemsets.

    k : integer
        The cardinality of the current itemsets being evaluated.

    Returns
    -------
    retlist : list
        The list of merged frequent itemsets.
    """
    retList = [] # list of merged frequent itemsets
    lenLk = len(freq_sets) # number of frequent itemsets
    for i in range(lenLk):
        for j in range(i+1, lenLk):
            a=list(freq_sets[i])
            b=list(freq_sets[j])
            a.sort()
            b.sort()
            F1 = a[:k-2] # first k-2 items of freq_sets[i]
            F2 = b[:k-2] # first k-2 items of freq_sets[j]

            if F1 == F2: # if the first k-2 items are identical
                # Merge the frequent itemsets.
                retList.append(freq_sets[i] | freq_sets[j])

    return retList

def rules_from_conseq(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Generates a set of candidate rules.

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    support_data : dict
        The support data for all candidate itemsets.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.
    """
    m = len(H[0])
    if m == 1:
        Hmp1 = calc_confidence(freq_set, H, support_data, rules, min_confidence, verbose)
    if (len(freq_set) > (m+1)):
        Hmp1 = apriori_gen(H, m+1) # generate candidate itemsets
        Hmp1 = calc_confidence(freq_set, Hmp1, support_data, rules, min_confidence, verbose)
        if len(Hmp1) > 1:
            # If there are candidate rules above the minimum confidence 
            # threshold, recurse on the list of these candidate rules.
            rules_from_conseq(freq_set, Hmp1, support_data, rules, min_confidence, verbose)

def calc_confidence(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Evaluates the generated rules.

    One measurement for quantifying the goodness of association rules is 
    confidence. The confidence for a rule 'P implies H' (P -> H) is defined as 
    the support for P and H divided by the support for P 
    (support (P|H) / support(P)), where the | symbol denotes the set union 
    (thus P|H means all the items in set P or in set H).

    To calculate the confidence, we iterate through the frequent itemsets and 
    associated support data. For each frequent itemset, we divide the support 
    of the itemset by the support of the antecedent (left-hand-side of the 
    rule).

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    min_support : float
        The minimum support threshold.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    pruned_H : list
        The list of candidate rules above the minimum confidence threshold.
    """
    pruned_H = [] # list of candidate rules above the minimum confidence threshold
    for conseq in H: # iterate over the frequent itemsets
        conf = support_data[freq_set] / support_data[freq_set - conseq]
        if conf >= min_confidence:
            rules.append((freq_set - conseq, conseq, conf))
            pruned_H.append(conseq)

            if verbose:
                print("" \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(freq_set-conseq)]).rstrip(', ') \
                    + "}" \
                    + " ---> " \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(conseq)]).rstrip(', ') \
                    + "}" \
                    + ":  conf = " + str(round(conf, 3)) \
                    + ", sup = " + str(round(support_data[freq_set], 3)))

    return pruned_H

def generate_rules(F, support_data, min_confidence=0.5, verbose=True):
    """Generates a set of candidate rules from a list of frequent itemsets.

    For each frequent itemset, we calculate the confidence of using a
    particular item as the rule consequent (right-hand-side of the rule). By 
    testing and merging the remaining rules, we recursively create a list of 
    pruned rules.

    Parameters
    ----------
    F : list
        A list of frequent itemsets.

    support_data : dict
        The corresponding support data for the frequent itemsets (L).

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    rules : list
        The list of candidate rules above the minimum confidence threshold.
    """
    rules = []
    for i in range(1, len(F)):
        for freq_set in F[i]:
            H1 = [frozenset([itemset]) for itemset in freq_set]
            if (i > 1):
                rules_from_conseq(freq_set, H1, support_data, rules, min_confidence, verbose)
            else:
                calc_confidence(freq_set, H1, support_data, rules, min_confidence, verbose)

    return rules

# %%
import pandas as pd

# Import the dataset
df = pd.read_csv('Chicago_Crime_Apriori.csv')

# %%
df.head(3)
# Out:
#                   Date       ID               Block   Primary Type  \
# 0  2006-04-02 13:00:00  4673626   055XX N MANGO AVE  OTHER OFFENSE
# 1  2006-02-26 13:40:48  4673627  065XX S RHODES AVE      NARCOTICS
# 2  2006-01-08 23:16:00  4673628     013XX E 69TH ST        ASSAULT
#
#                Description Location Description  Arrest  Domestic  District  \
# 0  HARASSMENT BY TELEPHONE            RESIDENCE   False     False      16.0
# 1       MANU/DELIVER:CRACK             SIDEWALK    True     False       3.0
# 2      AGGRAVATED: HANDGUN                OTHER   False     False       3.0
#
#    Year   Latitude  Longitude  Month  Day  Hour
# 0  2006  41.981913 -87.771996      4    2    13
# 1  2006  41.775733 -87.611920      2   26    13
# 2  2006  41.769897 -87.593671      1    8    23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4273756 entries, 0 to 4273755
# Data columns (total 15 columns):
# Date                    object
# ID                      int64
# Block                   object
# Primary Type            object
# Description             object
# Location Description    object
# Arrest                  bool
# Domestic                bool
# District                float64
# Year                    int64
# Latitude                float64
# Longitude               float64
# Month                   int64
# Day                     int64
# Hour                    int64
# dtypes: bool(2), float64(3), int64(5), object(5)
# memory usage: 432.0+ MB

# %%
# Change Month from month number to month name
import calendar
d = dict(enumerate(calendar.month_abbr))
df['Month'] = df['Month'].map(d)

# %%
# Create classification feature for time of day based on Hour
df['Time'] = ''
df.loc[(df['Hour'] > 20), 'Time'] = 'Night'
df.loc[(df['Hour'] <= 5), 'Time'] = 'Night'
df.loc[(df['Hour'] > 5) & (df['Hour'] <= 12), 'Time'] = 'Morning'
df.loc[(df['Hour'] > 12) & (df['Hour'] <= 16), 'Time'] = 'Noon'
df.loc[(df['Hour'] > 16) & (df['Hour'] <= 20), 'Time'] = 'Evening'

# %%
# Drop null values and unwanted features
df.dropna()
df = df.drop(['Date', 'ID', 'Latitude', 'Longitude','Hour'], axis=1)
df.head()
# Out:
#                  Block   Primary Type                   Description  \
# 0    055XX N MANGO AVE  OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 1   065XX S RHODES AVE      NARCOTICS            MANU/DELIVER:CRACK
# 2      013XX E 69TH ST        ASSAULT           AGGRAVATED: HANDGUN
# 3  061XX W NEWPORT AVE        BATTERY                        SIMPLE
# 4      037XX W 60TH ST      NARCOTICS  POSS: CANNABIS 30GMS OR LESS
#
#   Location Description  Arrest  Domestic  District  Year Month  Day     Time
# 0            RESIDENCE   False     False      16.0  2006   Apr    2     Noon
# 1             SIDEWALK    True     False       3.0  2006   Feb   26     Noon
# 2                OTHER   False     False       3.0  2006   Jan    8    Night
# 3            RESIDENCE   False     False      16.0  2006   Apr    5  Evening
# 4                ALLEY    True     False       8.0  2006   Feb   17    Night

# %%
df['Arrest'] = df['Arrest'].replace({True: 'Arrested', False: 'Not Arrested'})
df['Domestic'] = df['Domestic'].replace({True: 'Domestic', False: 'Not Domestic'})

df['District'] = 'District ' + df['District'].astype(str)
df['Day'] = 'Day of Month ' + df['Day'].astype(str)

# %%
df.head(3)
# Out:
#                 Block   Primary Type              Description  \
# 0   055XX N MANGO AVE  OTHER OFFENSE  HARASSMENT BY TELEPHONE
# 1  065XX S RHODES AVE      NARCOTICS       MANU/DELIVER:CRACK
# 2     013XX E 69TH ST        ASSAULT      AGGRAVATED: HANDGUN
#
#   Location Description        Arrest      Domestic       District  Year Month  \
# 0            RESIDENCE  Not Arrested  Not Domestic  District 16.0  2006   Apr
# 1             SIDEWALK      Arrested  Not Domestic   District 3.0  2006   Feb
# 2                OTHER  Not Arrested  Not Domestic   District 3.0  2006   Jan
#
#                Day   Time
# 0   Day of Month 2   Noon
# 1  Day of Month 26   Noon
# 2   Day of Month 8  Night

# %%
df = df.astype(str)

# %%
df = np.asarray(df[1:])
D = list(map(set, df))

# %%
D[0]
# Out:
# {'065XX S RHODES AVE',
#  '2006',
#  'Arrested',
#  'Day of Month 26',
#  'District 3.0',
#  'Feb',
#  'MANU/DELIVER:CRACK',
#  'NARCOTICS',
#  'Noon',
#  'Not Domestic',
#  'SIDEWALK'}

# %%
# Generate candidate itemsets
C1 = create_candidates(df[:10000], verbose=True)
# Out:
# {$500 AND UNDER, 0000X E 100TH PL, 0000X E 102ND PL, 0000X E 107TH ST, 0000X E 118TH PL, 0000X E 119TH PL, 0000X E 119TH ST, 0000X E 122ND ST, 0000X E 16TH ST, 0000X E 21ST ST, 0000X E 36TH ST, 0000X E 37TH PL, 0000X E 41ST ST, 0000X E 48TH ST, 0000X E 58TH ST, 0000X E 59TH ST, 0000X E 69TH ST, 0000X E 70TH ST, 0000X E 71ST ST, 0000X E 75TH ST, 0000X E 95TH ST, 0000X E 9TH ST, 0000X E ADAMS ST, 0000X E CHESTNUT ST, 0000X E CHICAGO AVE, 0000X E DELAWARE PL, 0000X E GARFIELD BLVD, 0000X E GOETHE ST, 0000X E GRAND AVE, 0000X E HARRISON ST, 0000X E HUBBARD ST, 0000X E JACKSON BLVD, 0000X E LAKE ST, 0000X E MADISON ST, 0000X E MONROE ST, 0000X E OAK ST, 0000X E OHIO ST, 0000X E RANDOLPH ST, 0000X E ROOSEVELT RD, 0000X E SUPERIOR ST, 0000X E WACKER DR, 0000X E WASHINGTON ST, 0000X N ADA ST, 0000X N ALBANY AVE, 0000X N CENTRAL AVE, 0000X N CICERO AVE, 0000X N DAMEN AVE, 0000X N DEARBORN ST, 0000X N DESPLAINES ST, 0000X N HALSTED ST, 0000X N KEDZIE AVE, 0000X N KEELER AVE, 0000X N KILBOURN AVE, 0000X N KOSTNER AVE, 0000X N LA SALLE ST, 0000X N LAMON AVE, 0000X N LATROBE AVE, 0000X N LECLAIRE AVE, 0000X N LOOMIS ST, 0000X N LOTUS AVE, 0000X N MAY ST, 0000X N MAYFIELD AVE, 0000X N MORGAN ST, 0000X N PAULINA ST, 0000X N PULASKI RD, 0000X N STATE ST, 0000X N WABASH AVE, 0000X N WACKER DR, 0000X N WELLS ST, 0000X N WESTERN AVE, 0000X S ALBANY AVE, 0000X S AUSTIN BLVD, 0000X S CAMPBELL AVE, 0000X S CLARK ST, 0000X S DEARBORN ST, 0000X S HOMAN AVE, 0000X S KEDZIE AVE, 0000X S KILBOURN AVE, 0000X S LEAMINGTON AVE, 0000X S LEAVITT ST, 0000X S MENARD AVE, 0000X S MICHIGAN AVE, 0000X S OAKLEY BLVD, 0000X S RIVERSIDE PLZ, 0000X S SANGAMON ST, 0000X S SPRINGFIELD AVE, 0000X S STATE ST, 0000X S THROOP PKWY, 0000X S THROOP ST, 0000X W 103RD ST, 0000X W 108TH ST, 0000X W 109TH ST, 0000X W 110TH PL, 0000X W 110TH ST, 0000X W 111TH PL, 0000X W 111TH ST, 0000X W 112TH ST, 0000X W 114TH PL, 0000X W 125TH ST, 0000X W 35TH ST, 0000X W 43RD ST, 0000X W 71ST ST, 0000X W 72ND ST, 0000X W 74TH ST, 0000X W 79TH ST, 0000X W 87TH ST, 0000X W 95TH ST, 0000X W BRAYTON ST, 0000X W CHESTNUT ST, 0000X W DIVISION ST, 0000X W GOETHE ST, 0000X W HUBBARD ST, 0000X W HURON ST, 0000X W ILLINOIS ST, 0000X W JACKSON BLVD, 0000X W KINZIE ST, 0000X W MONROE ST, 0000X W NORTH BLVD, 0000X W RANDOLPH ST, 0000X W ROOSEVELT RD, 0000X W ROOT ST, 0000X W SUPERIOR ST, 0000X W VAN BUREN ST, 0000X W WACKER DR, 0000X W WASHINGTON ST, 001XX E 104TH ST, 001XX E 113TH ST, 001XX E 118TH PL, 001XX E 119TH PL, 001XX E 119TH ST, 001XX E 123RD ST, 001XX E 124TH ST, 001XX E 23RD ST, 001XX E 44TH ST, 001XX E 47TH ST, 001XX E 51ST ST, 001XX E 57TH ST, 001XX E 68TH ST, 001XX E 69TH ST, 001XX E 70TH ST, 001XX E 71ST ST, 001XX E 79TH ST, 001XX E 80TH ST, 001XX E CERMAK RD, 001XX E CHESTNUT ST, 001XX E CHICAGO AVE, 001XX E GARFIELD BLVD, 001XX E GRAND AVE, 001XX E HURON ST, 001XX E KENSINGTON AVE, 001XX E LAKE ST, 001XX E SOUTH WATER ST, 001XX E WACKER DR, 001XX N ABERDEEN ST, 001XX N ADA ST, 001XX N AUSTIN BLVD, 001XX N BELL AVE, 001XX N CARPENTER ST, 001XX N CENTRAL PARK DR, 001XX N CICERO AVE, 001XX N CLARK ST, 001XX N FRANKLIN ST, 001XX N GREEN ST, 001XX N HAMLIN BLVD, 001XX N HERMITAGE AVE, 001XX N HOMAN BLVD, 001XX N KEDZIE AVE, 001XX N KOSTNER AVE, 001XX N LA SALLE ST, 001XX N LAMON AVE, 001XX N LAPORTE AVE, 001XX N LARAMIE AVE, 001XX N LATROBE AVE, 001XX N LEAMINGTON AVE, 001XX N LEAVITT ST, 001XX N LECLAIRE AVE, 001XX N LONG AVE, 001XX N LOTUS AVE, 001XX N MAYFIELD AVE, 001XX N MENARD AVE, 001XX N MICHIGAN AVE, 001XX N PARKSIDE AVE, 001XX N PEORIA ST, 001XX N PINE AVE, 001XX N SACRAMENTO BLVD, 001XX N STATE ST, 001XX N WABASH AVE, 001XX N WACKER DR, 001XX N WALLER AVE, 001XX N WELLS ST, 001XX S ABERDEEN ST, 001XX S CALIFORNIA AVE, 001XX S CENTRAL PARK BLVD, 001XX S CICERO AVE, 001XX S DEARBORN ST, 001XX S FRANCISCO AVE, 001XX S HALSTED ST, 001XX S HAMLIN BLVD, 001XX S KILDARE AVE, 001XX S LAVERGNE AVE, 001XX S MICHIGAN AVE, 001XX S PULASKI RD, 001XX S RACINE AVE, 001XX S RIVERSIDE PLZ, 001XX S  ...

# %%
# Frequent itemsets with support 5%
F_apr, support_data_apr = apriori(df[:10000], min_support=0.05, verbose=True)
# Out:
# {Day of Month 12}:  sup = 0.082
# {Day of Month 11}:  sup = 0.093
# {Day of Month 10}:  sup = 0.092
# {Day of Month 13}:  sup = 0.069
# {Day of Month 9}:  sup = 0.093
# {District 6.0}:  sup = 0.061
# {Day of Month 7}:  sup = 0.101
# {TO VEHICLE}:  sup = 0.068
# {TO PROPERTY}:  sup = 0.06
# {CRIMINAL DAMAGE}:  sup = 0.14
# {District 25.0}:  sup = 0.051
# {OTHER OFFENSE}:  sup = 0.068
# {District 11.0}:  sup = 0.067
# {District 4.0}:  sup = 0.052
# {OVER $500}:  sup = 0.052
# {Day of Month 6}:  sup = 0.092
# {Domestic}:  sup = 0.129
# {DOMESTIC BATTERY SIMPLE}:  sup = 0.095
# {THEFT}:  sup = 0.194
# {STREET}:  sup = 0.266
# {$500 AND UNDER}:  sup = 0.065
# {Morning}:  sup = 0.235
# {Mar}:  sup = 0.095
# {District 7.0}:  sup = 0.082
# {APARTMENT}:  sup = 0.101
# {District 8.0}:  sup = 0.077
# {SIMPLE}:  sup = 0.116
# {RESIDENCE}:  sup = 0.163
# {Evening}:  sup = 0.212
# {BATTERY}:  sup = 0.203
# {Apr}:  sup = 0.814
# {Not Arrested}:  sup = 0.726
# {Night}:  sup = 0.36
# {Day of Month 8}:  sup = 0.098
# {ASSAULT}:  sup = 0.061
# {SIDEWALK}:  sup = 0.1
# {Not Domestic}:  sup = 0.871
# {Noon}:  sup = 0.192
# {NARCOTICS}:  sup = 0.1
# {Feb}:  sup = 0.068
# {District 3.0}:  sup = 0.06
# {Arrested}:  sup = 0.274
# {2006}:  sup = 0.984
# {Day of Month 13, Apr}:  sup = 0.064
# {Day of Month 12, Apr}:  sup = 0.08
# {Day of Month 11, Apr}:  sup = 0.089
# {Day of Month 10, Apr}:  sup = 0.089
# {Day of Month 9, Apr}:  sup = 0.088
# {Day of Month 13, Not Domestic}:  sup = 0.059
# {Day of Month 8, Apr}:  sup = 0.088
# {Day of Month 9, Not Arrested}:  sup = 0.073
# {2006, Day of Month 12}:  sup = 0.081
# {Day of Month 12, Not Domestic}:  sup = 0.07
# {Day of Month 12, Not Arrested}:  sup = 0.065
# {2006, Day of Month 11}:  sup = 0.092
# {Day of Month 11, Not Domestic}:  sup = 0.079
# {Day of Month 11, Not Arrested}:  sup = 0.073
# {Day of Month 7, Apr}:  sup = 0.096
# {2006, Day of Month 10}:  sup = 0.092
# {Day of Month 10, Not Domestic}:  sup = 0.078
# {Not Arrested, Day of Month 10}:  sup = 0.075
# {Day of Month 13, 2006}:  sup = 0.069
# {Day of Month 13, Not Arrested}:  sup = 0.053
# {Day of Month 9, 2006}:  sup = 0.093
# {Day of Month 9, Not Domestic}:  sup = 0.079
# {2006, District 6.0}:  sup = 0.058
# {2006, Day of Month 7}:  sup = 0.101
# {Day of Month 7, Not Domestic}:  sup = 0.088
# {Day of Month 7, Not Arrested}:  sup = 0.08
# {APARTMENT, Not Arrested}:  sup = 0.08
# {APARTMENT, Apr}:  sup = 0.092
# {District 7.0, Apr}:  sup = 0.064
# {Not Arrested, OTHER OFFENSE}:  sup = 0.06
# {OTHER OFFENSE, Apr}:  sup = 0.059
# {2006, TO VEHICLE}:  sup = 0.068
# {TO VEHICLE, Not Domestic}:  sup = 0.064
# {Not Arrested, TO VEHICLE}:  sup = 0.065
# {TO VEHICLE, Apr}:  sup = 0.065
# {TO VEHICLE, CRIMINAL DAMAGE}:  sup = 0.067
# {2006, CRIMINAL DAMAGE}:  sup = 0.139
# {CRIMINAL DAMAGE, Not Domestic}:  sup = 0.13
# {Night, CRIMINAL DAMAGE}:  sup = 0.061
# {Not Arrested, CRIMINAL DAMAGE}:  sup = 0.13
# {CRIMINAL DAMAGE, Apr}:  sup = 0.133
# {2006, TO PROPERTY}:  sup = 0.059
# {TO PROPERTY, Not Domestic}:  sup = 0.054
# {Not Arrested, TO PROPERTY}:  sup = 0.055
# {TO PROPERTY, Apr}:  sup = 0.057
# {TO PROPERTY, CRIMINAL DAMAGE}:  sup = 0.06
# {2006, District 25.0}:  sup = 0.05
# {2006, OTHER OFFENSE}:  sup = 0.067
# {STREET, Evening}:  sup = 0.059
# {RESIDENCE, Night}:  sup = 0.057
# {Night, THEFT}:  sup = 0.052
# {Not Arrested, District 7.0}:  sup = 0.062
# {2006, District 11.0}:  sup = 0.064
# {District 11.0, Not Domestic}:  sup = 0.058
# {STREET, Arrested}:  sup = 0.072
# {STREET, Night}:  sup = 0.111
# {2006, District 4.0}:  sup = 0.051
# {Evening, Arrested}:  sup = 0.06
# {Morning, Not Arrested}:  sup = 0.174
# {STREET, Morning}:  sup = 0.054
# {THEFT, Morning}:  sup = 0.058
# {2006, Day of Month 6}:  sup = 0.091
# {Day of Month 6, Not Domestic}:  sup = 0.081
# {Not Arrested, Day of Month 6}:  sup = 0.07
# {Day of Month 6, Apr}:  sup = 0.089
# {2006, OVER $500}:  sup = 0.052
# {Not Domestic, OVER $500}:  sup = 0.051
# {THEFT, OVER $500}:  sup = 0.052
# {SIDEWALK, Apr}:  sup = 0.062
# {Night, BATTERY}:  sup = 0.082
# {2006, DOMESTIC BATTERY SIMPLE}:  sup = 0.094
# {Not Arrested, DOMESTIC BATTERY SIMPLE}:  sup = 0.071
# {DOMESTIC BATTERY SIMPLE, Apr}:  sup = 0.091
# {BATTERY, DOMESTIC BATTERY SIMPLE}:  sup = 0.095
# {Domestic, 2006}:  sup = 0.127
# {Domestic, Night}:  sup = 0.054
# {Domestic, Not Arrested}:  sup = 0.103
# {Domestic, Apr}:  sup = 0.121
# {Domestic, BATTERY}:  sup = 0.076
# {Domestic, DOMESTIC BATTERY SIMPLE}:  sup = 0.069
# {ASSAULT, Apr}:  sup = 0.058
# {Night, Apr}:  sup = 0.29
# {Not Arrested, Noon}:  sup = 0.142
# {Noon, Apr}:  sup = 0.157
# {District 8.0, Not Arrested}:  sup = 0.057
# {District 8.0, Apr}:  sup = 0.065
# {2006, $500 AND UNDER}:  sup = 0.064
# {$500 AND UNDER, Not Domestic}:  sup = 0.063
# {Not Arrested, $500 AND UNDER}:  sup = 0.061
# {$500 AND UNDER, Apr}:  sup = 0.061
# {STREET, 2006}:  sup = 0.262
# {STREET, Not Domestic}:  sup = 0.247
# {STREET, Not Arrested}:  sup = 0.194
# {STREET, Apr}:  sup = 0.212
# {2006, THEFT}:  sup = 0.19
# {THEFT, Not Domestic}:  sup = 0.189
# {THEFT, Not Arrested}:  sup = 0.171
# {THEFT, Apr}:  sup = 0.172
# {THEFT, $500 AND UNDER}:  sup = 0.065
# {Arrested, Apr}:  sup = 0.158
# {2006, Morning}:  sup = 0.231
# {Morning, Arrested}:  sup = 0.061
# {Morning, Not Domestic}:  sup = 0.208
# {Morning, Apr}:  sup = 0.189
# {APARTMENT, 2006}:  sup = 0.1
# {APARTMENT, Not Domestic}:  sup = 0.063
# {2006, District 7.0}:  sup = 0.081
# {District 7.0, Not Domestic}:  sup = 0.063
# {2006, Mar}:  sup = 0.095
# {Arrested, Mar}:  sup = 0.051
# {Mar, Not Domestic}:  sup = 0.09
# {Night, Arrested}:  sup = 0.102
# {District 8.0, 2006}:  sup = 0.076
# {District 8.0, Not Domestic}:  sup = 0.066
# {2006, Apr}:  sup = 0.813
# {Not Domestic, Apr}:  sup = 0.693
# {Not Arrested, Apr}:  sup = 0.656
# {2006, BATTERY}:  sup = 0.2
# {BATTERY, Not Domestic}:  sup = 0.126
# {Not Arrested, BATTERY}:  sup = 0.155
# {BATTERY, Apr}:  sup = 0.193
# {2006, Evening}:  sup = 0.21
# {Evening, Not Domestic}:  sup = 0.189
# {Not Arrested, Evening}:  sup = 0.152
# {Evening, Apr}:  sup = 0.178
# {RESIDENCE, 2006}:  sup = 0.159
# {RESIDENCE, Not Domestic}:  sup = 0.114
# {RESIDENCE, Not Arrested}:  sup = 0.141
# {RESIDENCE, Apr}:  sup = 0.14
# {2006, SIMPLE}:  sup = 0.114
# {SIMPLE, Not Domestic}:  sup = 0.106
# {Not Arrested, SIMPLE}:  sup = 0.095
# {SIMPLE, Apr}:  sup = 0.109
# {BATTERY, SIMPLE}:  sup = 0.074
# {2006, ASSAULT}:  sup = 0.061
# {ASSAULT, Not Domestic}:  sup = 0.05
# {2006, Day of Month 8}:  sup = 0.097
# {Day of Month 8, Not Domestic}:  sup = 0.084
# {Night, 2006}:  sup = 0.355
# {Night, Not Domestic}:  sup = 0.306
# {2006, Not Arrested}:  sup = 0.712
# {Not Arrested, Not Domestic}:  sup = 0.623
# {Not Arrested, Day of Month 8}:  sup = 0.072
# {Night, Not Arrested}:  sup = 0.258
# {2006, Arrested}:  sup = 0.272
# {2006, District 3.0}:  sup = 0.059
# {2006, Feb}:  sup = 0.067
# {Arrested, Feb}:  sup = 0.062
# {2006, NARCOTICS}:  sup = 0.099
# {NARCOTICS, Arrested}:  sup = 0.1
# {NARCOTICS, Feb}:  sup = 0.056
# {2006, Noon}:  sup = 0.188
# {Noon, Arrested}:  sup = 0.05
# {2006, Not Domestic}:  sup = 0.856
# {Arrested, Not Domestic}:  sup = 0.248
# {Feb, Not Domestic}:  sup = 0.067
# {NARCOTICS, Not Domestic}:  sup = 0.1
# {Noon, Not Domestic}:  sup = 0.168
# {2006, SIDEWALK}:  sup = 0.099
# {SIDEWALK, Arrested}:  sup = 0.053
# {SIDEWALK, Not Domestic}:  sup = 0.091
# {Day of Month 13, 2006, Apr}:  sup = 0.064
# {Day of Month 13, Not Arrested, Apr}:  sup = 0.051
# {Day of Month 13, Not Domestic, Apr}:  sup = 0.054
# {2006, Day of Month 12, Apr}:  sup = 0.079
# {Day of Month 12, Not Arrested, Apr}:  sup = 0.064
# {Day of Month 12, Not Domestic, Apr}:  sup = 0.068
# {Day of Month 11, Not Arrested, Apr}:  sup = 0.072
# {2006, Day of Month 11, Apr}:  sup = 0.089
# {Day of Month 11, Not Domestic, Apr}:  sup = 0.076
# {2006, Day of Month 10, Apr}:  sup = 0.089
# {Not Arrested, Day of Month 10, Apr}:  sup = 0.073
# {Not Domestic, Day of Month 10, Apr}:  sup = 0.076
# {Day of Month 9, 2006, Apr}:  sup = 0.088
# {Day of Month 9, Not Arrested, Not Domestic}:  sup = 0.061
# {Day of Month 9, Not Arrested, Apr}:  sup = 0.072
# {Day of Month 9, Not Domestic, Apr}:  sup = 0.074
# {Day of Month 13, 2006, Not Domestic}:  sup = 0.059
# {2006, Day of Month 8, Apr}:  sup = 0.088
# {Not Arrested, Day of Month 8, Apr}:  sup = 0.071
# {Not Domestic, Day of Month 8, Apr}:  sup = 0.075
# {Day of Month 9, 2006, Not Arrested}:  sup = 0.073
# {Day of Month 12, Not Arrested, Not Domestic}:  sup = 0.056
# {2006, Day of Month 12, Not Domestic}:  sup = 0.07
# {2006, Day of Month 12, Not Arrested}:  sup = 0.064
# {Day of Month 11, Not Arrested, Not Domestic}:  sup = 0.063
# {2006, Day of Month 11, Not Domestic}:  sup = 0.078
# {2006, Day of Month 11, Not Arrested}:  sup = 0.073
# {Day of Month 7, Not Domestic, Apr}:  sup = 0.083
# {2006, Day of Month 7, Apr}:  sup = 0.096
# {Day of Month 7, Not Arrested, Apr}:  sup = 0.077
# {Not Arrested, Day of Month 10, Not Domestic}:  sup = 0.065
# {2006, Day of Month 10, Not Domestic}:  sup = 0.078
# {2006, Not Arrested, Day of Month 10}:  sup = 0.074
# {Day of Month 13, 2006, Not Arrested}:  sup = 0.053
# {Day of Month 9, 2006, Not Domestic}:  sup = 0.079
# {Night, Arrested, Apr}:  sup = 0.053
# {Day of Month 7, Not Arrested, Not Domestic}:  sup = 0.069
# {2006, Day of Month 7, Not Domestic}:  sup = 0.088
# {2006, Day of Month 7, Not Arrested}:  sup = 0.08
# {APARTMENT, 2006, Not Arrested}:  sup = 0.079
# {APARTMENT, 2006, Apr}:  sup = 0.092
# {APARTMENT, Not Domestic, Apr}:  sup = 0.056
# {APARTMENT, Not Arrested, Not Domestic}:  sup = 0.051
# {APARTMENT, Not Arrested, Apr}:  sup = 0.073
# {2006, District 7.0, Apr}:  sup = 0.064
# {Not Arrested, District 7.0, Apr}:  sup = 0.054
# {2006, Not Arrested, OTHER OFFENSE}:  sup = 0.059
# {2006, OTHER OFFENSE, Apr}:  sup = 0.059
# {Not Arrested, OTHER OFFENSE, Apr}:  sup = 0.051
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE}:  sup = 0.064
# {TO VEHICLE, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.063
# {Not Arrested, TO VEHICLE, Apr}:  sup = 0.061
# {Not Domestic, TO VEHICLE, Apr}:  sup = 0.061
# {TO VEHICLE, CRIMINAL DAMAGE, Apr}:  sup = 0.063
# {Not Arrested, TO VEHICLE, Not Domestic}:  sup = 0.061
# {2006, TO VEHICLE, Not Domestic}:  sup = 0.064
# {2006, Not Arrested, TO VEHICLE}:  sup = 0.064
# {2006, TO VEHICLE, Apr}:  sup = 0.065
# {2006, TO VEHICLE, CRIMINAL DAMAGE}:  sup = 0.066
# {Night, STREET, Apr}:  sup = 0.084
# {STREET, Not Arrested, Night}:  sup = 0.078
# {Not Arrested, TO PROPERTY, Apr}:  sup = 0.052
# {Not Domestic, TO PROPERTY, Apr}:  sup = 0.052
# {Not Arrested, TO PROPERTY, Not Domestic}:  sup = 0.05
# {2006, TO PROPERTY, Not Domestic}:  sup = 0.054
# {2006, Not Arrested, TO PROPERTY}:  sup = 0.055
# {2006, TO PROPERTY, Apr}:  sup = 0.057
# {Not Arrested, CRIMINAL DAMAGE, Apr}:  sup = 0.124
# {Not Domestic, CRIMINAL DAMAGE, Apr}:  sup = 0.124
# {Night, CRIMINAL DAMAGE, Apr}:  sup = 0.059
# {TO PROPERTY, CRIMINAL DAMAGE, Apr}:  sup = 0.057
# {Not Arrested, TO PROPERTY, CRIMINAL DAMAGE}:  sup = 0.055
# {Night, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.056
# {TO PROPERTY, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.054
# {Not Arrested, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.121
# {Night, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.056
# {2006, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.129
# {2006, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.129
# {2006, Night, CRIMINAL DAMAGE}:  sup = 0.06
# {2006, CRIMINAL DAMAGE, Apr}:  sup = 0.133
# {2006, TO PROPERTY, CRIMINAL DAMAGE}:  sup = 0.059
# {STREET, 2006, Evening}:  sup = 0.059
# {STREET, Evening, Not Domestic}:  sup = 0.055
# {RESIDENCE, 2006, Night}:  sup = 0.055
# {2006, THEFT, Night}:  sup = 0.051
# {Night, THEFT, Not Domestic}:  sup = 0.051
# {2006, Not Arrested, District 7.0}:  sup = 0.061
# {2006, District 11.0, Not Domestic}:  sup = 0.055
# {STREET, 2006, Arrested}:  sup = 0.071
# {STREET, 2006, Night}:  sup = 0.109
# {STREET, Night, Not Domestic}:  sup = 0.104
# {STREET, Arrested, Not Domestic}:  sup = 0.068
# {SIDEWALK, Not Domestic, Apr}:  sup = 0.054
# {2006, Evening, Arrested}:  sup = 0.06
# {Evening, Arrested, Not Domestic}:  sup = 0.055
# {Morning, Not Arrested, Apr}:  sup = 0.152
# {2006, Morning, Not Arrested}:  sup = 0.171
# {2006, THEFT, Morning}:  sup = 0.057
# {STREET, 2006, Morning}:  sup = 0.053
# {THEFT, Not Domestic, OVER $500}:  sup = 0.051
# {2006, Not Domestic, OVER $500}:  sup = 0.051
# {2006, THEFT, OVER $500}:  sup = 0.052
# {Not Arrested, Day of Month 6, Apr}:  sup = 0.069
# {Not Domestic, Day of Month 6, Apr}:  sup = 0.078
# {Not Arrested, Day of Month 6, Not Domestic}:  sup = 0.061
# {2006, Day of Month 6, Not Domestic}:  sup = 0.08
# {2006, Not Arrested, Day of Month 6}:  sup = 0.07
# {2006, Day of Month 6, Apr}:  sup = 0.089
# {THEFT, Morning, Not Domestic}:  sup = 0.057
# {Morning, Not Arrested, Not Domestic}:  sup = 0.153
# {Morning, Not Arrested, THEFT}:  sup = 0.052
# {2006, BATTERY, Night}:  sup = 0.081
# {2006, SIDEWALK, Apr}:  sup = 0.062
# {Night, BATTERY, Apr}:  sup = 0.079
# {Domestic, Not Arrested, BATTERY}:  sup = 0.058
# {Domestic, BATTERY, Apr}:  sup = 0.074
# {Domestic, Not Arrested, Apr}:  sup = 0.096
# {Domestic, Night, Apr}:  sup = 0.051
# {Domestic, 2006, Not Arrested}:  sup = 0.102
# {Domestic, 2006, Night}:  sup = 0.053
# {Domestic, 2006, BATTERY}:  sup = 0.075
# {Domestic, 2006, Apr}:  sup = 0.12
# {Not Arrested, BATTERY, DOMESTIC BATTERY SIMPLE}:  sup = 0.071
# {Domestic, BATTERY, DOMESTIC BATTERY SIMPLE}:  sup = 0.069
# {BATTERY, DOMESTIC BATTERY SIMPLE, Apr}:  sup = 0.091
# {Not Arrested, DOMESTIC BATTERY SIMPLE, Apr}:  sup = 0.068
# {Domestic, DOMESTIC BATTERY SIMPLE, Apr}:  sup = 0.067
# {Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE}:  sup = 0.053
# {2006, Not Arrested, DOMESTIC BATTERY SIMPLE}:  sup = 0.07
# {2006, BATTERY, DOMESTIC BATTERY SIMPLE}:  sup = 0.094
# {2006, DOMESTIC BATTERY SIMPLE, Apr}:  sup = 0.091
# {2006, Domestic, DOMESTIC BATTERY SIMPLE}:  sup = 0.069
# {Night, Not Arrested, BATTERY}:  sup = 0.062
# {2006, Night, Apr}:  sup = 0.29
# {2006, ASSAULT, Apr}:  sup = 0.058
# {Night, Not Arrested, Apr}:  sup = 0.237
# {Night, Not Domestic, Apr}:  sup = 0.239
# {2006, Not Arrested, Noon}:  sup = 0.138
# {2006, Noon, Apr}:  sup = 0.157
# {District 8.0, 2006, Not Arrested}:  sup = 0.057
# {District 8.0, 2006, Apr}:  sup = 0.065
# {THEFT, Not Arrested, Apr}:  sup = 0.15
# {THEFT, Not Domestic, Apr}:  sup = 0.168
# {THEFT, Not Arrested, Not Domestic}:  sup = 0.166
# {2006, THEFT, Not Domestic}:  sup = 0.185
# {2006, THEFT, Not Arrested}:  sup = 0.167
# {2006, THEFT, Apr}:  sup = 0.172
# {STREET, Not Arrested, Apr}:  sup = 0.182
# {STREET, Not Domestic, Apr}:  sup = 0.194
# {STREET, Not Arrested, Not Domestic}:  sup = 0.179
# {STREET, 2006, Not Domestic}:  sup = 0.244
# {STREET, 2006, Not Arrested}:  sup = 0.191
# {STREET, 2006, Apr}:  sup = 0.211
# {THEFT, $500 AND UNDER, Apr}:  sup = 0.061
# {THEFT, Not Arrested, $500 AND UNDER}:  sup = 0.061
# {Not Arrested, $500 AND UNDER, Apr}:  sup = 0.056
# {THEFT, $500 AND UNDER, Not Domestic}:  sup = 0.063
# {Apr, $500 AND UNDER, Not Domestic}:  sup = 0.059
# {Not Arrested, $500 AND UNDER, Not Domestic}:  sup = 0.059
# {2006, THEFT, $500 AND UNDER}:  sup = 0.064
# {2006, $500 AND UNDER, Apr}:  sup = 0.061
# {2006, Not Arrested, $500 AND UNDER}:  sup = 0.06
# {2006, $500 AND UNDER, Not Domestic}:  sup = 0.062
# {District 8.0, Not Arrested, Apr}:  sup = 0.054
# {District 8.0, Not Domestic, Apr}:  sup = 0.055
# {Noon, Not Arrested, Apr}:  sup = 0.126
# {Noon, Not Domestic, Apr}:  sup = 0.134
# {Not Arrested, Noon, Not Domestic}:  sup = 0.121
# {2006, Arrested, Apr}:  sup = 0.158
# {Morning, Not Domestic, Apr}:  sup = 0.164
# {Morning, Arrested, Not Domestic}:  sup = 0.055
# {2006, Morning, Not Domestic}:  sup = 0.204
# {2006, Morning, Arrested}:  sup = 0.061
# {2006, Morning, Apr}:  sup = 0.189
# {Not Domestic, Arrested, Apr}:  sup = 0.133
# {Arrested, Mar, Not Domestic}:  sup = 0.05
# {2006, Mar, Not Domestic}:  sup = 0.09
# {2006, Arrested, Mar}:  sup = 0.051
# {2006, District 7.0, Not Domestic}:  sup = 0.062
# {APARTMENT, 2006, Not Domestic}:  sup = 0.062
# {Night, 2006, Arrested}:  sup = 0.102
# {District 8.0, 2006, Not Domestic}:  sup = 0.065
# {Night, Arrested, Not Domestic}:  sup = 0.091
# {Not Arrested, SIMPLE, Not Domestic}:  sup = 0.086
# {2006, SIMPLE, Not Domestic}:  sup = 0.104
# {2006, Not Arrested, SIMPLE}:  sup = 0.093
# {RESIDENCE, Not Arrested, Not Domestic}:  sup = 0.101
# {RESIDENCE, 2006, Not Domestic}:  sup = 0.111
# {RESIDENCE, 2006, Not Arrested}:  sup = 0.138
# {Not Arrested, Evening, Not Domestic}:  sup = 0.135
# {2006, Evening, Not Domestic}:  sup = 0.187
# {2006, Not Arrested, Evening}:  sup = 0.15
# {BATTERY, SIMPLE, Apr}:  sup = 0.07
# {Not Arrested, BATTERY, SIMPLE}:  sup = 0.06
# {BATTERY, SIMPLE, Not Domestic}:  sup = 0.072
# {Not Arrested, BATTERY, Not Domestic}:  sup = 0.098
# {2006, BATTERY, Not Domestic}:  sup = 0.124
# {2006, Not Arrested, BATTERY}:  sup = 0.153
# {2006, BATTERY, SIMPLE}:  sup = 0.073
# {Not Arrested, SIMPLE, Apr}:  sup = 0.088
# {RESIDENCE, Not Arrested, Apr}:  sup = 0.123
# {Not Arrested, Evening, Apr}:  sup = 0.142
# {Not Arrested, BATTERY, Apr}:  sup = 0.147
# {SIMPLE, Not Domestic, Apr}:  sup = 0.099
# {RESIDENCE, Not Domestic, Apr}:  sup = 0.095
# {Evening, Not Domestic, Apr}:  sup = 0.157
# {BATTERY, Not Domestic, Apr}:  sup = 0.119
# {Not Arrested, Not Domestic, Apr}:  sup = 0.56
# {2006, Not Domestic, Apr}:  sup = 0.693
# {2006, Not Arrested, Apr}:  sup = 0.655
# {2006, SIMPLE, Apr}:  sup = 0.109
# {2006, RESIDENCE, Apr}:  sup = 0.14
# {2006, Evening, Apr}:  sup = 0.178
# {2006, BATTERY, Apr}:  sup = 0.193
# {2006, Not Arrested, Not Domestic}:  sup = 0.611
# {Night, Not Arrested, Not Domestic}:  sup = 0.215
# {Night, 2006, Not Domestic}:  sup = 0.301
# {Night, 2006, Not Arrested}:  sup = 0.253
# {Not Arrested, Day of Month 8, Not Domestic}:  sup = 0.062
# {2006, Day of Month 8, Not Domestic}:  sup = 0.084
# {2006, Not Arrested, Day of Month 8}:  sup = 0.072
# {SIDEWALK, Arrested, Not Domestic}:  sup = 0.051
# {2006, SIDEWALK, Not Domestic}:  sup = 0.09
# {2006, Noon, Not Domestic}:  sup = 0.164
# {NARCOTICS, Feb, Not Domestic}:  sup = 0.056
# {NARCOTICS, Arrested, Not Domestic}:  sup = 0.1
# {2006, NARCOTICS, Not Domestic}:  sup = 0.099
# {Arrested, Feb, Not Domestic}:  sup = 0.062
# {NARCOTICS, Arrested, Feb}:  sup = 0.056
# {2006, Feb, Not Domestic}:  sup = 0.066
# {2006, NARCOTICS, Feb}:  sup = 0.055
# {2006, SIDEWALK, Arrested}:  sup = 0.053
# {2006, Arrested, Not Domestic}:  sup = 0.246
# {2006, NARCOTICS, Arrested}:  sup = 0.099
# {2006, Feb, Arrested}:  sup = 0.062
# {Day of Month 13, 2006, Not Arrested, Apr}:  sup = 0.051
# {Day of Month 13, 2006, Apr, Not Domestic}:  sup = 0.054
# {Not Arrested, Apr, Day of Month 12, Not Domestic}:  sup = 0.055
# {2006, Not Arrested, Apr, Day of Month 12}:  sup = 0.063
# {2006, Apr, Day of Month 12, Not Domestic}:  sup = 0.068
# {2006, Day of Month 11, Not Arrested, Apr}:  sup = 0.071
# {Day of Month 11, Not Arrested, Apr, Not Domestic}:  sup = 0.061
# {2006, Day of Month 11, Apr, Not Domestic}:  sup = 0.076
# {Not Arrested, Day of Month 10, Apr, Not Domestic}:  sup = 0.063
# {2006, Not Arrested, Day of Month 10, Apr}:  sup = 0.073
# {2006, Day of Month 10, Apr, Not Domestic}:  sup = 0.076
# {Day of Month 9, 2006, Not Arrested, Not Domestic}:  sup = 0.061
# {Day of Month 9, Not Arrested, Apr, Not Domestic}:  sup = 0.06
# {Day of Month 9, 2006, Not Arrested, Apr}:  sup = 0.072
# {Day of Month 9, 2006, Apr, Not Domestic}:  sup = 0.074
# {Not Arrested, Apr, Day of Month 8, Not Domestic}:  sup = 0.061
# {2006, Not Arrested, Apr, Day of Month 8}:  sup = 0.071
# {2006, Apr, Day of Month 8, Not Domestic}:  sup = 0.075
# {2006, Not Arrested, Day of Month 12, Not Domestic}:  sup = 0.055
# {2006, Day of Month 11, Not Arrested, Not Domestic}:  sup = 0.062
# {2006, Apr, Day of Month 7, Not Domestic}:  sup = 0.083
# {Not Arrested, Apr, Day of Month 7, Not Domestic}:  sup = 0.067
# {2006, Not Arrested, Apr, Day of Month 7}:  sup = 0.077
# {2006, Not Arrested, Day of Month 10, Not Domestic}:  sup = 0.064
# {2006, Night, Apr, Arrested}:  sup = 0.053
# {2006, Not Arrested, Day of Month 7, Not Domestic}:  sup = 0.069
# {APARTMENT, 2006, Apr, Not Domestic}:  sup = 0.056
# {APARTMENT, 2006, Not Arrested, Not Domestic}:  sup = 0.05
# {APARTMENT, 2006, Not Arrested, Apr}:  sup = 0.073
# {2006, Not Arrested, Apr, District 7.0}:  sup = 0.054
# {2006, Not Arrested, Apr, OTHER OFFENSE}:  sup = 0.051
# {2006, Not Arrested, TO VEHICLE, CRIMINAL DAMAGE}:  sup = 0.064
# {2006, TO VEHICLE, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.062
# {2006, Not Arrested, TO VEHICLE, Apr}:  sup = 0.061
# {2006, TO VEHICLE, Apr, Not Domestic}:  sup = 0.061
# {2006, TO VEHICLE, CRIMINAL DAMAGE, Apr}:  sup = 0.063
# {2006, Not Arrested, TO VEHICLE, Not Domestic}:  sup = 0.06
# {TO VEHICLE, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.059
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE, Apr}:  sup = 0.061
# {Not Arrested, TO VEHICLE, Apr, Not Domestic}:  sup = 0.057
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.06
# {2006, Night, Apr, STREET}:  sup = 0.084
# {2006, Night, Not Arrested, STREET}:  sup = 0.077
# {Night, Not Arrested, STREET, Not Domestic}:  sup = 0.073
# {Night, Apr, STREET, Not Domestic}:  sup = 0.078
# {Night, Not Arrested, Apr, STREET}:  sup = 0.074
# {2006, Not Arrested, CRIMINAL DAMAGE, Apr}:  sup = 0.124
# {2006, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.124
# {2006, Night, CRIMINAL DAMAGE, Apr}:  sup = 0.059
# {2006, Not Arrested, TO PROPERTY, CRIMINAL DAMAGE}:  sup = 0.055
# {2006, Night, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.056
# {2006, TO PROPERTY, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.054
# {2006, Night, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.055
# {2006, Not Arrested, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.121
# {Night, Not Arrested, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.052
# {Not Arrested, TO PROPERTY, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.05
# {TO PROPERTY, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.052
# {Night, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.054
# {Not Arrested, TO PROPERTY, CRIMINAL DAMAGE, Apr}:  sup = 0.052
# {Night, Not Arrested, CRIMINAL DAMAGE, Apr}:  sup = 0.054
# {Not Arrested, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.115
# {2006, Not Arrested, TO PROPERTY, Apr}:  sup = 0.052
# {2006, TO PROPERTY, Apr, Not Domestic}:  sup = 0.052
# {2006, TO PROPERTY, CRIMINAL DAMAGE, Apr}:  sup = 0.057
# {2006, Not Arrested, TO PROPERTY, Not Domestic}:  sup = 0.05
# {2006, Evening, STREET, Not Domestic}:  sup = 0.055
# {2006, Night, STREET, Not Domestic}:  sup = 0.103
# {2006, STREET, Arrested, Not Domestic}:  sup = 0.067
# {2006, Apr, SIDEWALK, Not Domestic}:  sup = 0.054
# {2006, Evening, Arrested, Not Domestic}:  sup = 0.055
# {2006, Morning, Not Arrested, Apr}:  sup = 0.151
# {Morning, Not Arrested, THEFT, Not Domestic}:  sup = 0.051
# {2006, Not Arrested, Day of Month 6, Apr}:  sup = 0.069
# {2006, Day of Month 6, Apr, Not Domestic}:  sup = 0.078
# {2006, Not Arrested, Day of Month 6, Not Domestic}:  sup = 0.061
# {Not Arrested, Day of Month 6, Apr, Not Domestic}:  sup = 0.06
# {2006, THEFT, OVER $500, Not Domestic}:  sup = 0.051
# {2006, THEFT, Morning, Not Domestic}:  sup = 0.056
# {2006, Morning, Not Arrested, Not Domestic}:  sup = 0.149
# {2006, Morning, Not Arrested, THEFT}:  sup = 0.051
# {Morning, Not Arrested, Apr, Not Domestic}:  sup = 0.132
# {2006, Night, BATTERY, Apr}:  sup = 0.078
# {2006, BATTERY, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.091
# {2006, Not Arrested, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.068
# {2006, Not Arrested, BATTERY, DOMESTIC BATTERY SIMPLE}:  sup = 0.07
# {2006, Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE}:  sup = 0.052
# {Domestic, Not Arrested, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.05
# {Not Arrested, BATTERY, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.068
# {Domestic, Not Arrested, BATTERY, DOMESTIC BATTERY SIMPLE}:  sup = 0.053
# {Domestic, 2006, BATTERY, Apr}:  sup = 0.074
# {Domestic, 2006, Not Arrested, Apr}:  sup = 0.096
# {Domestic, 2006, Night, Apr}:  sup = 0.051
# {Domestic, 2006, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.067
# {Domestic, 2006, Not Arrested, BATTERY}:  sup = 0.057
# {Domestic, 2006, BATTERY, DOMESTIC BATTERY SIMPLE}:  sup = 0.069
# {Domestic, Not Arrested, BATTERY, Apr}:  sup = 0.055
# {Domestic, BATTERY, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.067
# {Night, Not Arrested, BATTERY, Apr}:  sup = 0.06
# {2006, Night, Not Arrested, BATTERY}:  sup = 0.061
# {Night, Not Arrested, Apr, Not Domestic}:  sup = 0.197
# {2006, Night, Not Arrested, Apr}:  sup = 0.237
# {2006, Night, Apr, Not Domestic}:  sup = 0.239
# {Noon, Not Arrested, Apr, Not Domestic}:  sup = 0.106
# {2006, Not Arrested, $500 AND UNDER, Not Domestic}:  sup = 0.058
# {2006, Apr, $500 AND UNDER, Not Domestic}:  sup = 0.059
# {2006, Not Arrested, Apr, $500 AND UNDER}:  sup = 0.056
# {2006, THEFT, $500 AND UNDER, Not Domestic}:  sup = 0.062
# {2006, THEFT, Not Arrested, $500 AND UNDER}:  sup = 0.06
# {2006, THEFT, Apr, $500 AND UNDER}:  sup = 0.061
# {Not Arrested, Apr, $500 AND UNDER, Not Domestic}:  sup = 0.055
# {THEFT, Not Arrested, $500 AND UNDER, Not Domestic}:  sup = 0.059
# {THEFT, Apr, $500 AND UNDER, Not Domestic}:  sup = 0.059
# {THEFT, Not Arrested, Apr, $500 AND UNDER}:  sup = 0.056
# {2006, Not Arrested, Apr, STREET}:  sup = 0.182
# {2006, Apr, STREET, Not Domestic}:  sup = 0.194
# {2006, Not Arrested, STREET, Not Domestic}:  sup = 0.177
# {Not Arrested, Apr, STREET, Not Domestic}:  sup = 0.168
# {2006, THEFT, Not Arrested, Apr}:  sup = 0.15
# {2006, THEFT, Apr, Not Domestic}:  sup = 0.168
# {2006, THEFT, Not Arrested, Not Domestic}:  sup = 0.162
# {THEFT, Not Arrested, Apr, Not Domestic}:  sup = 0.146
# {2006, Not Arrested, Apr, District 8.0}:  sup = 0.054
# {2006, Apr, District 8.0, Not Domestic}:  sup = 0.055
# {2006, Noon, Not Arrested, Apr}:  sup = 0.126
# {2006, Noon, Apr, Not Domestic}:  sup = 0.134
# {2006, Not Arrested, Noon, Not Domestic}:  sup = 0.118
# {2006, Morning, Apr, Not Domestic}:  sup = 0.163
# {2006, Morning, Arrested, Not Domestic}:  sup = 0.055
# {2006, Apr, Arrested, Not Domestic}:  sup = 0.133
# {2006, Arrested, Mar, Not Domestic}:  sup = 0.05
# {Night, 2006, Arrested, Not Domestic}:  sup = 0.09
# {2006, BATTERY, Apr, SIMPLE}:  sup = 0.07
# {2006, Not Arrested, BATTERY, Apr}:  sup = 0.147
# {2006, Not Arrested, Evening, Apr}:  sup = 0.142
# {2006, Not Arrested, Apr, RESIDENCE}:  sup = 0.123
# {2006, Not Arrested, Apr, SIMPLE}:  sup = 0.088
# {2006, BATTERY, Apr, Not Domestic}:  sup = 0.119
# {2006, Evening, Apr, Not Domestic}:  sup = 0.157
# {2006, Apr, RESIDENCE, Not Domestic}:  sup = 0.095
# {2006, Apr, SIMPLE, Not Domestic}:  sup = 0.099
# {2006, Not Arrested, Apr, Not Domestic}:  sup = 0.56
# {Not Arrested, BATTERY, Apr, Not Domestic}:  sup = 0.092
# {Not Arrested, Evening, Apr, Not Domestic}:  sup = 0.125
# {Not Arrested, Apr, RESIDENCE, Not Domestic}:  sup = 0.086
# {Not Arrested, Apr, SIMPLE, Not Domestic}:  sup = 0.08
# {2006, Not Arrested, BATTERY, SIMPLE}:  sup = 0.059
# {2006, BATTERY, SIMPLE, Not Domestic}:  sup = 0.071
# {2006, Not Arrested, BATTERY, Not Domestic}:  sup = 0.096
# {Not Arrested, BATTERY, SIMPLE, Not Domestic}:  sup = 0.059
# {BATTERY, Apr, SIMPLE, Not Domestic}:  sup = 0.068
# {Not Arrested, BATTERY, Apr, SIMPLE}:  sup = 0.056
# {2006, Not Arrested, Evening, Not Domestic}:  sup = 0.133
# {2006, Not Arrested, RESIDENCE, Not Domestic}:  sup = 0.098
# {2006, Not Arrested, SIMPLE, Not Domestic}:  sup = 0.084
# {2006, Not Arrested, Day of Month 8, Not Domestic}:  sup = 0.061
# {Night, 2006, Not Arrested, Not Domestic}:  sup = 0.211
# {2006, NARCOTICS, Feb, Arrested}:  sup = 0.055
# {2006, Feb, Arrested, Not Domestic}:  sup = 0.062
# {2006, NARCOTICS, Arrested, Not Domestic}:  sup = 0.099
# {2006, SIDEWALK, Arrested, Not Domestic}:  sup = 0.051
# {2006, NARCOTICS, Feb, Not Domestic}:  sup = 0.055
# {NARCOTICS, Feb, Arrested, Not Domestic}:  sup = 0.056
# {Not Arrested, Day of Month 12, 2006, Apr, Not Domestic}:  sup = 0.055
# {Not Arrested, 2006, Day of Month 11, Apr, Not Domestic}:  sup = 0.061
# {Not Arrested, Day of Month 10, 2006, Apr, Not Domestic}:  sup = 0.063
# {Not Arrested, Day of Month 9, 2006, Apr, Not Domestic}:  sup = 0.06
# {Not Arrested, Day of Month 8, 2006, Apr, Not Domestic}:  sup = 0.061
# {Not Arrested, Day of Month 7, 2006, Apr, Not Domestic}:  sup = 0.067
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.057
# {TO VEHICLE, 2006, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.059
# {Not Arrested, TO VEHICLE, 2006, CRIMINAL DAMAGE, Apr}:  sup = 0.061
# {Not Arrested, TO VEHICLE, 2006, Apr, Not Domestic}:  sup = 0.057
# {Not Arrested, TO VEHICLE, 2006, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.059
# {Night, Not Arrested, STREET, Apr, Not Domestic}:  sup = 0.069
# {Night, Not Arrested, STREET, 2006, Not Domestic}:  sup = 0.072
# {Night, STREET, 2006, Apr, Not Domestic}:  sup = 0.078
# {Night, Not Arrested, STREET, 2006, Apr}:  sup = 0.074
# {Night, Not Arrested, 2006, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.051
# {Not Arrested, 2006, TO PROPERTY, CRIMINAL DAMAGE, Not Domestic}:  sup = 0.05
# {2006, TO PROPERTY, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.052
# {Night, 2006, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.054
# {Not Arrested, 2006, TO PROPERTY, CRIMINAL DAMAGE, Apr}:  sup = 0.052
# {Night, Not Arrested, 2006, CRIMINAL DAMAGE, Apr}:  sup = 0.054
# {Not Arrested, 2006, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.115
# {Morning, Not Arrested, 2006, THEFT, Not Domestic}:  sup = 0.05
# {Not Arrested, Day of Month 6, 2006, Apr, Not Domestic}:  sup = 0.06
# {Morning, Not Arrested, 2006, Apr, Not Domestic}:  sup = 0.132
# {Not Arrested, BATTERY, Domestic, 2006, Apr}:  sup = 0.055
# {Not Arrested, BATTERY, Domestic, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.05
# {Not Arrested, BATTERY, 2006, Domestic, DOMESTIC BATTERY SIMPLE}:  sup = 0.052
# {Not Arrested, 2006, Domestic, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.05
# {Not Arrested, BATTERY, 2006, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.068
# {BATTERY, 2006, Domestic, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.067
# {Night, Not Arrested, BATTERY, 2006, Apr}:  sup = 0.06
# {Night, Not Arrested, 2006, Apr, Not Domestic}:  sup = 0.197
# {Not Arrested, 2006, Noon, Apr, Not Domestic}:  sup = 0.106
# {Not Arrested, 2006, THEFT, Apr, Not Domestic}:  sup = 0.146
# {Not Arrested, STREET, 2006, Apr, Not Domestic}:  sup = 0.168
# {Not Arrested, THEFT, Apr, $500 AND UNDER, Not Domestic}:  sup = 0.055
# {Not Arrested, 2006, THEFT, Apr, $500 AND UNDER}:  sup = 0.056
# {2006, THEFT, Apr, $500 AND UNDER, Not Domestic}:  sup = 0.059
# {Not Arrested, 2006, Apr, $500 AND UNDER, Not Domestic}:  sup = 0.055
# {Not Arrested, 2006, THEFT, $500 AND UNDER, Not Domestic}:  sup = 0.058
# {Not Arrested, BATTERY, SIMPLE, 2006, Not Domestic}:  sup = 0.058
# {Not Arrested, BATTERY, SIMPLE, Apr, Not Domestic}:  sup = 0.055
# {Not Arrested, SIMPLE, 2006, Apr, Not Domestic}:  sup = 0.08
# {Not Arrested, RESIDENCE, 2006, Apr, Not Domestic}:  sup = 0.086
# {Not Arrested, 2006, Evening, Apr, Not Domestic}:  sup = 0.125
# {Not Arrested, BATTERY, 2006, Apr, Not Domestic}:  sup = 0.091
# {BATTERY, SIMPLE, 2006, Apr, Not Domestic}:  sup = 0.068
# {Not Arrested, BATTERY, SIMPLE, 2006, Apr}:  sup = 0.056
# {NARCOTICS, Feb, Arrested, 2006, Not Domestic}:  sup = 0.055
# {Not Arrested, TO VEHICLE, 2006, CRIMINAL DAMAGE, Apr, Not Domestic}:  sup = 0.057
# {Night, Not Arrested, STREET, 2006, Apr, Not Domestic}:  sup = 0.069
# {Not Arrested, BATTERY, 2006, Domestic, Apr, DOMESTIC BATTERY SIMPLE}:  sup = 0.05
# {Not Arrested, 2006, THEFT, Apr, $500 AND UNDER, Not Domestic}:  sup = 0.055
# {Not Arrested, BATTERY, SIMPLE, 2006, Apr, Not Domestic}:  sup = 0.055

# %%
# Association rules with confidence 40%
H_apr = generate_rules(F_apr, support_data_apr, min_confidence=0.9, verbose=True)
# Out:
# {Day of Month 13} ---> {Apr}:  conf = 0.926, sup = 0.064
# {Day of Month 12} ---> {Apr}:  conf = 0.975, sup = 0.08
# {Day of Month 11} ---> {Apr}:  conf = 0.965, sup = 0.089
# {Day of Month 10} ---> {Apr}:  conf = 0.968, sup = 0.089
# {Day of Month 9} ---> {Apr}:  conf = 0.942, sup = 0.088
# {Day of Month 8} ---> {Apr}:  conf = 0.905, sup = 0.088
# {Day of Month 12} ---> {2006}:  conf = 0.995, sup = 0.081
# {Day of Month 11} ---> {2006}:  conf = 0.99, sup = 0.092
# {Day of Month 7} ---> {Apr}:  conf = 0.948, sup = 0.096
# {Day of Month 10} ---> {2006}:  conf = 0.991, sup = 0.092
# {Day of Month 13} ---> {2006}:  conf = 0.994, sup = 0.069
# {Day of Month 9} ---> {2006}:  conf = 0.997, sup = 0.093
# {District 6.0} ---> {2006}:  conf = 0.948, sup = 0.058
# {Day of Month 7} ---> {2006}:  conf = 0.997, sup = 0.101
# {APARTMENT} ---> {Apr}:  conf = 0.911, sup = 0.092
# {TO VEHICLE} ---> {2006}:  conf = 0.99, sup = 0.068
# {TO VEHICLE} ---> {Not Domestic}:  conf = 0.94, sup = 0.064
# {TO VEHICLE} ---> {Not Arrested}:  conf = 0.946, sup = 0.065
# {TO VEHICLE} ---> {Apr}:  conf = 0.947, sup = 0.065
# {TO VEHICLE} ---> {CRIMINAL DAMAGE}:  conf = 0.977, sup = 0.067
# {CRIMINAL DAMAGE} ---> {2006}:  conf = 0.994, sup = 0.139
# {CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.931, sup = 0.13
# {CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.931, sup = 0.13
# {CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.953, sup = 0.133
# {TO PROPERTY} ---> {2006}:  conf = 0.998, sup = 0.059
# {TO PROPERTY} ---> {Not Domestic}:  conf = 0.909, sup = 0.054
# {TO PROPERTY} ---> {Not Arrested}:  conf = 0.921, sup = 0.055
# {TO PROPERTY} ---> {Apr}:  conf = 0.958, sup = 0.057
# {TO PROPERTY} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.06
# {District 25.0} ---> {2006}:  conf = 0.986, sup = 0.05
# {OTHER OFFENSE} ---> {2006}:  conf = 0.982, sup = 0.067
# {District 11.0} ---> {2006}:  conf = 0.953, sup = 0.064
# {District 4.0} ---> {2006}:  conf = 0.983, sup = 0.051
# {Day of Month 6} ---> {2006}:  conf = 0.991, sup = 0.091
# {Day of Month 6} ---> {Apr}:  conf = 0.966, sup = 0.089
# {OVER $500} ---> {2006}:  conf = 0.996, sup = 0.052
# {OVER $500} ---> {Not Domestic}:  conf = 0.986, sup = 0.051
# {OVER $500} ---> {THEFT}:  conf = 1.0, sup = 0.052
# {DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.99, sup = 0.094
# {DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.966, sup = 0.091
# {DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.095
# {Domestic} ---> {2006}:  conf = 0.988, sup = 0.127
# {Domestic} ---> {Apr}:  conf = 0.936, sup = 0.121
# {ASSAULT} ---> {Apr}:  conf = 0.938, sup = 0.058
# {$500 AND UNDER} ---> {2006}:  conf = 0.988, sup = 0.064
# {$500 AND UNDER} ---> {Not Domestic}:  conf = 0.966, sup = 0.063
# {$500 AND UNDER} ---> {Not Arrested}:  conf = 0.932, sup = 0.061
# {$500 AND UNDER} ---> {Apr}:  conf = 0.934, sup = 0.061
# {STREET} ---> {2006}:  conf = 0.986, sup = 0.262
# {STREET} ---> {Not Domestic}:  conf = 0.93, sup = 0.247
# {THEFT} ---> {2006}:  conf = 0.98, sup = 0.19
# {THEFT} ---> {Not Domestic}:  conf = 0.973, sup = 0.189
# {$500 AND UNDER} ---> {THEFT}:  conf = 1.0, sup = 0.065
# {Morning} ---> {2006}:  conf = 0.983, sup = 0.231
# {APARTMENT} ---> {2006}:  conf = 0.989, sup = 0.1
# {District 7.0} ---> {2006}:  conf = 0.993, sup = 0.081
# {Mar} ---> {2006}:  conf = 0.996, sup = 0.095
# {Mar} ---> {Not Domestic}:  conf = 0.947, sup = 0.09
# {District 8.0} ---> {2006}:  conf = 0.992, sup = 0.076
# {Apr} ---> {2006}:  conf = 0.999, sup = 0.813
# {Not Arrested} ---> {Apr}:  conf = 0.903, sup = 0.656
# {BATTERY} ---> {2006}:  conf = 0.985, sup = 0.2
# {BATTERY} ---> {Apr}:  conf = 0.951, sup = 0.193
# {Evening} ---> {2006}:  conf = 0.99, sup = 0.21
# {RESIDENCE} ---> {2006}:  conf = 0.975, sup = 0.159
# {SIMPLE} ---> {2006}:  conf = 0.984, sup = 0.114
# {SIMPLE} ---> {Not Domestic}:  conf = 0.91, sup = 0.106
# {SIMPLE} ---> {Apr}:  conf = 0.939, sup = 0.109
# {ASSAULT} ---> {2006}:  conf = 0.985, sup = 0.061
# {Day of Month 8} ---> {2006}:  conf = 0.996, sup = 0.097
# {Night} ---> {2006}:  conf = 0.984, sup = 0.355
# {Not Arrested} ---> {2006}:  conf = 0.981, sup = 0.712
# {Arrested} ---> {2006}:  conf = 0.992, sup = 0.272
# {District 3.0} ---> {2006}:  conf = 0.988, sup = 0.059
# {Feb} ---> {2006}:  conf = 0.997, sup = 0.067
# {Feb} ---> {Arrested}:  conf = 0.92, sup = 0.062
# {NARCOTICS} ---> {2006}:  conf = 0.987, sup = 0.099
# {NARCOTICS} ---> {Arrested}:  conf = 0.998, sup = 0.1
# {Noon} ---> {2006}:  conf = 0.979, sup = 0.188
# {Not Domestic} ---> {2006}:  conf = 0.983, sup = 0.856
# {Arrested} ---> {Not Domestic}:  conf = 0.905, sup = 0.248
# {Feb} ---> {Not Domestic}:  conf = 0.987, sup = 0.067
# {NARCOTICS} ---> {Not Domestic}:  conf = 1.0, sup = 0.1
# {SIDEWALK} ---> {2006}:  conf = 0.997, sup = 0.099
# {SIDEWALK} ---> {Not Domestic}:  conf = 0.911, sup = 0.091
# {Day of Month 13, Apr} ---> {2006}:  conf = 1.0, sup = 0.064
# {Day of Month 13, 2006} ---> {Apr}:  conf = 0.932, sup = 0.064
# {Day of Month 13} ---> {2006, Apr}:  conf = 0.926, sup = 0.064
# {Day of Month 13, Not Arrested} ---> {Apr}:  conf = 0.966, sup = 0.051
# {Day of Month 13, Not Domestic} ---> {Apr}:  conf = 0.919, sup = 0.054
# {Day of Month 12, Apr} ---> {2006}:  conf = 0.997, sup = 0.079
# {2006, Day of Month 12} ---> {Apr}:  conf = 0.978, sup = 0.079
# {Day of Month 12} ---> {2006, Apr}:  conf = 0.973, sup = 0.079
# {Day of Month 12, Not Arrested} ---> {Apr}:  conf = 0.985, sup = 0.064
# {Day of Month 12, Not Domestic} ---> {Apr}:  conf = 0.973, sup = 0.068
# {Day of Month 11, Not Arrested} ---> {Apr}:  conf = 0.976, sup = 0.072
# {Day of Month 11, Apr} ---> {2006}:  conf = 0.998, sup = 0.089
# {2006, Day of Month 11} ---> {Apr}:  conf = 0.973, sup = 0.089
# {Day of Month 11} ---> {2006, Apr}:  conf = 0.963, sup = 0.089
# {Day of Month 11, Not Domestic} ---> {Apr}:  conf = 0.963, sup = 0.076
# {Day of Month 10, Apr} ---> {2006}:  conf = 1.0, sup = 0.089
# {2006, Day of Month 10} ---> {Apr}:  conf = 0.976, sup = 0.089
# {Day of Month 10} ---> {2006, Apr}:  conf = 0.968, sup = 0.089
# {Not Arrested, Day of Month 10} ---> {Apr}:  conf = 0.975, sup = 0.073
# {Day of Month 10, Not Domestic} ---> {Apr}:  conf = 0.964, sup = 0.076
# {Day of Month 9, Apr} ---> {2006}:  conf = 1.0, sup = 0.088
# {Day of Month 9, 2006} ---> {Apr}:  conf = 0.945, sup = 0.088
# {Day of Month 9} ---> {2006, Apr}:  conf = 0.942, sup = 0.088
# {Day of Month 9, Not Arrested} ---> {Apr}:  conf = 0.981, sup = 0.072
# {Day of Month 9, Not Domestic} ---> {Apr}:  conf = 0.934, sup = 0.074
# {Day of Month 13, Not Domestic} ---> {2006}:  conf = 0.993, sup = 0.059
# {Day of Month 8, Apr} ---> {2006}:  conf = 1.0, sup = 0.088
# {2006, Day of Month 8} ---> {Apr}:  conf = 0.908, sup = 0.088
# {Day of Month 8} ---> {2006, Apr}:  conf = 0.905, sup = 0.088
# {Not Arrested, Day of Month 8} ---> {Apr}:  conf = 0.988, sup = 0.071
# {Day of Month 9, Not Arrested} ---> {2006}:  conf = 0.996, sup = 0.073
# {Day of Month 12, Not Domestic} ---> {2006}:  conf = 0.994, sup = 0.07
# {Day of Month 12, Not Arrested} ---> {2006}:  conf = 0.994, sup = 0.064
# {Day of Month 11, Not Domestic} ---> {2006}:  conf = 0.991, sup = 0.078
# {Day of Month 11, Not Arrested} ---> {2006}:  conf = 0.988, sup = 0.073
# {Day of Month 7, Not Domestic} ---> {Apr}:  conf = 0.942, sup = 0.083
# {Day of Month 7, Apr} ---> {2006}:  conf = 1.0, sup = 0.096
# {2006, Day of Month 7} ---> {Apr}:  conf = 0.95, sup = 0.096
# {Day of Month 7} ---> {2006, Apr}:  conf = 0.948, sup = 0.096
# {Day of Month 7, Not Arrested} ---> {Apr}:  conf = 0.969, sup = 0.077
# {Day of Month 10, Not Domestic} ---> {2006}:  conf = 0.99, sup = 0.078
# {Not Arrested, Day of Month 10} ---> {2006}:  conf = 0.989, sup = 0.074
# {Day of Month 13, Not Arrested} ---> {2006}:  conf = 0.992, sup = 0.053
# {Day of Month 9, Not Domestic} ---> {2006}:  conf = 0.996, sup = 0.079
# {Day of Month 7, Not Domestic} ---> {2006}:  conf = 0.997, sup = 0.088
# {Day of Month 7, Not Arrested} ---> {2006}:  conf = 0.996, sup = 0.08
# {APARTMENT, Not Arrested} ---> {2006}:  conf = 0.989, sup = 0.079
# {APARTMENT, Apr} ---> {2006}:  conf = 1.0, sup = 0.092
# {APARTMENT, 2006} ---> {Apr}:  conf = 0.921, sup = 0.092
# {APARTMENT} ---> {2006, Apr}:  conf = 0.911, sup = 0.092
# {APARTMENT, Not Arrested} ---> {Apr}:  conf = 0.916, sup = 0.073
# {District 7.0, Apr} ---> {2006}:  conf = 1.0, sup = 0.064
# {Not Arrested, OTHER OFFENSE} ---> {2006}:  conf = 0.98, sup = 0.059
# {OTHER OFFENSE, Apr} ---> {2006}:  conf = 1.0, sup = 0.059
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.961, sup = 0.064
# {Not Arrested, TO VEHICLE} ---> {CRIMINAL DAMAGE}:  conf = 0.992, sup = 0.064
# {TO VEHICLE} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.939, sup = 0.064
# {TO VEHICLE, Not Domestic} ---> {CRIMINAL DAMAGE}:  conf = 0.975, sup = 0.063
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.939, sup = 0.063
# {TO VEHICLE} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.917, sup = 0.063
# {TO VEHICLE, Apr} ---> {Not Arrested}:  conf = 0.946, sup = 0.061
# {Not Arrested, TO VEHICLE} ---> {Apr}:  conf = 0.947, sup = 0.061
# {TO VEHICLE, Apr} ---> {Not Domestic}:  conf = 0.94, sup = 0.061
# {TO VEHICLE, Not Domestic} ---> {Apr}:  conf = 0.947, sup = 0.061
# {TO VEHICLE, Apr} ---> {CRIMINAL DAMAGE}:  conf = 0.98, sup = 0.063
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.951, sup = 0.063
# {TO VEHICLE} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.928, sup = 0.063
# {TO VEHICLE, Not Domestic} ---> {Not Arrested}:  conf = 0.944, sup = 0.061
# {Not Arrested, TO VEHICLE} ---> {Not Domestic}:  conf = 0.938, sup = 0.061
# {TO VEHICLE, Not Domestic} ---> {2006}:  conf = 0.989, sup = 0.064
# {2006, TO VEHICLE} ---> {Not Domestic}:  conf = 0.939, sup = 0.064
# {TO VEHICLE} ---> {2006, Not Domestic}:  conf = 0.93, sup = 0.064
# {Not Arrested, TO VEHICLE} ---> {2006}:  conf = 0.991, sup = 0.064
# {2006, TO VEHICLE} ---> {Not Arrested}:  conf = 0.947, sup = 0.064
# {TO VEHICLE} ---> {2006, Not Arrested}:  conf = 0.937, sup = 0.064
# {TO VEHICLE, Apr} ---> {2006}:  conf = 1.0, sup = 0.065
# {2006, TO VEHICLE} ---> {Apr}:  conf = 0.957, sup = 0.065
# {TO VEHICLE} ---> {2006, Apr}:  conf = 0.947, sup = 0.065
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.991, sup = 0.066
# {2006, TO VEHICLE} ---> {CRIMINAL DAMAGE}:  conf = 0.978, sup = 0.066
# {TO VEHICLE} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.968, sup = 0.066
# {TO PROPERTY, Apr} ---> {Not Arrested}:  conf = 0.919, sup = 0.052
# {Not Arrested, TO PROPERTY} ---> {Apr}:  conf = 0.956, sup = 0.052
# {TO PROPERTY, Apr} ---> {Not Domestic}:  conf = 0.905, sup = 0.052
# {TO PROPERTY, Not Domestic} ---> {Apr}:  conf = 0.954, sup = 0.052
# {TO PROPERTY, Not Domestic} ---> {Not Arrested}:  conf = 0.926, sup = 0.05
# {Not Arrested, TO PROPERTY} ---> {Not Domestic}:  conf = 0.914, sup = 0.05
# {TO PROPERTY, Not Domestic} ---> {2006}:  conf = 0.998, sup = 0.054
# {2006, TO PROPERTY} ---> {Not Domestic}:  conf = 0.909, sup = 0.054
# {TO PROPERTY} ---> {2006, Not Domestic}:  conf = 0.908, sup = 0.054
# {Not Arrested, TO PROPERTY} ---> {2006}:  conf = 0.998, sup = 0.055
# {2006, TO PROPERTY} ---> {Not Arrested}:  conf = 0.921, sup = 0.055
# {TO PROPERTY} ---> {2006, Not Arrested}:  conf = 0.919, sup = 0.055
# {TO PROPERTY, Apr} ---> {2006}:  conf = 1.0, sup = 0.057
# {2006, TO PROPERTY} ---> {Apr}:  conf = 0.96, sup = 0.057
# {TO PROPERTY} ---> {2006, Apr}:  conf = 0.958, sup = 0.057
# {CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.929, sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.951, sup = 0.124
# {CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.929, sup = 0.124
# {CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.951, sup = 0.124
# {Night, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.967, sup = 0.059
# {TO PROPERTY, Apr} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.057
# {TO PROPERTY, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.958, sup = 0.057
# {TO PROPERTY} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.958, sup = 0.057
# {TO PROPERTY, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.921, sup = 0.055
# {Not Arrested, TO PROPERTY} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.055
# {TO PROPERTY} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.921, sup = 0.055
# {Night, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.924, sup = 0.056
# {TO PROPERTY, Not Domestic} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.054
# {TO PROPERTY, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.909, sup = 0.054
# {TO PROPERTY} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.909, sup = 0.054
# {CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested}:  conf = 0.933, sup = 0.121
# {Not Arrested, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.933, sup = 0.121
# {Night, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.919, sup = 0.056
# {CRIMINAL DAMAGE, Not Domestic} ---> {2006}:  conf = 0.994, sup = 0.129
# {2006, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.931, sup = 0.129
# {CRIMINAL DAMAGE} ---> {2006, Not Domestic}:  conf = 0.926, sup = 0.129
# {Not Arrested, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.995, sup = 0.129
# {2006, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.932, sup = 0.129
# {CRIMINAL DAMAGE} ---> {2006, Not Arrested}:  conf = 0.926, sup = 0.129
# {Night, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.995, sup = 0.06
# {CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.133
# {2006, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.958, sup = 0.133
# {CRIMINAL DAMAGE} ---> {2006, Apr}:  conf = 0.953, sup = 0.133
# {TO PROPERTY, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.998, sup = 0.059
# {2006, TO PROPERTY} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.059
# {TO PROPERTY} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.998, sup = 0.059
# {STREET, Evening} ---> {2006}:  conf = 0.997, sup = 0.059
# {STREET, Evening} ---> {Not Domestic}:  conf = 0.934, sup = 0.055
# {RESIDENCE, Night} ---> {2006}:  conf = 0.965, sup = 0.055
# {Night, THEFT} ---> {2006}:  conf = 0.967, sup = 0.051
# {Night, THEFT} ---> {Not Domestic}:  conf = 0.966, sup = 0.051
# {Not Arrested, District 7.0} ---> {2006}:  conf = 0.992, sup = 0.061
# {District 11.0, Not Domestic} ---> {2006}:  conf = 0.95, sup = 0.055
# {STREET, Arrested} ---> {2006}:  conf = 0.986, sup = 0.071
# {STREET, Night} ---> {2006}:  conf = 0.986, sup = 0.109
# {STREET, Night} ---> {Not Domestic}:  conf = 0.939, sup = 0.104
# {STREET, Arrested} ---> {Not Domestic}:  conf = 0.944, sup = 0.068
# {Evening, Arrested} ---> {2006}:  conf = 0.997, sup = 0.06
# {Evening, Arrested} ---> {Not Domestic}:  conf = 0.912, sup = 0.055
# {Morning, Not Arrested} ---> {2006}:  conf = 0.979, sup = 0.171
# {THEFT, Morning} ---> {2006}:  conf = 0.979, sup = 0.057
# {STREET, Morning} ---> {2006}:  conf = 0.987, sup = 0.053
# {OVER $500, Not Domestic} ---> {THEFT}:  conf = 1.0, sup = 0.051
# {THEFT, OVER $500} ---> {Not Domestic}:  conf = 0.986, sup = 0.051
# {OVER $500} ---> {THEFT, Not Domestic}:  conf = 0.986, sup = 0.051
# {OVER $500, Not Domestic} ---> {2006}:  conf = 0.996, sup = 0.051
# {2006, OVER $500} ---> {Not Domestic}:  conf = 0.986, sup = 0.051
# {OVER $500} ---> {2006, Not Domestic}:  conf = 0.983, sup = 0.051
# {THEFT, OVER $500} ---> {2006}:  conf = 0.996, sup = 0.052
# {2006, OVER $500} ---> {THEFT}:  conf = 1.0, sup = 0.052
# {OVER $500} ---> {2006, THEFT}:  conf = 0.996, sup = 0.052
# {Not Arrested, Day of Month 6} ---> {Apr}:  conf = 0.977, sup = 0.069
# {Day of Month 6, Not Domestic} ---> {Apr}:  conf = 0.964, sup = 0.078
# {Day of Month 6, Not Domestic} ---> {2006}:  conf = 0.993, sup = 0.08
# {Not Arrested, Day of Month 6} ---> {2006}:  conf = 0.989, sup = 0.07
# {Day of Month 6, Apr} ---> {2006}:  conf = 1.0, sup = 0.089
# {2006, Day of Month 6} ---> {Apr}:  conf = 0.975, sup = 0.089
# {Day of Month 6} ---> {2006, Apr}:  conf = 0.966, sup = 0.089
# {THEFT, Morning} ---> {Not Domestic}:  conf = 0.976, sup = 0.057
# {Morning, THEFT} ---> {Not Arrested}:  conf = 0.901, sup = 0.052
# {Night, BATTERY} ---> {2006}:  conf = 0.983, sup = 0.081
# {SIDEWALK, Apr} ---> {2006}:  conf = 0.998, sup = 0.062
# {Night, BATTERY} ---> {Apr}:  conf = 0.958, sup = 0.079
# {Domestic, BATTERY} ---> {Apr}:  conf = 0.965, sup = 0.074
# {Domestic, Not Arrested} ---> {Apr}:  conf = 0.929, sup = 0.096
# {Domestic, Night} ---> {Apr}:  conf = 0.943, sup = 0.051
# {Domestic, Not Arrested} ---> {2006}:  conf = 0.986, sup = 0.102
# {Domestic, Night} ---> {2006}:  conf = 0.985, sup = 0.053
# {Domestic, BATTERY} ---> {2006}:  conf = 0.987, sup = 0.075
# {Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.12
# {Domestic, 2006} ---> {Apr}:  conf = 0.947, sup = 0.12
# {Domestic} ---> {2006, Apr}:  conf = 0.935, sup = 0.12
# {Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.071
# {Domestic, DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.069
# {Domestic, BATTERY} ---> {DOMESTIC BATTERY SIMPLE}:  conf = 0.908, sup = 0.069
# {DOMESTIC BATTERY SIMPLE, Apr} ---> {BATTERY}:  conf = 1.0, sup = 0.091
# {BATTERY, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.966, sup = 0.091
# {DOMESTIC BATTERY SIMPLE} ---> {BATTERY, Apr}:  conf = 0.966, sup = 0.091
# {Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.963, sup = 0.068
# {Domestic, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.963, sup = 0.067
# {Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.989, sup = 0.07
# {BATTERY, DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.99, sup = 0.094
# {2006, DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.094
# {DOMESTIC BATTERY SIMPLE} ---> {2006, BATTERY}:  conf = 0.99, sup = 0.094
# {DOMESTIC BATTERY SIMPLE, Apr} ---> {2006}:  conf = 0.999, sup = 0.091
# {2006, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.974, sup = 0.091
# {DOMESTIC BATTERY SIMPLE} ---> {2006, Apr}:  conf = 0.965, sup = 0.091
# {Domestic, DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.987, sup = 0.069
# {Night, Apr} ---> {2006}:  conf = 1.0, sup = 0.29
# {ASSAULT, Apr} ---> {2006}:  conf = 0.998, sup = 0.058
# {2006, ASSAULT} ---> {Apr}:  conf = 0.95, sup = 0.058
# {ASSAULT} ---> {2006, Apr}:  conf = 0.937, sup = 0.058
# {Night, Not Arrested} ---> {Apr}:  conf = 0.918, sup = 0.237
# {Not Arrested, Noon} ---> {2006}:  conf = 0.977, sup = 0.138
# {Noon, Apr} ---> {2006}:  conf = 0.998, sup = 0.157
# {District 8.0, Not Arrested} ---> {2006}:  conf = 0.995, sup = 0.057
# {District 8.0, Apr} ---> {2006}:  conf = 0.998, sup = 0.065
# {THEFT, Apr} ---> {Not Domestic}:  conf = 0.976, sup = 0.168
# {THEFT, Not Arrested} ---> {Not Domestic}:  conf = 0.971, sup = 0.166
# {THEFT, Not Domestic} ---> {2006}:  conf = 0.98, sup = 0.185
# {2006, THEFT} ---> {Not Domestic}:  conf = 0.973, sup = 0.185
# {THEFT} ---> {2006, Not Domestic}:  conf = 0.954, sup = 0.185
# {THEFT, Not Arrested} ---> {2006}:  conf = 0.978, sup = 0.167
# {THEFT, Apr} ---> {2006}:  conf = 0.999, sup = 0.172
# {2006, THEFT} ---> {Apr}:  conf = 0.905, sup = 0.172
# {STREET, Not Arrested} ---> {Apr}:  conf = 0.939, sup = 0.182
# {STREET, Apr} ---> {Not Domestic}:  conf = 0.917, sup = 0.194
# {STREET, Not Arrested} ---> {Not Domestic}:  conf = 0.924, sup = 0.179
# {STREET, Not Domestic} ---> {2006}:  conf = 0.987, sup = 0.244
# {STREET, 2006} ---> {Not Domestic}:  conf = 0.93, sup = 0.244
# {STREET} ---> {2006, Not Domestic}:  conf = 0.918, sup = 0.244
# {STREET, Not Arrested} ---> {2006}:  conf = 0.987, sup = 0.191
# {STREET, Apr} ---> {2006}:  conf = 0.999, sup = 0.211
# {$500 AND UNDER, Apr} ---> {THEFT}:  conf = 1.0, sup = 0.061
# {THEFT, $500 AND UNDER} ---> {Apr}:  conf = 0.934, sup = 0.061
# {$500 AND UNDER} ---> {THEFT, Apr}:  conf = 0.934, sup = 0.061
# {Not Arrested, $500 AND UNDER} ---> {THEFT}:  conf = 1.0, sup = 0.061
# {THEFT, $500 AND UNDER} ---> {Not Arrested}:  conf = 0.932, sup = 0.061
# {$500 AND UNDER} ---> {THEFT, Not Arrested}:  conf = 0.932, sup = 0.061
# {$500 AND UNDER, Apr} ---> {Not Arrested}:  conf = 0.929, sup = 0.056
# {Not Arrested, $500 AND UNDER} ---> {Apr}:  conf = 0.931, sup = 0.056
# {$500 AND UNDER, Not Domestic} ---> {THEFT}:  conf = 1.0, sup = 0.063
# {THEFT, $500 AND UNDER} ---> {Not Domestic}:  conf = 0.966, sup = 0.063
# {$500 AND UNDER} ---> {THEFT, Not Domestic}:  conf = 0.966, sup = 0.063
# {$500 AND UNDER, Not Domestic} ---> {Apr}:  conf = 0.935, sup = 0.059
# {$500 AND UNDER, Apr} ---> {Not Domestic}:  conf = 0.967, sup = 0.059
# {$500 AND UNDER} ---> {Not Domestic, Apr}:  conf = 0.903, sup = 0.059
# {$500 AND UNDER, Not Domestic} ---> {Not Arrested}:  conf = 0.935, sup = 0.059
# {Not Arrested, $500 AND UNDER} ---> {Not Domestic}:  conf = 0.969, sup = 0.059
# {$500 AND UNDER} ---> {Not Arrested, Not Domestic}:  conf = 0.903, sup = 0.059
# {THEFT, $500 AND UNDER} ---> {2006}:  conf = 0.988, sup = 0.064
# {2006, $500 AND UNDER} ---> {THEFT}:  conf = 1.0, sup = 0.064
# {$500 AND UNDER} ---> {2006, THEFT}:  conf = 0.988, sup = 0.064
# {$500 AND UNDER, Apr} ---> {2006}:  conf = 1.0, sup = 0.061
# {2006, $500 AND UNDER} ---> {Apr}:  conf = 0.945, sup = 0.061
# {$500 AND UNDER} ---> {2006, Apr}:  conf = 0.934, sup = 0.061
# {Not Arrested, $500 AND UNDER} ---> {2006}:  conf = 0.987, sup = 0.06
# {2006, $500 AND UNDER} ---> {Not Arrested}:  conf = 0.931, sup = 0.06
# {$500 AND UNDER} ---> {2006, Not Arrested}:  conf = 0.92, sup = 0.06
# {$500 AND UNDER, Not Domestic} ---> {2006}:  conf = 0.987, sup = 0.062
# {2006, $500 AND UNDER} ---> {Not Domestic}:  conf = 0.966, sup = 0.062
# {$500 AND UNDER} ---> {2006, Not Domestic}:  conf = 0.954, sup = 0.062
# {District 8.0, Not Arrested} ---> {Apr}:  conf = 0.943, sup = 0.054
# {Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.158
# {Morning, Arrested} ---> {Not Domestic}:  conf = 0.903, sup = 0.055
# {Morning, Not Domestic} ---> {2006}:  conf = 0.981, sup = 0.204
# {Morning, Arrested} ---> {2006}:  conf = 0.993, sup = 0.061
# {Morning, Apr} ---> {2006}:  conf = 0.999, sup = 0.189
# {Arrested, Mar} ---> {Not Domestic}:  conf = 0.988, sup = 0.05
# {Mar, Not Domestic} ---> {2006}:  conf = 0.996, sup = 0.09
# {2006, Mar} ---> {Not Domestic}:  conf = 0.947, sup = 0.09
# {Mar} ---> {2006, Not Domestic}:  conf = 0.943, sup = 0.09
# {Arrested, Mar} ---> {2006}:  conf = 0.996, sup = 0.051
# {District 7.0, Not Domestic} ---> {2006}:  conf = 0.99, sup = 0.062
# {APARTMENT, Not Domestic} ---> {2006}:  conf = 0.986, sup = 0.062
# {Night, Arrested} ---> {2006}:  conf = 0.992, sup = 0.102
# {District 8.0, Not Domestic} ---> {2006}:  conf = 0.994, sup = 0.065
# {Not Arrested, SIMPLE} ---> {Not Domestic}:  conf = 0.905, sup = 0.086
# {SIMPLE, Not Domestic} ---> {2006}:  conf = 0.983, sup = 0.104
# {2006, SIMPLE} ---> {Not Domestic}:  conf = 0.908, sup = 0.104
# {Not Arrested, SIMPLE} ---> {2006}:  conf = 0.982, sup = 0.093
# {RESIDENCE, Not Domestic} ---> {2006}:  conf = 0.97, sup = 0.111
# {RESIDENCE, Not Arrested} ---> {2006}:  conf = 0.973, sup = 0.138
# {Evening, Not Domestic} ---> {2006}:  conf = 0.989, sup = 0.187
# {Not Arrested, Evening} ---> {2006}:  conf = 0.987, sup = 0.15
# {BATTERY, SIMPLE} ---> {Apr}:  conf = 0.94, sup = 0.07
# {BATTERY, SIMPLE} ---> {Not Domestic}:  conf = 0.981, sup = 0.072
# {BATTERY, Not Domestic} ---> {2006}:  conf = 0.984, sup = 0.124
# {Not Arrested, BATTERY} ---> {2006}:  conf = 0.982, sup = 0.153
# {BATTERY, SIMPLE} ---> {2006}:  conf = 0.984, sup = 0.073
# {Not Arrested, SIMPLE} ---> {Apr}:  conf = 0.931, sup = 0.088
# {Not Arrested, Evening} ---> {Apr}:  conf = 0.93, sup = 0.142
# {Not Arrested, BATTERY} ---> {Apr}:  conf = 0.944, sup = 0.147
# {SIMPLE, Apr} ---> {Not Domestic}:  conf = 0.909, sup = 0.099
# {SIMPLE, Not Domestic} ---> {Apr}:  conf = 0.938, sup = 0.099
# {BATTERY, Not Domestic} ---> {Apr}:  conf = 0.942, sup = 0.119
# {Apr, Not Domestic} ---> {2006}:  conf = 0.999, sup = 0.693
# {Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.655
# {2006, Not Arrested} ---> {Apr}:  conf = 0.92, sup = 0.655
# {Not Arrested} ---> {2006, Apr}:  conf = 0.902, sup = 0.655
# {SIMPLE, Apr} ---> {2006}:  conf = 0.999, sup = 0.109
# {2006, SIMPLE} ---> {Apr}:  conf = 0.953, sup = 0.109
# {SIMPLE} ---> {2006, Apr}:  conf = 0.938, sup = 0.109
# {RESIDENCE, Apr} ---> {2006}:  conf = 0.999, sup = 0.14
# {Evening, Apr} ---> {2006}:  conf = 1.0, sup = 0.178
# {BATTERY, Apr} ---> {2006}:  conf = 0.999, sup = 0.193
# {2006, BATTERY} ---> {Apr}:  conf = 0.964, sup = 0.193
# {BATTERY} ---> {2006, Apr}:  conf = 0.95, sup = 0.193
# {Not Arrested, Not Domestic} ---> {2006}:  conf = 0.98, sup = 0.611
# {Night, Not Domestic} ---> {2006}:  conf = 0.983, sup = 0.301
# {Night, Not Arrested} ---> {2006}:  conf = 0.98, sup = 0.253
# {Day of Month 8, Not Domestic} ---> {2006}:  conf = 0.995, sup = 0.084
# {Not Arrested, Day of Month 8} ---> {2006}:  conf = 0.994, sup = 0.072
# {SIDEWALK, Arrested} ---> {Not Domestic}:  conf = 0.964, sup = 0.051
# {SIDEWALK, Not Domestic} ---> {2006}:  conf = 0.997, sup = 0.09
# {2006, SIDEWALK} ---> {Not Domestic}:  conf = 0.91, sup = 0.09
# {SIDEWALK} ---> {2006, Not Domestic}:  conf = 0.908, sup = 0.09
# {Noon, Not Domestic} ---> {2006}:  conf = 0.978, sup = 0.164
# {NARCOTICS, Feb} ---> {Not Domestic}:  conf = 1.0, sup = 0.056
# {NARCOTICS, Not Domestic} ---> {Arrested}:  conf = 0.998, sup = 0.1
# {NARCOTICS, Arrested} ---> {Not Domestic}:  conf = 1.0, sup = 0.1
# {NARCOTICS} ---> {Arrested, Not Domestic}:  conf = 0.998, sup = 0.1
# {NARCOTICS, Not Domestic} ---> {2006}:  conf = 0.987, sup = 0.099
# {2006, NARCOTICS} ---> {Not Domestic}:  conf = 1.0, sup = 0.099
# {NARCOTICS} ---> {2006, Not Domestic}:  conf = 0.987, sup = 0.099
# {Feb, Not Domestic} ---> {Arrested}:  conf = 0.929, sup = 0.062
# {Feb, Arrested} ---> {Not Domestic}:  conf = 0.997, sup = 0.062
# {Feb} ---> {Arrested, Not Domestic}:  conf = 0.917, sup = 0.062
# {NARCOTICS, Feb} ---> {Arrested}:  conf = 1.0, sup = 0.056
# {Feb, Not Domestic} ---> {2006}:  conf = 0.997, sup = 0.066
# {2006, Feb} ---> {Not Domestic}:  conf = 0.987, sup = 0.066
# {Feb} ---> {2006, Not Domestic}:  conf = 0.984, sup = 0.066
# {NARCOTICS, Feb} ---> {2006}:  conf = 0.998, sup = 0.055
# {SIDEWALK, Arrested} ---> {2006}:  conf = 0.996, sup = 0.053
# {Arrested, Not Domestic} ---> {2006}:  conf = 0.992, sup = 0.246
# {2006, Arrested} ---> {Not Domestic}:  conf = 0.905, sup = 0.246
# {NARCOTICS, Arrested} ---> {2006}:  conf = 0.988, sup = 0.099
# {2006, NARCOTICS} ---> {Arrested}:  conf = 0.999, sup = 0.099
# {NARCOTICS} ---> {2006, Arrested}:  conf = 0.986, sup = 0.099
# {Arrested, Feb} ---> {2006}:  conf = 0.998, sup = 0.062
# {2006, Feb} ---> {Arrested}:  conf = 0.921, sup = 0.062
# {Feb} ---> {2006, Arrested}:  conf = 0.919, sup = 0.062
# {Day of Month 13, Not Arrested, Apr} ---> {2006}:  conf = 1.0, sup = 0.051
# {Day of Month 13, 2006, Not Arrested} ---> {Apr}:  conf = 0.974, sup = 0.051
# {Day of Month 13, Not Arrested} ---> {2006, Apr}:  conf = 0.966, sup = 0.051
# {Day of Month 13, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.054
# {Day of Month 13, 2006, Not Domestic} ---> {Apr}:  conf = 0.925, sup = 0.054
# {Day of Month 13, Not Domestic} ---> {2006, Apr}:  conf = 0.919, sup = 0.054
# {Not Arrested, Day of Month 12, Not Domestic} ---> {Apr}:  conf = 0.984, sup = 0.055
# {Not Arrested, Day of Month 12, Apr} ---> {2006}:  conf = 0.997, sup = 0.063
# {2006, Not Arrested, Day of Month 12} ---> {Apr}:  conf = 0.988, sup = 0.063
# {Not Arrested, Day of Month 12} ---> {2006, Apr}:  conf = 0.981, sup = 0.063
# {Day of Month 12, Not Domestic, Apr} ---> {2006}:  conf = 0.997, sup = 0.068
# {2006, Day of Month 12, Not Domestic} ---> {Apr}:  conf = 0.976, sup = 0.068
# {Day of Month 12, Not Domestic} ---> {2006, Apr}:  conf = 0.97, sup = 0.068
# {Day of Month 11, Not Arrested, Apr} ---> {2006}:  conf = 0.997, sup = 0.071
# {2006, Day of Month 11, Not Arrested} ---> {Apr}:  conf = 0.985, sup = 0.071
# {Day of Month 11, Not Arrested} ---> {2006, Apr}:  conf = 0.973, sup = 0.071
# {Day of Month 11, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.976, sup = 0.061
# {Day of Month 11, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.076
# {2006, Day of Month 11, Not Domestic} ---> {Apr}:  conf = 0.971, sup = 0.076
# {Day of Month 11, Not Domestic} ---> {2006, Apr}:  conf = 0.962, sup = 0.076
# {Not Arrested, Day of Month 10, Not Domestic} ---> {Apr}:  conf = 0.974, sup = 0.063
# {Not Arrested, Day of Month 10, Apr} ---> {2006}:  conf = 1.0, sup = 0.073
# {2006, Not Arrested, Day of Month 10} ---> {Apr}:  conf = 0.985, sup = 0.073
# {Not Arrested, Day of Month 10} ---> {2006, Apr}:  conf = 0.975, sup = 0.073
# {Not Domestic, Day of Month 10, Apr} ---> {2006}:  conf = 1.0, sup = 0.076
# {2006, Day of Month 10, Not Domestic} ---> {Apr}:  conf = 0.974, sup = 0.076
# {Day of Month 10, Not Domestic} ---> {2006, Apr}:  conf = 0.964, sup = 0.076
# {Day of Month 9, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.995, sup = 0.061
# {Day of Month 9, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.98, sup = 0.06
# {Day of Month 9, Not Arrested, Apr} ---> {2006}:  conf = 1.0, sup = 0.072
# {Day of Month 9, 2006, Not Arrested} ---> {Apr}:  conf = 0.985, sup = 0.072
# {Day of Month 9, Not Arrested} ---> {2006, Apr}:  conf = 0.981, sup = 0.072
# {Day of Month 9, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.074
# {Day of Month 9, 2006, Not Domestic} ---> {Apr}:  conf = 0.938, sup = 0.074
# {Day of Month 9, Not Domestic} ---> {2006, Apr}:  conf = 0.934, sup = 0.074
# {Not Arrested, Day of Month 8, Not Domestic} ---> {Apr}:  conf = 0.989, sup = 0.061
# {Not Arrested, Day of Month 8, Apr} ---> {2006}:  conf = 1.0, sup = 0.071
# {2006, Not Arrested, Day of Month 8} ---> {Apr}:  conf = 0.993, sup = 0.071
# {Not Arrested, Day of Month 8} ---> {2006, Apr}:  conf = 0.988, sup = 0.071
# {Not Domestic, Day of Month 8, Apr} ---> {2006}:  conf = 1.0, sup = 0.075
# {Not Arrested, Day of Month 12, Not Domestic} ---> {2006}:  conf = 0.993, sup = 0.055
# {Day of Month 11, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.989, sup = 0.062
# {Day of Month 7, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.083
# {2006, Day of Month 7, Not Domestic} ---> {Apr}:  conf = 0.945, sup = 0.083
# {Day of Month 7, Not Domestic} ---> {2006, Apr}:  conf = 0.942, sup = 0.083
# {Day of Month 7, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.967, sup = 0.067
# {Day of Month 7, Not Arrested, Apr} ---> {2006}:  conf = 1.0, sup = 0.077
# {2006, Day of Month 7, Not Arrested} ---> {Apr}:  conf = 0.972, sup = 0.077
# {Day of Month 7, Not Arrested} ---> {2006, Apr}:  conf = 0.969, sup = 0.077
# {Not Arrested, Day of Month 10, Not Domestic} ---> {2006}:  conf = 0.988, sup = 0.064
# {Night, Arrested, Apr} ---> {2006}:  conf = 1.0, sup = 0.053
# {Day of Month 7, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.996, sup = 0.069
# {APARTMENT, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.056
# {APARTMENT, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.984, sup = 0.05
# {APARTMENT, Not Arrested, Apr} ---> {2006}:  conf = 1.0, sup = 0.073
# {APARTMENT, 2006, Not Arrested} ---> {Apr}:  conf = 0.927, sup = 0.073
# {APARTMENT, Not Arrested} ---> {2006, Apr}:  conf = 0.916, sup = 0.073
# {Not Arrested, District 7.0, Apr} ---> {2006}:  conf = 1.0, sup = 0.054
# {Not Arrested, OTHER OFFENSE, Apr} ---> {2006}:  conf = 1.0, sup = 0.051
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.991, sup = 0.064
# {2006, TO VEHICLE, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.961, sup = 0.064
# {2006, Not Arrested, TO VEHICLE} ---> {CRIMINAL DAMAGE}:  conf = 0.992, sup = 0.064
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {2006, Not Arrested}:  conf = 0.952, sup = 0.064
# {Not Arrested, TO VEHICLE} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.983, sup = 0.064
# {2006, TO VEHICLE} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.939, sup = 0.064
# {TO VEHICLE} ---> {2006, Not Arrested, CRIMINAL DAMAGE}:  conf = 0.93, sup = 0.064
# {TO VEHICLE, CRIMINAL DAMAGE, Not Domestic} ---> {2006}:  conf = 0.99, sup = 0.062
# {2006, TO VEHICLE, Not Domestic} ---> {CRIMINAL DAMAGE}:  conf = 0.976, sup = 0.062
# {2006, TO VEHICLE, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.938, sup = 0.062
# {TO VEHICLE, Not Domestic} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.966, sup = 0.062
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {2006, Not Domestic}:  conf = 0.93, sup = 0.062
# {2006, TO VEHICLE} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.917, sup = 0.062
# {TO VEHICLE} ---> {2006, CRIMINAL DAMAGE, Not Domestic}:  conf = 0.908, sup = 0.062
# {Not Arrested, TO VEHICLE, Apr} ---> {2006}:  conf = 1.0, sup = 0.061
# {2006, TO VEHICLE, Apr} ---> {Not Arrested}:  conf = 0.946, sup = 0.061
# {2006, Not Arrested, TO VEHICLE} ---> {Apr}:  conf = 0.956, sup = 0.061
# {TO VEHICLE, Apr} ---> {2006, Not Arrested}:  conf = 0.946, sup = 0.061
# {Not Arrested, TO VEHICLE} ---> {2006, Apr}:  conf = 0.947, sup = 0.061
# {2006, TO VEHICLE} ---> {Not Arrested, Apr}:  conf = 0.905, sup = 0.061
# {Not Domestic, TO VEHICLE, Apr} ---> {2006}:  conf = 1.0, sup = 0.061
# {2006, TO VEHICLE, Not Domestic} ---> {Apr}:  conf = 0.957, sup = 0.061
# {2006, TO VEHICLE, Apr} ---> {Not Domestic}:  conf = 0.94, sup = 0.061
# {TO VEHICLE, Not Domestic} ---> {2006, Apr}:  conf = 0.947, sup = 0.061
# {TO VEHICLE, Apr} ---> {2006, Not Domestic}:  conf = 0.94, sup = 0.061
# {TO VEHICLE, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.063
# {2006, TO VEHICLE, Apr} ---> {CRIMINAL DAMAGE}:  conf = 0.98, sup = 0.063
# {2006, TO VEHICLE, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.959, sup = 0.063
# {TO VEHICLE, Apr} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.98, sup = 0.063
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {2006, Apr}:  conf = 0.951, sup = 0.063
# {2006, TO VEHICLE} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.938, sup = 0.063
# {TO VEHICLE} ---> {2006, CRIMINAL DAMAGE, Apr}:  conf = 0.928, sup = 0.063
# {Not Arrested, TO VEHICLE, Not Domestic} ---> {2006}:  conf = 0.99, sup = 0.06
# {2006, TO VEHICLE, Not Domestic} ---> {Not Arrested}:  conf = 0.945, sup = 0.06
# {2006, Not Arrested, TO VEHICLE} ---> {Not Domestic}:  conf = 0.938, sup = 0.06
# {TO VEHICLE, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.935, sup = 0.06
# {Not Arrested, TO VEHICLE} ---> {2006, Not Domestic}:  conf = 0.929, sup = 0.06
# {Not Domestic, TO VEHICLE, Apr} ---> {CRIMINAL DAMAGE}:  conf = 0.979, sup = 0.059
# {TO VEHICLE, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.95, sup = 0.059
# {TO VEHICLE, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.938, sup = 0.059
# {TO VEHICLE, Not Domestic} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.927, sup = 0.059
# {TO VEHICLE, Apr} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.92, sup = 0.059
# {TO VEHICLE, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.959, sup = 0.061
# {Not Arrested, TO VEHICLE, Apr} ---> {CRIMINAL DAMAGE}:  conf = 0.993, sup = 0.061
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.949, sup = 0.061
# {TO VEHICLE, Apr} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.94, sup = 0.061
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {Not Arrested, Apr}:  conf = 0.912, sup = 0.061
# {Not Arrested, TO VEHICLE} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.941, sup = 0.061
# {Not Domestic, TO VEHICLE, Apr} ---> {Not Arrested}:  conf = 0.944, sup = 0.057
# {Not Arrested, TO VEHICLE, Not Domestic} ---> {Apr}:  conf = 0.947, sup = 0.057
# {Not Arrested, TO VEHICLE, Apr} ---> {Not Domestic}:  conf = 0.938, sup = 0.057
# {TO VEHICLE, CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested}:  conf = 0.96, sup = 0.06
# {Not Arrested, TO VEHICLE, Not Domestic} ---> {CRIMINAL DAMAGE}:  conf = 0.992, sup = 0.06
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.938, sup = 0.06
# {TO VEHICLE, Not Domestic} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.936, sup = 0.06
# {TO VEHICLE, CRIMINAL DAMAGE} ---> {Not Arrested, Not Domestic}:  conf = 0.901, sup = 0.06
# {Not Arrested, TO VEHICLE} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.93, sup = 0.06
# {Night, STREET, Apr} ---> {2006}:  conf = 1.0, sup = 0.084
# {Night, Not Arrested, STREET} ---> {2006}:  conf = 0.985, sup = 0.077
# {Night, Not Arrested, STREET} ---> {Not Domestic}:  conf = 0.93, sup = 0.073
# {Night, STREET, Apr} ---> {Not Domestic}:  conf = 0.923, sup = 0.078
# {Night, Not Arrested, STREET} ---> {Apr}:  conf = 0.941, sup = 0.074
# {Not Arrested, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.124
# {2006, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.929, sup = 0.124
# {2006, Not Arrested, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.956, sup = 0.124
# {CRIMINAL DAMAGE, Apr} ---> {2006, Not Arrested}:  conf = 0.929, sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE} ---> {2006, Apr}:  conf = 0.951, sup = 0.124
# {Not Domestic, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.124
# {2006, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.957, sup = 0.124
# {2006, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.929, sup = 0.124
# {CRIMINAL DAMAGE, Not Domestic} ---> {2006, Apr}:  conf = 0.951, sup = 0.124
# {CRIMINAL DAMAGE, Apr} ---> {2006, Not Domestic}:  conf = 0.929, sup = 0.124
# {Night, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.059
# {2006, Night, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.972, sup = 0.059
# {Night, CRIMINAL DAMAGE} ---> {2006, Apr}:  conf = 0.967, sup = 0.059
# {Not Arrested, TO PROPERTY, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.998, sup = 0.055
# {2006, TO PROPERTY, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.921, sup = 0.055
# {2006, Not Arrested, TO PROPERTY} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.055
# {TO PROPERTY, CRIMINAL DAMAGE} ---> {2006, Not Arrested}:  conf = 0.919, sup = 0.055
# {Not Arrested, TO PROPERTY} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.998, sup = 0.055
# {2006, TO PROPERTY} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.921, sup = 0.055
# {TO PROPERTY} ---> {2006, Not Arrested, CRIMINAL DAMAGE}:  conf = 0.919, sup = 0.055
# {Night, Not Arrested, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.996, sup = 0.056
# {2006, Night, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.925, sup = 0.056
# {Night, CRIMINAL DAMAGE} ---> {2006, Not Arrested}:  conf = 0.921, sup = 0.056
# {TO PROPERTY, CRIMINAL DAMAGE, Not Domestic} ---> {2006}:  conf = 0.998, sup = 0.054
# {2006, TO PROPERTY, Not Domestic} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.054
# {2006, TO PROPERTY, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.909, sup = 0.054
# {TO PROPERTY, Not Domestic} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.998, sup = 0.054
# {TO PROPERTY, CRIMINAL DAMAGE} ---> {2006, Not Domestic}:  conf = 0.908, sup = 0.054
# {2006, TO PROPERTY} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.909, sup = 0.054
# {TO PROPERTY} ---> {2006, CRIMINAL DAMAGE, Not Domestic}:  conf = 0.908, sup = 0.054
# {Night, CRIMINAL DAMAGE, Not Domestic} ---> {2006}:  conf = 0.995, sup = 0.055
# {2006, Night, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.919, sup = 0.055
# {Night, CRIMINAL DAMAGE} ---> {2006, Not Domestic}:  conf = 0.914, sup = 0.055
# {Not Arrested, CRIMINAL DAMAGE, Not Domestic} ---> {2006}:  conf = 0.994, sup = 0.121
# {2006, CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested}:  conf = 0.933, sup = 0.121
# {2006, Not Arrested, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.933, sup = 0.121
# {CRIMINAL DAMAGE, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.928, sup = 0.121
# {Not Arrested, CRIMINAL DAMAGE} ---> {2006, Not Domestic}:  conf = 0.928, sup = 0.121
# {Night, CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested}:  conf = 0.926, sup = 0.052
# {Night, Not Arrested, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.921, sup = 0.052
# {TO PROPERTY, CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested}:  conf = 0.926, sup = 0.05
# {Not Arrested, TO PROPERTY, Not Domestic} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.05
# {Not Arrested, TO PROPERTY, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.914, sup = 0.05
# {TO PROPERTY, Not Domestic} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.926, sup = 0.05
# {Not Arrested, TO PROPERTY} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.914, sup = 0.05
# {Not Domestic, TO PROPERTY, Apr} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.052
# {TO PROPERTY, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.954, sup = 0.052
# {TO PROPERTY, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.905, sup = 0.052
# {TO PROPERTY, Not Domestic} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.954, sup = 0.052
# {TO PROPERTY, Apr} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.905, sup = 0.052
# {Night, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.964, sup = 0.054
# {Night, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.916, sup = 0.054
# {TO PROPERTY, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.919, sup = 0.052
# {Not Arrested, TO PROPERTY, Apr} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.052
# {Not Arrested, TO PROPERTY, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.956, sup = 0.052
# {TO PROPERTY, Apr} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.919, sup = 0.052
# {Not Arrested, TO PROPERTY} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.956, sup = 0.052
# {Night, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.923, sup = 0.054
# {Night, Not Arrested, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.966, sup = 0.054
# {Not Domestic, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.931, sup = 0.115
# {Not Arrested, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.949, sup = 0.115
# {Not Arrested, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.931, sup = 0.115
# {Not Arrested, TO PROPERTY, Apr} ---> {2006}:  conf = 1.0, sup = 0.052
# {2006, TO PROPERTY, Apr} ---> {Not Arrested}:  conf = 0.919, sup = 0.052
# {2006, Not Arrested, TO PROPERTY} ---> {Apr}:  conf = 0.958, sup = 0.052
# {TO PROPERTY, Apr} ---> {2006, Not Arrested}:  conf = 0.919, sup = 0.052
# {Not Arrested, TO PROPERTY} ---> {2006, Apr}:  conf = 0.956, sup = 0.052
# {Not Domestic, TO PROPERTY, Apr} ---> {2006}:  conf = 1.0, sup = 0.052
# {2006, TO PROPERTY, Not Domestic} ---> {Apr}:  conf = 0.956, sup = 0.052
# {2006, TO PROPERTY, Apr} ---> {Not Domestic}:  conf = 0.905, sup = 0.052
# {TO PROPERTY, Not Domestic} ---> {2006, Apr}:  conf = 0.954, sup = 0.052
# {TO PROPERTY, Apr} ---> {2006, Not Domestic}:  conf = 0.905, sup = 0.052
# {TO PROPERTY, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.057
# {2006, TO PROPERTY, Apr} ---> {CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.057
# {2006, TO PROPERTY, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.96, sup = 0.057
# {TO PROPERTY, Apr} ---> {2006, CRIMINAL DAMAGE}:  conf = 1.0, sup = 0.057
# {TO PROPERTY, CRIMINAL DAMAGE} ---> {2006, Apr}:  conf = 0.958, sup = 0.057
# {2006, TO PROPERTY} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.96, sup = 0.057
# {TO PROPERTY} ---> {2006, CRIMINAL DAMAGE, Apr}:  conf = 0.958, sup = 0.057
# {Not Arrested, TO PROPERTY, Not Domestic} ---> {2006}:  conf = 0.998, sup = 0.05
# {2006, TO PROPERTY, Not Domestic} ---> {Not Arrested}:  conf = 0.926, sup = 0.05
# {2006, Not Arrested, TO PROPERTY} ---> {Not Domestic}:  conf = 0.914, sup = 0.05
# {TO PROPERTY, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.924, sup = 0.05
# {Not Arrested, TO PROPERTY} ---> {2006, Not Domestic}:  conf = 0.913, sup = 0.05
# {STREET, Evening, Not Domestic} ---> {2006}:  conf = 0.998, sup = 0.055
# {2006, Evening, STREET} ---> {Not Domestic}:  conf = 0.935, sup = 0.055
# {STREET, Evening} ---> {2006, Not Domestic}:  conf = 0.932, sup = 0.055
# {Night, STREET, Not Domestic} ---> {2006}:  conf = 0.987, sup = 0.103
# {2006, Night, STREET} ---> {Not Domestic}:  conf = 0.94, sup = 0.103
# {Night, STREET} ---> {2006, Not Domestic}:  conf = 0.927, sup = 0.103
# {STREET, Arrested, Not Domestic} ---> {2006}:  conf = 0.985, sup = 0.067
# {2006, Arrested, STREET} ---> {Not Domestic}:  conf = 0.944, sup = 0.067
# {STREET, Arrested} ---> {2006, Not Domestic}:  conf = 0.93, sup = 0.067
# {SIDEWALK, Not Domestic, Apr} ---> {2006}:  conf = 0.998, sup = 0.054
# {Evening, Arrested, Not Domestic} ---> {2006}:  conf = 0.996, sup = 0.055
# {2006, Evening, Arrested} ---> {Not Domestic}:  conf = 0.912, sup = 0.055
# {Evening, Arrested} ---> {2006, Not Domestic}:  conf = 0.909, sup = 0.055
# {Morning, Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.151
# {Morning, Not Arrested, THEFT} ---> {Not Domestic}:  conf = 0.975, sup = 0.051
# {Not Arrested, Day of Month 6, Apr} ---> {2006}:  conf = 1.0, sup = 0.069
# {2006, Not Arrested, Day of Month 6} ---> {Apr}:  conf = 0.988, sup = 0.069
# {Not Arrested, Day of Month 6} ---> {2006, Apr}:  conf = 0.977, sup = 0.069
# {Not Domestic, Day of Month 6, Apr} ---> {2006}:  conf = 1.0, sup = 0.078
# {2006, Day of Month 6, Not Domestic} ---> {Apr}:  conf = 0.971, sup = 0.078
# {Day of Month 6, Not Domestic} ---> {2006, Apr}:  conf = 0.964, sup = 0.078
# {Not Arrested, Day of Month 6, Not Domestic} ---> {2006}:  conf = 0.99, sup = 0.061
# {Not Arrested, Day of Month 6, Not Domestic} ---> {Apr}:  conf = 0.977, sup = 0.06
# {THEFT, Not Domestic, OVER $500} ---> {2006}:  conf = 0.996, sup = 0.051
# {2006, Not Domestic, OVER $500} ---> {THEFT}:  conf = 1.0, sup = 0.051
# {2006, THEFT, OVER $500} ---> {Not Domestic}:  conf = 0.986, sup = 0.051
# {Not Domestic, OVER $500} ---> {2006, THEFT}:  conf = 0.996, sup = 0.051
# {THEFT, OVER $500} ---> {2006, Not Domestic}:  conf = 0.983, sup = 0.051
# {2006, OVER $500} ---> {THEFT, Not Domestic}:  conf = 0.986, sup = 0.051
# {OVER $500} ---> {2006, THEFT, Not Domestic}:  conf = 0.983, sup = 0.051
# {THEFT, Morning, Not Domestic} ---> {2006}:  conf = 0.979, sup = 0.056
# {2006, THEFT, Morning} ---> {Not Domestic}:  conf = 0.975, sup = 0.056
# {THEFT, Morning} ---> {2006, Not Domestic}:  conf = 0.955, sup = 0.056
# {Morning, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.977, sup = 0.149
# {Morning, Not Arrested, THEFT} ---> {2006}:  conf = 0.977, sup = 0.051
# {Night, BATTERY, Apr} ---> {2006}:  conf = 0.999, sup = 0.078
# {2006, BATTERY, Night} ---> {Apr}:  conf = 0.974, sup = 0.078
# {Night, BATTERY} ---> {2006, Apr}:  conf = 0.957, sup = 0.078
# {BATTERY, DOMESTIC BATTERY SIMPLE, Apr} ---> {2006}:  conf = 0.999, sup = 0.091
# {2006, DOMESTIC BATTERY SIMPLE, Apr} ---> {BATTERY}:  conf = 1.0, sup = 0.091
# {2006, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.974, sup = 0.091
# {DOMESTIC BATTERY SIMPLE, Apr} ---> {2006, BATTERY}:  conf = 0.999, sup = 0.091
# {BATTERY, DOMESTIC BATTERY SIMPLE} ---> {2006, Apr}:  conf = 0.965, sup = 0.091
# {2006, DOMESTIC BATTERY SIMPLE} ---> {BATTERY, Apr}:  conf = 0.974, sup = 0.091
# {DOMESTIC BATTERY SIMPLE} ---> {2006, BATTERY, Apr}:  conf = 0.965, sup = 0.091
# {Not Arrested, DOMESTIC BATTERY SIMPLE, Apr} ---> {2006}:  conf = 0.999, sup = 0.068
# {2006, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.973, sup = 0.068
# {Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {2006, Apr}:  conf = 0.962, sup = 0.068
# {Not Arrested, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.989, sup = 0.07
# {2006, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.07
# {Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {2006, BATTERY}:  conf = 0.989, sup = 0.07
# {Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.985, sup = 0.052
# {Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.958, sup = 0.05
# {Not Arrested, DOMESTIC BATTERY SIMPLE, Apr} ---> {BATTERY}:  conf = 1.0, sup = 0.068
# {Not Arrested, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.963, sup = 0.068
# {Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {BATTERY, Apr}:  conf = 0.963, sup = 0.068
# {Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.053
# {Domestic, Not Arrested, BATTERY} ---> {DOMESTIC BATTERY SIMPLE}:  conf = 0.915, sup = 0.053
# {Domestic, BATTERY, Apr} ---> {2006}:  conf = 0.999, sup = 0.074
# {Domestic, 2006, BATTERY} ---> {Apr}:  conf = 0.976, sup = 0.074
# {Domestic, BATTERY} ---> {2006, Apr}:  conf = 0.963, sup = 0.074
# {Domestic, Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.096
# {Domestic, 2006, Not Arrested} ---> {Apr}:  conf = 0.941, sup = 0.096
# {Domestic, Not Arrested} ---> {2006, Apr}:  conf = 0.928, sup = 0.096
# {Domestic, Night, Apr} ---> {2006}:  conf = 1.0, sup = 0.051
# {Domestic, 2006, Night} ---> {Apr}:  conf = 0.957, sup = 0.051
# {Domestic, Night} ---> {2006, Apr}:  conf = 0.943, sup = 0.051
# {Domestic, DOMESTIC BATTERY SIMPLE, Apr} ---> {2006}:  conf = 0.999, sup = 0.067
# {Domestic, 2006, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.974, sup = 0.067
# {Domestic, DOMESTIC BATTERY SIMPLE} ---> {2006, Apr}:  conf = 0.961, sup = 0.067
# {Domestic, Not Arrested, BATTERY} ---> {2006}:  conf = 0.984, sup = 0.057
# {Domestic, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.987, sup = 0.069
# {Domestic, 2006, DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.069
# {Domestic, 2006, BATTERY} ---> {DOMESTIC BATTERY SIMPLE}:  conf = 0.908, sup = 0.069
# {Domestic, DOMESTIC BATTERY SIMPLE} ---> {2006, BATTERY}:  conf = 0.987, sup = 0.069
# {Domestic, Not Arrested, BATTERY} ---> {Apr}:  conf = 0.96, sup = 0.055
# {Domestic, DOMESTIC BATTERY SIMPLE, Apr} ---> {BATTERY}:  conf = 1.0, sup = 0.067
# {Domestic, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.963, sup = 0.067
# ...
# {2006, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {BATTERY, Apr}:  conf = 0.973, sup = 0.068
# {Not Arrested, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {2006, Apr}:  conf = 0.962, sup = 0.068
# {Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {2006, BATTERY, Apr}:  conf = 0.962, sup = 0.068
# {2006, Domestic, DOMESTIC BATTERY SIMPLE, Apr} ---> {BATTERY}:  conf = 1.0, sup = 0.067
# {Domestic, BATTERY, DOMESTIC BATTERY SIMPLE, Apr} ---> {2006}:  conf = 0.999, sup = 0.067
# {2006, Domestic, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.974, sup = 0.067
# {2006, Domestic, BATTERY, Apr} ---> {DOMESTIC BATTERY SIMPLE}:  conf = 0.906, sup = 0.067
# {Domestic, DOMESTIC BATTERY SIMPLE, Apr} ---> {2006, BATTERY}:  conf = 0.999, sup = 0.067
# {2006, Domestic, DOMESTIC BATTERY SIMPLE} ---> {BATTERY, Apr}:  conf = 0.974, sup = 0.067
# {Domestic, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {2006, Apr}:  conf = 0.961, sup = 0.067
# {Domestic, BATTERY, Apr} ---> {2006, DOMESTIC BATTERY SIMPLE}:  conf = 0.905, sup = 0.067
# {Domestic, DOMESTIC BATTERY SIMPLE} ---> {2006, BATTERY, Apr}:  conf = 0.961, sup = 0.067
# {Night, Not Arrested, BATTERY, Apr} ---> {2006}:  conf = 0.998, sup = 0.06
# {Night, 2006, Not Arrested, BATTERY} ---> {Apr}:  conf = 0.974, sup = 0.06
# {Night, Not Arrested, BATTERY} ---> {2006, Apr}:  conf = 0.954, sup = 0.06
# {Night, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.197
# {Night, 2006, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.933, sup = 0.197
# {Night, Not Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.914, sup = 0.197
# {Not Domestic, Not Arrested, Noon, Apr} ---> {2006}:  conf = 1.0, sup = 0.106
# {2006, Not Arrested, Noon, Not Domestic} ---> {Apr}:  conf = 0.902, sup = 0.106
# {THEFT, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.146
# {2006, THEFT, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.9, sup = 0.146
# {2006, THEFT, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.973, sup = 0.146
# {THEFT, Not Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.973, sup = 0.146
# {STREET, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.168
# {STREET, 2006, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.951, sup = 0.168
# {STREET, 2006, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.925, sup = 0.168
# {STREET, Not Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.939, sup = 0.168
# {STREET, Not Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.925, sup = 0.168
# {THEFT, Not Domestic, $500 AND UNDER, Apr} ---> {Not Arrested}:  conf = 0.93, sup = 0.055
# {Not Arrested, Not Domestic, $500 AND UNDER, Apr} ---> {THEFT}:  conf = 1.0, sup = 0.055
# {THEFT, Not Arrested, $500 AND UNDER, Not Domestic} ---> {Apr}:  conf = 0.93, sup = 0.055
# {THEFT, Not Arrested, $500 AND UNDER, Apr} ---> {Not Domestic}:  conf = 0.968, sup = 0.055
# {Not Domestic, $500 AND UNDER, Apr} ---> {THEFT, Not Arrested}:  conf = 0.93, sup = 0.055
# {Not Arrested, $500 AND UNDER, Not Domestic} ---> {THEFT, Apr}:  conf = 0.93, sup = 0.055
# {Not Arrested, $500 AND UNDER, Apr} ---> {THEFT, Not Domestic}:  conf = 0.968, sup = 0.055
# {THEFT, Not Arrested, $500 AND UNDER} ---> {Not Domestic, Apr}:  conf = 0.901, sup = 0.055
# {Not Arrested, $500 AND UNDER} ---> {THEFT, Not Domestic, Apr}:  conf = 0.901, sup = 0.055
# {2006, THEFT, $500 AND UNDER, Apr} ---> {Not Arrested}:  conf = 0.929, sup = 0.056
# {THEFT, Not Arrested, $500 AND UNDER, Apr} ---> {2006}:  conf = 1.0, sup = 0.056
# {2006, Not Arrested, $500 AND UNDER, Apr} ---> {THEFT}:  conf = 1.0, sup = 0.056
# {2006, THEFT, Not Arrested, $500 AND UNDER} ---> {Apr}:  conf = 0.943, sup = 0.056
# {THEFT, $500 AND UNDER, Apr} ---> {2006, Not Arrested}:  conf = 0.929, sup = 0.056
# {2006, $500 AND UNDER, Apr} ---> {THEFT, Not Arrested}:  conf = 0.929, sup = 0.056
# {Not Arrested, $500 AND UNDER, Apr} ---> {2006, THEFT}:  conf = 1.0, sup = 0.056
# {THEFT, Not Arrested, $500 AND UNDER} ---> {2006, Apr}:  conf = 0.931, sup = 0.056
# {2006, Not Arrested, $500 AND UNDER} ---> {THEFT, Apr}:  conf = 0.943, sup = 0.056
# {$500 AND UNDER, Apr} ---> {2006, THEFT, Not Arrested}:  conf = 0.929, sup = 0.056
# {Not Arrested, $500 AND UNDER} ---> {2006, THEFT, Apr}:  conf = 0.931, sup = 0.056
# {THEFT, Not Domestic, $500 AND UNDER, Apr} ---> {2006}:  conf = 1.0, sup = 0.059
# {2006, Not Domestic, $500 AND UNDER, Apr} ---> {THEFT}:  conf = 1.0, sup = 0.059
# {2006, THEFT, $500 AND UNDER, Not Domestic} ---> {Apr}:  conf = 0.947, sup = 0.059
# {2006, THEFT, $500 AND UNDER, Apr} ---> {Not Domestic}:  conf = 0.967, sup = 0.059
# {Not Domestic, $500 AND UNDER, Apr} ---> {2006, THEFT}:  conf = 1.0, sup = 0.059
# {THEFT, $500 AND UNDER, Not Domestic} ---> {2006, Apr}:  conf = 0.935, sup = 0.059
# {THEFT, $500 AND UNDER, Apr} ---> {2006, Not Domestic}:  conf = 0.967, sup = 0.059
# {2006, $500 AND UNDER, Not Domestic} ---> {THEFT, Apr}:  conf = 0.947, sup = 0.059
# {2006, $500 AND UNDER, Apr} ---> {THEFT, Not Domestic}:  conf = 0.967, sup = 0.059
# {2006, THEFT, $500 AND UNDER} ---> {Not Domestic, Apr}:  conf = 0.914, sup = 0.059
# {$500 AND UNDER, Not Domestic} ---> {2006, THEFT, Apr}:  conf = 0.935, sup = 0.059
# {$500 AND UNDER, Apr} ---> {2006, THEFT, Not Domestic}:  conf = 0.967, sup = 0.059
# {THEFT, $500 AND UNDER} ---> {2006, Not Domestic, Apr}:  conf = 0.903, sup = 0.059
# {2006, $500 AND UNDER} ---> {THEFT, Not Domestic, Apr}:  conf = 0.914, sup = 0.059
# {$500 AND UNDER} ---> {2006, THEFT, Apr, Not Domestic}:  conf = 0.903, sup = 0.059
# {2006, Not Domestic, $500 AND UNDER, Apr} ---> {Not Arrested}:  conf = 0.93, sup = 0.055
# {Not Arrested, Not Domestic, $500 AND UNDER, Apr} ---> {2006}:  conf = 1.0, sup = 0.055
# {2006, Not Arrested, $500 AND UNDER, Not Domestic} ---> {Apr}:  conf = 0.943, sup = 0.055
# {2006, Not Arrested, $500 AND UNDER, Apr} ---> {Not Domestic}:  conf = 0.968, sup = 0.055
# {Not Domestic, $500 AND UNDER, Apr} ---> {2006, Not Arrested}:  conf = 0.93, sup = 0.055
# {Not Arrested, $500 AND UNDER, Not Domestic} ---> {2006, Apr}:  conf = 0.93, sup = 0.055
# {Not Arrested, $500 AND UNDER, Apr} ---> {2006, Not Domestic}:  conf = 0.968, sup = 0.055
# {2006, Not Arrested, $500 AND UNDER} ---> {Not Domestic, Apr}:  conf = 0.913, sup = 0.055
# {Not Arrested, $500 AND UNDER} ---> {2006, Not Domestic, Apr}:  conf = 0.901, sup = 0.055
# {2006, THEFT, $500 AND UNDER, Not Domestic} ---> {Not Arrested}:  conf = 0.934, sup = 0.058
# {THEFT, Not Arrested, $500 AND UNDER, Not Domestic} ---> {2006}:  conf = 0.986, sup = 0.058
# {2006, Not Arrested, $500 AND UNDER, Not Domestic} ---> {THEFT}:  conf = 1.0, sup = 0.058
# {2006, THEFT, Not Arrested, $500 AND UNDER} ---> {Not Domestic}:  conf = 0.968, sup = 0.058
# {THEFT, $500 AND UNDER, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.922, sup = 0.058
# {2006, $500 AND UNDER, Not Domestic} ---> {THEFT, Not Arrested}:  conf = 0.934, sup = 0.058
# {2006, THEFT, $500 AND UNDER} ---> {Not Arrested, Not Domestic}:  conf = 0.902, sup = 0.058
# {Not Arrested, $500 AND UNDER, Not Domestic} ---> {2006, THEFT}:  conf = 0.986, sup = 0.058
# {THEFT, Not Arrested, $500 AND UNDER} ---> {2006, Not Domestic}:  conf = 0.955, sup = 0.058
# {2006, Not Arrested, $500 AND UNDER} ---> {THEFT, Not Domestic}:  conf = 0.968, sup = 0.058
# {$500 AND UNDER, Not Domestic} ---> {2006, THEFT, Not Arrested}:  conf = 0.922, sup = 0.058
# {2006, $500 AND UNDER} ---> {THEFT, Not Arrested, Not Domestic}:  conf = 0.902, sup = 0.058
# {Not Arrested, $500 AND UNDER} ---> {2006, THEFT, Not Domestic}:  conf = 0.955, sup = 0.058
# {Not Arrested, BATTERY, SIMPLE, Not Domestic} ---> {2006}:  conf = 0.981, sup = 0.058
# {2006, Not Arrested, BATTERY, SIMPLE} ---> {Not Domestic}:  conf = 0.978, sup = 0.058
# {Not Arrested, BATTERY, SIMPLE} ---> {2006, Not Domestic}:  conf = 0.96, sup = 0.058
# {Not Arrested, BATTERY, SIMPLE, Not Domestic} ---> {Apr}:  conf = 0.932, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE, Apr} ---> {Not Domestic}:  conf = 0.977, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE} ---> {Not Domestic, Apr}:  conf = 0.912, sup = 0.055
# {Not Arrested, SIMPLE, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.08
# {2006, Not Arrested, SIMPLE, Not Domestic} ---> {Apr}:  conf = 0.949, sup = 0.08
# {2006, Not Arrested, SIMPLE, Apr} ---> {Not Domestic}:  conf = 0.905, sup = 0.08
# {Not Arrested, SIMPLE, Not Domestic} ---> {2006, Apr}:  conf = 0.93, sup = 0.08
# {Not Arrested, SIMPLE, Apr} ---> {2006, Not Domestic}:  conf = 0.904, sup = 0.08
# {RESIDENCE, 2006, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.902, sup = 0.086
# {RESIDENCE, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.086
# {RESIDENCE, Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.901, sup = 0.086
# {Not Arrested, Evening, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.125
# {2006, Not Arrested, Evening, Not Domestic} ---> {Apr}:  conf = 0.943, sup = 0.125
# {Not Arrested, Evening, Not Domestic} ---> {2006, Apr}:  conf = 0.931, sup = 0.125
# {Not Arrested, BATTERY, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.091
# {2006, Not Arrested, BATTERY, Not Domestic} ---> {Apr}:  conf = 0.952, sup = 0.091
# {Not Arrested, BATTERY, Not Domestic} ---> {2006, Apr}:  conf = 0.934, sup = 0.091
# {BATTERY, SIMPLE, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.068
# {2006, BATTERY, SIMPLE, Not Domestic} ---> {Apr}:  conf = 0.955, sup = 0.068
# {2006, BATTERY, SIMPLE, Apr} ---> {Not Domestic}:  conf = 0.98, sup = 0.068
# {BATTERY, SIMPLE, Not Domestic} ---> {2006, Apr}:  conf = 0.939, sup = 0.068
# {BATTERY, SIMPLE, Apr} ---> {2006, Not Domestic}:  conf = 0.98, sup = 0.068
# {2006, BATTERY, SIMPLE} ---> {Not Domestic, Apr}:  conf = 0.937, sup = 0.068
# {BATTERY, SIMPLE} ---> {2006, Not Domestic, Apr}:  conf = 0.922, sup = 0.068
# {Not Arrested, BATTERY, SIMPLE, Apr} ---> {2006}:  conf = 1.0, sup = 0.056
# {2006, Not Arrested, BATTERY, SIMPLE} ---> {Apr}:  conf = 0.951, sup = 0.056
# {Not Arrested, BATTERY, SIMPLE} ---> {2006, Apr}:  conf = 0.934, sup = 0.056
# {2006, NARCOTICS, Feb, Not Domestic} ---> {Arrested}:  conf = 1.0, sup = 0.055
# {NARCOTICS, Arrested, Feb, Not Domestic} ---> {2006}:  conf = 0.998, sup = 0.055
# {2006, NARCOTICS, Arrested, Feb} ---> {Not Domestic}:  conf = 1.0, sup = 0.055
# {NARCOTICS, Feb, Not Domestic} ---> {2006, Arrested}:  conf = 0.998, sup = 0.055
# {2006, NARCOTICS, Feb} ---> {Arrested, Not Domestic}:  conf = 1.0, sup = 0.055
# {NARCOTICS, Arrested, Feb} ---> {2006, Not Domestic}:  conf = 0.998, sup = 0.055
# {NARCOTICS, Feb} ---> {2006, Arrested, Not Domestic}:  conf = 0.998, sup = 0.055
# {TO VEHICLE, 2006, CRIMINAL DAMAGE, Apr, Not Domestic} ---> {Not Arrested}:  conf = 0.958, sup = 0.057
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE, Apr, Not Domestic} ---> {2006}:  conf = 1.0, sup = 0.057
# {Not Arrested, TO VEHICLE, 2006, Apr, Not Domestic} ---> {CRIMINAL DAMAGE}:  conf = 0.993, sup = 0.057
# {Not Arrested, TO VEHICLE, 2006, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.958, sup = 0.057
# {Not Arrested, TO VEHICLE, 2006, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.938, sup = 0.057
# {Not Domestic, TO VEHICLE, CRIMINAL DAMAGE, Apr} ---> {2006, Not Arrested}:  conf = 0.958, sup = 0.057
# {2006, Not Domestic, TO VEHICLE, Apr} ---> {Not Arrested, CRIMINAL DAMAGE}:  conf = 0.938, sup = 0.057
# {2006, TO VEHICLE, CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.919, sup = 0.057
# {Not Domestic, Not Arrested, TO VEHICLE, Apr} ---> {2006, CRIMINAL DAMAGE}:  conf = 0.993, sup = 0.057
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE, Not Domestic} ---> {2006, Apr}:  conf = 0.948, sup = 0.057
# {Not Arrested, TO VEHICLE, CRIMINAL DAMAGE, Apr} ---> {2006, Not Domestic}:  conf = 0.938, sup = 0.057
# {2006, Not Arrested, TO VEHICLE, Not Domestic} ---> {CRIMINAL DAMAGE, Apr}:  conf = 0.95, sup = 0.057
# {2006, Not Arrested, TO VEHICLE, Apr} ---> {CRIMINAL DAMAGE, Not Domestic}:  conf = 0.931, sup = 0.057
# {Not Domestic, TO VEHICLE, Apr} ---> {2006, Not Arrested, CRIMINAL DAMAGE}:  conf = 0.938, sup = 0.057
# {TO VEHICLE, CRIMINAL DAMAGE, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.911, sup = 0.057
# {Not Arrested, TO VEHICLE, Not Domestic} ---> {2006, CRIMINAL DAMAGE, Apr}:  conf = 0.941, sup = 0.057
# {Not Arrested, TO VEHICLE, Apr} ---> {2006, CRIMINAL DAMAGE, Not Domestic}:  conf = 0.931, sup = 0.057
# {Night, Not Arrested, STREET, Apr, Not Domestic} ---> {2006}:  conf = 1.0, sup = 0.069
# {Night, Not Arrested, STREET, 2006, Not Domestic} ---> {Apr}:  conf = 0.954, sup = 0.069
# {Night, Not Arrested, STREET, 2006, Apr} ---> {Not Domestic}:  conf = 0.93, sup = 0.069
# {Night, Not Arrested, STREET, Not Domestic} ---> {2006, Apr}:  conf = 0.941, sup = 0.069
# {Night, Not Arrested, STREET, Apr} ---> {2006, Not Domestic}:  conf = 0.93, sup = 0.069
# {Not Arrested, 2006, Domestic, Apr, DOMESTIC BATTERY SIMPLE} ---> {BATTERY}:  conf = 1.0, sup = 0.05
# {Not Arrested, BATTERY, Domestic, Apr, DOMESTIC BATTERY SIMPLE} ---> {2006}:  conf = 0.998, sup = 0.05
# {Not Arrested, BATTERY, 2006, Domestic, DOMESTIC BATTERY SIMPLE} ---> {Apr}:  conf = 0.971, sup = 0.05
# {Not Arrested, BATTERY, 2006, Domestic, Apr} ---> {DOMESTIC BATTERY SIMPLE}:  conf = 0.913, sup = 0.05
# {Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE, Apr} ---> {2006, BATTERY}:  conf = 0.998, sup = 0.05
# {2006, Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {BATTERY, Apr}:  conf = 0.971, sup = 0.05
# {Domestic, Not Arrested, BATTERY, DOMESTIC BATTERY SIMPLE} ---> {2006, Apr}:  conf = 0.956, sup = 0.05
# {Domestic, Not Arrested, BATTERY, Apr} ---> {2006, DOMESTIC BATTERY SIMPLE}:  conf = 0.911, sup = 0.05
# {Domestic, Not Arrested, DOMESTIC BATTERY SIMPLE} ---> {2006, BATTERY, Apr}:  conf = 0.956, sup = 0.05
# {2006, THEFT, Apr, $500 AND UNDER, Not Domestic} ---> {Not Arrested}:  conf = 0.93, sup = 0.055
# {Not Arrested, THEFT, Apr, $500 AND UNDER, Not Domestic} ---> {2006}:  conf = 1.0, sup = 0.055
# {Not Arrested, 2006, Apr, $500 AND UNDER, Not Domestic} ---> {THEFT}:  conf = 1.0, sup = 0.055
# {Not Arrested, 2006, THEFT, $500 AND UNDER, Not Domestic} ---> {Apr}:  conf = 0.943, sup = 0.055
# {Not Arrested, 2006, THEFT, Apr, $500 AND UNDER} ---> {Not Domestic}:  conf = 0.968, sup = 0.055
# {THEFT, Not Domestic, $500 AND UNDER, Apr} ---> {2006, Not Arrested}:  conf = 0.93, sup = 0.055
# {2006, Not Domestic, $500 AND UNDER, Apr} ---> {THEFT, Not Arrested}:  conf = 0.93, sup = 0.055
# {Not Arrested, Not Domestic, $500 AND UNDER, Apr} ---> {2006, THEFT}:  conf = 1.0, sup = 0.055
# {THEFT, Not Arrested, $500 AND UNDER, Not Domestic} ---> {2006, Apr}:  conf = 0.93, sup = 0.055
# {THEFT, Not Arrested, $500 AND UNDER, Apr} ---> {2006, Not Domestic}:  conf = 0.968, sup = 0.055
# {2006, Not Arrested, $500 AND UNDER, Not Domestic} ---> {THEFT, Apr}:  conf = 0.943, sup = 0.055
# {2006, Not Arrested, $500 AND UNDER, Apr} ---> {THEFT, Not Domestic}:  conf = 0.968, sup = 0.055
# {2006, THEFT, Not Arrested, $500 AND UNDER} ---> {Not Domestic, Apr}:  conf = 0.913, sup = 0.055
# {Not Domestic, $500 AND UNDER, Apr} ---> {2006, THEFT, Not Arrested}:  conf = 0.93, sup = 0.055
# {Not Arrested, $500 AND UNDER, Not Domestic} ---> {2006, THEFT, Apr}:  conf = 0.93, sup = 0.055
# {Not Arrested, $500 AND UNDER, Apr} ---> {2006, THEFT, Not Domestic}:  conf = 0.968, sup = 0.055
# {THEFT, Not Arrested, $500 AND UNDER} ---> {2006, Not Domestic, Apr}:  conf = 0.901, sup = 0.055
# {2006, Not Arrested, $500 AND UNDER} ---> {THEFT, Not Domestic, Apr}:  conf = 0.913, sup = 0.055
# {Not Arrested, $500 AND UNDER} ---> {2006, THEFT, Apr, Not Domestic}:  conf = 0.901, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE, Apr, Not Domestic} ---> {2006}:  conf = 1.0, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE, 2006, Not Domestic} ---> {Apr}:  conf = 0.95, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE, 2006, Apr} ---> {Not Domestic}:  conf = 0.977, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE, Not Domestic} ---> {2006, Apr}:  conf = 0.932, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE, Apr} ---> {2006, Not Domestic}:  conf = 0.977, sup = 0.055
# {2006, Not Arrested, BATTERY, SIMPLE} ---> {Not Domestic, Apr}:  conf = 0.929, sup = 0.055
# {Not Arrested, BATTERY, SIMPLE} ---> {2006, Not Domestic, Apr}:  conf = 0.912, sup = 0.055

# %%
# (c) 2014 Reid Johnson
#
# Modified from:
# Eric Naeseth <eric@naeseth.com>
# (https://github.com/enaeseth/python-fp-growth/blob/master/fp_growth.py)
#
# A Python implementation of the FP-growth algorithm.

from collections import defaultdict, namedtuple
#from itertools import imap

__author__ = 'Eric Naeseth <eric@naeseth.com>'
__copyright__ = 'Copyright © 2009 Eric Naeseth'
__license__ = 'MIT License'

def fpgrowth(dataset, min_support=0.5, include_support=True, verbose=False):
    """Implements the FP-growth algorithm.

    The `dataset` parameter can be any iterable of iterables of items.
    `min_support` should be an integer specifying the minimum number of
    occurrences of an itemset for it to be accepted.

    Each item must be hashable (i.e., it must be valid as a member of a
    dictionary or a set).

    If `include_support` is true, yield (itemset, support) pairs instead of
    just the itemsets.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    include_support : bool
        Include support in output (default=False).

    References
    ----------
    .. [1] J. Han, J. Pei, Y. Yin, "Mining Frequent Patterns without Candidate 
           Generation," 2000.

    """

    F = []
    support_data = {}
    for k,v in find_frequent_itemsets(dataset, min_support=min_support, include_support=include_support, verbose=verbose):
        F.append(frozenset(k))
        support_data[frozenset(k)] = v

    # Create one array with subarrays that hold all transactions of equal length.
    def bucket_list(nested_list, sort=True):
        bucket = defaultdict(list)
        for sublist in nested_list:
            bucket[len(sublist)].append(sublist)
        return [v for k,v in sorted(bucket.items())] if sort else bucket.values()

    F = bucket_list(F)
    
    return F, support_data

def find_frequent_itemsets(dataset, min_support, include_support=False, verbose=False):
    """
    Find frequent itemsets in the given transactions using FP-growth. This
    function returns a generator instead of an eagerly-populated list of items.

    The `dataset` parameter can be any iterable of iterables of items.
    `min_support` should be an integer specifying the minimum number of
    occurrences of an itemset for it to be accepted.

    Each item must be hashable (i.e., it must be valid as a member of a
    dictionary or a set).

    If `include_support` is true, yield (itemset, support) pairs instead of
    just the itemsets.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    include_support : bool
        Include support in output (default=False).

    """
    items = defaultdict(lambda: 0) # mapping from items to their supports
    processed_transactions = []

    # Load the passed-in transactions and count the support that individual
    # items have.
    for transaction in dataset:
        processed = []
        for item in transaction:
            items[item] += 1
            processed.append(item)
        processed_transactions.append(processed)

    # Remove infrequent items from the item support dictionary.
    items = dict((item, support) for item, support in items.items()
        if support >= min_support)

    # Build our FP-tree. Before any transactions can be added to the tree, they
    # must be stripped of infrequent items and their surviving items must be
    # sorted in decreasing order of frequency.
    def clean_transaction(transaction):
        #transaction = filter(lambda v: v in items, transaction)
        transaction.sort(key=lambda v: items[v], reverse=True)
        return transaction

    master = FPTree()
    for transaction in map(clean_transaction, processed_transactions):
        master.add(transaction)

    support_data = {}
    def find_with_suffix(tree, suffix):
        for item, nodes in tree.items():
            support = float(sum(n.count for n in nodes)) / len(dataset)
            if support >= min_support and item not in suffix:
                # New winner!
                found_set = [item] + suffix
                support_data[frozenset(found_set)] = support
                yield (found_set, support) if include_support else found_set

                # Build a conditional tree and recursively search for frequent
                # itemsets within it.
                cond_tree = conditional_tree_from_paths(tree.prefix_paths(item),
                    min_support)
                for s in find_with_suffix(cond_tree, found_set):
                    yield s # pass along the good news to our caller

    if verbose:
        # Print a list of all the frequent itemsets.
        for itemset, support in find_with_suffix(master, []):
            print("" \
                + "{" \
                + "".join(str(i) + ", " for i in iter(itemset)).rstrip(', ') \
                + "}" \
                + ":  sup = " + str(round(support_data[frozenset(itemset)], 3)))

    # Search for frequent itemsets, and yield the results we find.
    for itemset in find_with_suffix(master, []):
        yield itemset

class FPTree(object):
    """
    An FP tree.

    This object may only store transaction items that are hashable (i.e., all
    items must be valid as dictionary keys or set members).
    """

    Route = namedtuple('Route', 'head tail')

    def __init__(self):
        # The root node of the tree.
        self._root = FPNode(self, None, None)

        # A dictionary mapping items to the head and tail of a path of
        # "neighbors" that will hit every node containing that item.
        self._routes = {}

    @property
    def root(self):
        """The root node of the tree."""
        return self._root

    def add(self, transaction):
        """
        Adds a transaction to the tree.
        """

        point = self._root

        for item in transaction:
            next_point = point.search(item)
            if next_point:
                # There is already a node in this tree for the current
                # transaction item; reuse it.
                next_point.increment()
            else:
                # Create a new point and add it as a child of the point we're
                # currently looking at.
                next_point = FPNode(self, item)
                point.add(next_point)

                # Update the route of nodes that contain this item to include
                # our new node.
                self._update_route(next_point)

            point = next_point

    def _update_route(self, point):
        """Add the given node to the route through all nodes for its item."""
        assert self is point.tree

        try:
            route = self._routes[point.item]
            route[1].neighbor = point # route[1] is the tail
            self._routes[point.item] = self.Route(route[0], point)
        except KeyError:
            # First node for this item; start a new route.
            self._routes[point.item] = self.Route(point, point)

    def items(self):
        """
        Generate one 2-tuples for each item represented in the tree. The first
        element of the tuple is the item itself, and the second element is a
        generator that will yield the nodes in the tree that belong to the item.
        """
        for item in self._routes.keys():
            yield (item, self.nodes(item))

            
    def nodes(self, item):
        """
        Generates the sequence of nodes that contain the given item.
        """

        try:
            node = self._routes[item][0]
        except KeyError:
            return

        while node:
            yield node
            node = node.neighbor

    def prefix_paths(self, item):
        """Generates the prefix paths that end with the given item."""

        def collect_path(node):
            path = []
            while node and not node.root:
                path.append(node)
                node = node.parent
            path.reverse()
            return path

        return (collect_path(node) for node in self.nodes(item))

    def inspect(self):
        print("Tree:")
        self.root.inspect(1)

        print("")
        print("Routes:")
        for item, nodes in self.items():
            print("  %r" % item)
            for node in nodes:
                print("    %r" % node)

    def _removed(self, node):
        """Called when `node` is removed from the tree; performs cleanup."""

        head, tail = self._routes[node.item]
        if node is head:
            if node is tail or not node.neighbor:
                # It was the sole node.
                del self._routes[node.item]
            else:
                self._routes[node.item] = self.Route(node.neighbor, tail)
        else:
            for n in self.nodes(node.item):
                if n.neighbor is node:
                    n.neighbor = node.neighbor # skip over
                    if node is tail:
                        self._routes[node.item] = self.Route(head, n)
                    break

def conditional_tree_from_paths(paths, min_support):
    """Builds a conditional FP-tree from the given prefix paths."""
    tree = FPTree()
    condition_item = None
    items = set()

    # Import the nodes in the paths into the new tree. Only the counts of the
    # leaf notes matter; the remaining counts will be reconstructed from the
    # leaf counts.
    for path in paths:
        if condition_item is None:
            condition_item = path[-1].item

        point = tree.root
        for node in path:
            next_point = point.search(node.item)
            if not next_point:
                # Add a new node to the tree.
                items.add(node.item)
                count = node.count if node.item == condition_item else 0
                next_point = FPNode(tree, node.item, count)
                point.add(next_point)
                tree._update_route(next_point)
            point = next_point

    assert condition_item is not None

    # Calculate the counts of the non-leaf nodes.
    for path in tree.prefix_paths(condition_item):
        count = path[-1].count
        for node in reversed(path[:-1]):
            node._count += count

    # Eliminate the nodes for any items that are no longer frequent.
    for item in items:
        support = sum(n.count for n in tree.nodes(item))
        if support < min_support:
            # Doesn't make the cut anymore
            for node in tree.nodes(item):
                if node.parent is not None:
                    node.parent.remove(node)

    # Finally, remove the nodes corresponding to the item for which this
    # conditional tree was generated.
    for node in tree.nodes(condition_item):
        if node.parent is not None: # the node might already be an orphan
            node.parent.remove(node)

    return tree

class FPNode(object):
    """A node in an FP tree."""

    def __init__(self, tree, item, count=1):
        self._tree = tree
        self._item = item
        self._count = count
        self._parent = None
        self._children = {}
        self._neighbor = None

    def add(self, child):
        """Adds the given FPNode `child` as a child of this node."""

        if not isinstance(child, FPNode):
            raise TypeError("Can only add other FPNodes as children")

        if not child.item in self._children:
            self._children[child.item] = child
            child.parent = self

    def search(self, item):
        """
        Checks to see if this node contains a child node for the given item.
        If so, that node is returned; otherwise, `None` is returned.
        """

        try:
            return self._children[item]
        except KeyError:
            return None

    def remove(self, child):
        try:
            if self._children[child.item] is child:
                del self._children[child.item]
                child.parent = None
                self._tree._removed(child)
                for sub_child in child.children:
                    try:
                        # Merger case: we already have a child for that item, so
                        # add the sub-child's count to our child's count.
                        self._children[sub_child.item]._count += sub_child.count
                        sub_child.parent = None # it's an orphan now
                    except KeyError:
                        # Turns out we don't actually have a child, so just add
                        # the sub-child as our own child.
                        self.add(sub_child)
                child._children = {}
            else:
                raise ValueError("that node is not a child of this node")
        except KeyError:
            raise ValueError("that node is not a child of this node")

    def __contains__(self, item):
        return item in self._children

    @property
    def tree(self):
        """The tree in which this node appears."""
        return self._tree

    @property
    def item(self):
        """The item contained in this node."""
        return self._item

    @property
    def count(self):
        """The count associated with this node's item."""
        return self._count

    def increment(self):
        """Increments the count associated with this node's item."""
        if self._count is None:
            raise ValueError("Root nodes have no associated count.")
        self._count += 1

    @property
    def root(self):
        """True if this node is the root of a tree; false if otherwise."""
        return self._item is None and self._count is None

    @property
    def leaf(self):
        """True if this node is a leaf in the tree; false if otherwise."""
        return len(self._children) == 0

    def parent():
        doc = "The node's parent."
        def fget(self):
            return self._parent
        def fset(self, value):
            if value is not None and not isinstance(value, FPNode):
                raise TypeError("A node must have an FPNode as a parent.")
            if value and value.tree is not self.tree:
                raise ValueError("Cannot have a parent from another tree.")
            self._parent = value
        return locals()
    parent = property(**parent())

    def neighbor():
        doc = """
        The node's neighbor; the one with the same value that is "to the right"
        of it in the tree.
        """
        def fget(self):
            return self._neighbor
        def fset(self, value):
            if value is not None and not isinstance(value, FPNode):
                raise TypeError("A node must have an FPNode as a neighbor.")
            if value and value.tree is not self.tree:
                raise ValueError("Cannot have a neighbor from another tree.")
            self._neighbor = value
        return locals()
    neighbor = property(**neighbor())

    @property
    def children(self):
        """The nodes that are children of this node."""
        return tuple(self._children.values())
        
    def inspect(self, depth=0):
        print(('  ' * depth) + repr(self))
        for child in self.children:
            child.inspect(depth + 1)

    def __repr__(self):
        if self.root:
            return "<%s (root)>" % type(self).__name__
        return "<%s %r (%r)>" % (type(self).__name__, self.item, self.count)

def rules_from_conseq(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Generates a set of candidate rules.

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    support_data : dict
        The support data for all candidate itemsets.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.
    """
    m = len(H[0])
    if m == 1:
        Hmp1 = calc_confidence(freq_set, H, support_data, rules, min_confidence, verbose)
    if (len(freq_set) > (m+1)):
        Hmp1 = apriori_gen(H, m+1) # generate candidate itemsets
        Hmp1 = calc_confidence(freq_set, Hmp1,  support_data, rules, min_confidence, verbose)
        if len(Hmp1) > 1:
            # If there are candidate rules above the minimum confidence 
            # threshold, recurse on the list of these candidate rules.
            rules_from_conseq(freq_set, Hmp1, support_data, rules, min_confidence, verbose)

def calc_confidence(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Evaluates the generated rules.

    One measurement for quantifying the goodness of association rules is 
    confidence. The confidence for a rule 'P implies H' (P -> H) is defined as 
    the support for P and H divided by the support for P 
    (support (P|H) / support(P)), where the | symbol denotes the set union 
    (thus P|H means all the items in set P or in set H).

    To calculate the confidence, we iterate through the frequent itemsets and 
    associated support data. For each frequent itemset, we divide the support 
    of the itemset by the support of the antecedent (left-hand-side of the 
    rule).

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    min_support : float
        The minimum support threshold.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    pruned_H : list
        The list of candidate rules above the minimum confidence threshold.
    """
    pruned_H = [] # list of candidate rules above the minimum confidence threshold
    for conseq in H: # iterate over the frequent itemsets
        conf = support_data[freq_set] / support_data[freq_set - conseq]
        if conf >= min_confidence:
            rules.append((freq_set - conseq, conseq, conf))
            pruned_H.append(conseq)

            if verbose:
                print("" \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(freq_set-conseq)]).rstrip(', ') \
                    + "}" \
                    + " ---> " \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(conseq)]).rstrip(', ') \
                    + "}" \
                    + ":  conf = " + str(round(conf, 3)) \
                    + ", sup = " + str(round(support_data[freq_set], 3)))

    return pruned_H

def generate_rules(F, support_data, min_confidence=0.5, verbose=True):
    """Generates a set of candidate rules from a list of frequent itemsets.

    For each frequent itemset, we calculate the confidence of using a
    particular item as the rule consequent (right-hand-side of the rule). By 
    testing and merging the remaining rules, we recursively create a list of 
    pruned rules.

    Parameters
    ----------
    F : list
        A list of frequent itemsets.

    support_data : dict
        The corresponding support data for the frequent itemsets (L).

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    rules : list
        The list of candidate rules above the minimum confidence threshold.
    """
    rules = []
    for i in range(1, len(F)):
        for freq_set in F[i]:
            H1 = [frozenset([item]) for item in freq_set]
            if (i > 1):
                rules_from_conseq(freq_set, H1, support_data, rules, min_confidence, verbose)
            else:
                calc_confidence(freq_set, H1, support_data, rules, min_confidence, verbose)

    return rules

# %%
F_fp, support_data_fp = fpgrowth(df[:10000], min_support=0.1, verbose=True)
# Out:
# {2006}:  sup = 0.984
# {Not Domestic}:  sup = 0.871
# {2006, Not Domestic}:  sup = 0.856
# {Arrested}:  sup = 0.274
# {2006, Arrested}:  sup = 0.272
# {Not Domestic, Arrested}:  sup = 0.248
# {2006, Not Domestic, Arrested}:  sup = 0.246
# {Night, Arrested}:  sup = 0.102
# {2006, Night, Arrested}:  sup = 0.102
# {Apr, Arrested}:  sup = 0.158
# {2006, Apr, Arrested}:  sup = 0.158
# {Not Domestic, Apr, Arrested}:  sup = 0.133
# {2006, Not Domestic, Apr, Arrested}:  sup = 0.133
# {Noon}:  sup = 0.192
# {2006, Noon}:  sup = 0.188
# {Not Domestic, Noon}:  sup = 0.168
# {2006, Not Domestic, Noon}:  sup = 0.164
# {Apr, Noon}:  sup = 0.157
# {2006, Apr, Noon}:  sup = 0.157
# {Not Domestic, Apr, Noon}:  sup = 0.134
# {2006, Not Domestic, Apr, Noon}:  sup = 0.134
# {Not Arrested, Noon}:  sup = 0.142
# {2006, Not Arrested, Noon}:  sup = 0.138
# {Not Domestic, Not Arrested, Noon}:  sup = 0.121
# {2006, Not Domestic, Not Arrested, Noon}:  sup = 0.118
# {Apr, Not Arrested, Noon}:  sup = 0.126
# {2006, Apr, Not Arrested, Noon}:  sup = 0.126
# {Not Domestic, Apr, Not Arrested, Noon}:  sup = 0.106
# {2006, Not Domestic, Apr, Not Arrested, Noon}:  sup = 0.106
# {Not Arrested}:  sup = 0.726
# {2006, Not Arrested}:  sup = 0.712
# {Not Domestic, Not Arrested}:  sup = 0.623
# {2006, Not Domestic, Not Arrested}:  sup = 0.611
# {Apr, Not Arrested}:  sup = 0.656
# {2006, Apr, Not Arrested}:  sup = 0.655
# {Not Domestic, Apr, Not Arrested}:  sup = 0.56
# {2006, Not Domestic, Apr, Not Arrested}:  sup = 0.56
# {Night}:  sup = 0.36
# {2006, Night}:  sup = 0.355
# {Not Domestic, Night}:  sup = 0.306
# {2006, Not Domestic, Night}:  sup = 0.301
# {Not Arrested, Night}:  sup = 0.258
# {2006, Not Arrested, Night}:  sup = 0.253
# {Not Domestic, Not Arrested, Night}:  sup = 0.215
# {2006, Not Domestic, Not Arrested, Night}:  sup = 0.211
# {Apr, Not Arrested, Night}:  sup = 0.237
# {2006, Apr, Not Arrested, Night}:  sup = 0.237
# {Not Domestic, Apr, Not Arrested, Night}:  sup = 0.197
# {2006, Not Domestic, Apr, Not Arrested, Night}:  sup = 0.197
# {Apr, Night}:  sup = 0.29
# {2006, Apr, Night}:  sup = 0.29
# {Not Domestic, Apr, Night}:  sup = 0.239
# {2006, Not Domestic, Apr, Night}:  sup = 0.239
# {Apr}:  sup = 0.814
# {2006, Apr}:  sup = 0.813
# {Not Domestic, Apr}:  sup = 0.693
# {2006, Not Domestic, Apr}:  sup = 0.693
# {Evening}:  sup = 0.212
# {2006, Evening}:  sup = 0.21
# {Not Domestic, Evening}:  sup = 0.189
# {2006, Not Domestic, Evening}:  sup = 0.187
# {Apr, Evening}:  sup = 0.178
# {2006, Apr, Evening}:  sup = 0.178
# {Not Domestic, Apr, Evening}:  sup = 0.157
# {2006, Not Domestic, Apr, Evening}:  sup = 0.157
# {Not Arrested, Evening}:  sup = 0.152
# {2006, Not Arrested, Evening}:  sup = 0.15
# {Not Domestic, Not Arrested, Evening}:  sup = 0.135
# {2006, Not Domestic, Not Arrested, Evening}:  sup = 0.133
# {Apr, Not Arrested, Evening}:  sup = 0.142
# {2006, Apr, Not Arrested, Evening}:  sup = 0.142
# {Not Domestic, Apr, Not Arrested, Evening}:  sup = 0.125
# {2006, Not Domestic, Apr, Not Arrested, Evening}:  sup = 0.125
# {BATTERY}:  sup = 0.203
# {2006, BATTERY}:  sup = 0.2
# {Not Domestic, BATTERY}:  sup = 0.126
# {2006, Not Domestic, BATTERY}:  sup = 0.124
# {Apr, BATTERY}:  sup = 0.193
# {2006, Apr, BATTERY}:  sup = 0.193
# {Not Domestic, Apr, BATTERY}:  sup = 0.119
# {2006, Not Domestic, Apr, BATTERY}:  sup = 0.119
# {Not Arrested, BATTERY}:  sup = 0.155
# {2006, Not Arrested, BATTERY}:  sup = 0.153
# {Apr, Not Arrested, BATTERY}:  sup = 0.147
# {2006, Apr, Not Arrested, BATTERY}:  sup = 0.147
# {RESIDENCE}:  sup = 0.163
# {2006, RESIDENCE}:  sup = 0.159
# {Not Domestic, RESIDENCE}:  sup = 0.114
# {2006, Not Domestic, RESIDENCE}:  sup = 0.111
# {Apr, RESIDENCE}:  sup = 0.14
# {2006, Apr, RESIDENCE}:  sup = 0.14
# {Not Arrested, RESIDENCE}:  sup = 0.141
# {2006, Not Arrested, RESIDENCE}:  sup = 0.138
# {Not Domestic, Not Arrested, RESIDENCE}:  sup = 0.101
# {Apr, Not Arrested, RESIDENCE}:  sup = 0.123
# {2006, Apr, Not Arrested, RESIDENCE}:  sup = 0.123
# {SIMPLE}:  sup = 0.116
# {2006, SIMPLE}:  sup = 0.114
# {Not Domestic, SIMPLE}:  sup = 0.106
# {2006, Not Domestic, SIMPLE}:  sup = 0.104
# {Apr, SIMPLE}:  sup = 0.109
# {2006, Apr, SIMPLE}:  sup = 0.109
# {APARTMENT}:  sup = 0.101
# {Morning}:  sup = 0.235
# {2006, Morning}:  sup = 0.231
# {Not Domestic, Morning}:  sup = 0.208
# {2006, Not Domestic, Morning}:  sup = 0.204
# {Apr, Morning}:  sup = 0.189
# {2006, Apr, Morning}:  sup = 0.189
# {Not Domestic, Apr, Morning}:  sup = 0.164
# {2006, Not Domestic, Apr, Morning}:  sup = 0.163
# {Not Arrested, Morning}:  sup = 0.174
# {2006, Not Arrested, Morning}:  sup = 0.171
# {Not Domestic, Not Arrested, Morning}:  sup = 0.153
# {2006, Not Domestic, Not Arrested, Morning}:  sup = 0.149
# {Apr, Not Arrested, Morning}:  sup = 0.152
# {2006, Apr, Not Arrested, Morning}:  sup = 0.151
# {Not Domestic, Apr, Not Arrested, Morning}:  sup = 0.132
# {2006, Not Domestic, Apr, Not Arrested, Morning}:  sup = 0.132
# {STREET}:  sup = 0.266
# {2006, STREET}:  sup = 0.262
# {Not Domestic, STREET}:  sup = 0.247
# {2006, Not Domestic, STREET}:  sup = 0.244
# {Apr, STREET}:  sup = 0.212
# {2006, Apr, STREET}:  sup = 0.211
# {Not Domestic, Apr, STREET}:  sup = 0.194
# {2006, Not Domestic, Apr, STREET}:  sup = 0.194
# {Not Arrested, STREET}:  sup = 0.194
# {2006, Not Arrested, STREET}:  sup = 0.191
# {Not Domestic, Not Arrested, STREET}:  sup = 0.179
# {2006, Not Domestic, Not Arrested, STREET}:  sup = 0.177
# {Apr, Not Arrested, STREET}:  sup = 0.182
# {2006, Apr, Not Arrested, STREET}:  sup = 0.182
# {Not Domestic, Apr, Not Arrested, STREET}:  sup = 0.168
# {2006, Not Domestic, Apr, Not Arrested, STREET}:  sup = 0.168
# {Night, STREET}:  sup = 0.111
# {2006, Night, STREET}:  sup = 0.109
# {Not Domestic, Night, STREET}:  sup = 0.104
# {2006, Not Domestic, Night, STREET}:  sup = 0.103
# {THEFT}:  sup = 0.194
# {2006, THEFT}:  sup = 0.19
# {Not Domestic, THEFT}:  sup = 0.189
# {2006, Not Domestic, THEFT}:  sup = 0.185
# {Apr, THEFT}:  sup = 0.172
# {2006, Apr, THEFT}:  sup = 0.172
# {Not Domestic, Apr, THEFT}:  sup = 0.168
# {2006, Not Domestic, Apr, THEFT}:  sup = 0.168
# {Not Arrested, THEFT}:  sup = 0.171
# {2006, Not Arrested, THEFT}:  sup = 0.167
# {Not Domestic, Not Arrested, THEFT}:  sup = 0.166
# {2006, Not Domestic, Not Arrested, THEFT}:  sup = 0.162
# {Apr, Not Arrested, THEFT}:  sup = 0.15
# {2006, Apr, Not Arrested, THEFT}:  sup = 0.15
# {Not Domestic, Apr, Not Arrested, THEFT}:  sup = 0.146
# {2006, Not Domestic, Apr, Not Arrested, THEFT}:  sup = 0.146
# {Domestic}:  sup = 0.129
# {2006, Domestic}:  sup = 0.127
# {Apr, Domestic}:  sup = 0.121
# {2006, Apr, Domestic}:  sup = 0.12
# {Not Arrested, Domestic}:  sup = 0.103
# {2006, Not Arrested, Domestic}:  sup = 0.102
# {CRIMINAL DAMAGE}:  sup = 0.14
# {2006, CRIMINAL DAMAGE}:  sup = 0.139
# {Not Domestic, CRIMINAL DAMAGE}:  sup = 0.13
# {2006, Not Domestic, CRIMINAL DAMAGE}:  sup = 0.129
# {Apr, CRIMINAL DAMAGE}:  sup = 0.133
# {2006, Apr, CRIMINAL DAMAGE}:  sup = 0.133
# {Not Domestic, Apr, CRIMINAL DAMAGE}:  sup = 0.124
# {2006, Not Domestic, Apr, CRIMINAL DAMAGE}:  sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE}:  sup = 0.13
# {2006, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.129
# {Not Domestic, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.121
# {2006, Not Domestic, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.121
# {Apr, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.124
# {2006, Apr, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.124
# {Not Domestic, Apr, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.115
# {2006, Not Domestic, Apr, Not Arrested, CRIMINAL DAMAGE}:  sup = 0.115
# {Day of Month 7}:  sup = 0.101
# {2006, Day of Month 7}:  sup = 0.101

# %%
H_fp = generate_rules(F_fp, support_data_fp, min_confidence=0.4, verbose=True)
# Out:
# {Not Domestic} ---> {2006}:  conf = 0.983, sup = 0.856
# {2006} ---> {Not Domestic}:  conf = 0.871, sup = 0.856
# {Arrested} ---> {2006}:  conf = 0.992, sup = 0.272
# {Arrested} ---> {Not Domestic}:  conf = 0.905, sup = 0.248
# {Arrested} ---> {Apr}:  conf = 0.578, sup = 0.158
# {Noon} ---> {2006}:  conf = 0.979, sup = 0.188
# {Noon} ---> {Not Domestic}:  conf = 0.874, sup = 0.168
# {Noon} ---> {Apr}:  conf = 0.818, sup = 0.157
# {Noon} ---> {Not Arrested}:  conf = 0.739, sup = 0.142
# {Not Arrested} ---> {2006}:  conf = 0.981, sup = 0.712
# {2006} ---> {Not Arrested}:  conf = 0.724, sup = 0.712
# {Not Domestic} ---> {Not Arrested}:  conf = 0.716, sup = 0.623
# {Not Arrested} ---> {Not Domestic}:  conf = 0.858, sup = 0.623
# {Apr} ---> {Not Arrested}:  conf = 0.806, sup = 0.656
# {Not Arrested} ---> {Apr}:  conf = 0.903, sup = 0.656
# {Night} ---> {2006}:  conf = 0.984, sup = 0.355
# {Night} ---> {Not Domestic}:  conf = 0.849, sup = 0.306
# {Night} ---> {Not Arrested}:  conf = 0.716, sup = 0.258
# {Night} ---> {Apr}:  conf = 0.805, sup = 0.29
# {Apr} ---> {2006}:  conf = 0.999, sup = 0.813
# {2006} ---> {Apr}:  conf = 0.827, sup = 0.813
# {Not Domestic} ---> {Apr}:  conf = 0.796, sup = 0.693
# {Apr} ---> {Not Domestic}:  conf = 0.852, sup = 0.693
# {Evening} ---> {2006}:  conf = 0.99, sup = 0.21
# {Evening} ---> {Not Domestic}:  conf = 0.892, sup = 0.189
# {Evening} ---> {Apr}:  conf = 0.84, sup = 0.178
# {Evening} ---> {Not Arrested}:  conf = 0.717, sup = 0.152
# {BATTERY} ---> {2006}:  conf = 0.985, sup = 0.2
# {BATTERY} ---> {Not Domestic}:  conf = 0.623, sup = 0.126
# {BATTERY} ---> {Apr}:  conf = 0.951, sup = 0.193
# {BATTERY} ---> {Not Arrested}:  conf = 0.767, sup = 0.155
# {RESIDENCE} ---> {2006}:  conf = 0.975, sup = 0.159
# {RESIDENCE} ---> {Not Domestic}:  conf = 0.702, sup = 0.114
# {RESIDENCE} ---> {Apr}:  conf = 0.858, sup = 0.14
# {RESIDENCE} ---> {Not Arrested}:  conf = 0.869, sup = 0.141
# {SIMPLE} ---> {2006}:  conf = 0.984, sup = 0.114
# {SIMPLE} ---> {Not Domestic}:  conf = 0.91, sup = 0.106
# {SIMPLE} ---> {Apr}:  conf = 0.939, sup = 0.109
# {Morning} ---> {2006}:  conf = 0.983, sup = 0.231
# {Morning} ---> {Not Domestic}:  conf = 0.883, sup = 0.208
# {Morning} ---> {Apr}:  conf = 0.801, sup = 0.189
# {Morning} ---> {Not Arrested}:  conf = 0.741, sup = 0.174
# {STREET} ---> {2006}:  conf = 0.986, sup = 0.262
# {STREET} ---> {Not Domestic}:  conf = 0.93, sup = 0.247
# {STREET} ---> {Apr}:  conf = 0.797, sup = 0.212
# {STREET} ---> {Not Arrested}:  conf = 0.73, sup = 0.194
# {STREET} ---> {Night}:  conf = 0.417, sup = 0.111
# {THEFT} ---> {2006}:  conf = 0.98, sup = 0.19
# {THEFT} ---> {Not Domestic}:  conf = 0.973, sup = 0.189
# {THEFT} ---> {Apr}:  conf = 0.888, sup = 0.172
# {THEFT} ---> {Not Arrested}:  conf = 0.879, sup = 0.171
# {Domestic} ---> {2006}:  conf = 0.988, sup = 0.127
# {Domestic} ---> {Apr}:  conf = 0.936, sup = 0.121
# {Domestic} ---> {Not Arrested}:  conf = 0.798, sup = 0.103
# {CRIMINAL DAMAGE} ---> {2006}:  conf = 0.994, sup = 0.139
# {CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.931, sup = 0.13
# {CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.953, sup = 0.133
# {CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.931, sup = 0.13
# {Day of Month 7} ---> {2006}:  conf = 0.997, sup = 0.101
# {Arrested, Not Domestic} ---> {2006}:  conf = 0.992, sup = 0.246
# {2006, Arrested} ---> {Not Domestic}:  conf = 0.905, sup = 0.246
# {Arrested} ---> {2006, Not Domestic}:  conf = 0.898, sup = 0.246
# {Night, Arrested} ---> {2006}:  conf = 0.992, sup = 0.102
# {Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.158
# {2006, Arrested} ---> {Apr}:  conf = 0.582, sup = 0.158
# {Arrested} ---> {2006, Apr}:  conf = 0.577, sup = 0.158
# {Arrested, Not Domestic} ---> {Apr}:  conf = 0.538, sup = 0.133
# {Arrested, Apr} ---> {Not Domestic}:  conf = 0.842, sup = 0.133
# {Arrested} ---> {Not Domestic, Apr}:  conf = 0.487, sup = 0.133
# {Noon, Not Domestic} ---> {2006}:  conf = 0.978, sup = 0.164
# {2006, Noon} ---> {Not Domestic}:  conf = 0.874, sup = 0.164
# {Noon} ---> {2006, Not Domestic}:  conf = 0.855, sup = 0.164
# {Noon, Apr} ---> {2006}:  conf = 0.998, sup = 0.157
# {2006, Noon} ---> {Apr}:  conf = 0.835, sup = 0.157
# {Noon} ---> {2006, Apr}:  conf = 0.817, sup = 0.157
# {Noon, Not Domestic} ---> {Apr}:  conf = 0.801, sup = 0.134
# {Noon, Apr} ---> {Not Domestic}:  conf = 0.856, sup = 0.134
# {Noon} ---> {Not Domestic, Apr}:  conf = 0.7, sup = 0.134
# {Not Arrested, Noon} ---> {2006}:  conf = 0.977, sup = 0.138
# {2006, Noon} ---> {Not Arrested}:  conf = 0.738, sup = 0.138
# {Noon} ---> {2006, Not Arrested}:  conf = 0.722, sup = 0.138
# {Noon, Not Domestic} ---> {Not Arrested}:  conf = 0.723, sup = 0.121
# {Not Arrested, Noon} ---> {Not Domestic}:  conf = 0.855, sup = 0.121
# {Noon} ---> {Not Arrested, Not Domestic}:  conf = 0.632, sup = 0.121
# {Noon, Apr} ---> {Not Arrested}:  conf = 0.801, sup = 0.126
# {Not Arrested, Noon} ---> {Apr}:  conf = 0.887, sup = 0.126
# {Noon} ---> {Not Arrested, Apr}:  conf = 0.656, sup = 0.126
# {Not Arrested, Not Domestic} ---> {2006}:  conf = 0.98, sup = 0.611
# {2006, Not Domestic} ---> {Not Arrested}:  conf = 0.713, sup = 0.611
# {2006, Not Arrested} ---> {Not Domestic}:  conf = 0.857, sup = 0.611
# {Not Domestic} ---> {2006, Not Arrested}:  conf = 0.701, sup = 0.611
# {Not Arrested} ---> {2006, Not Domestic}:  conf = 0.841, sup = 0.611
# {2006} ---> {Not Arrested, Not Domestic}:  conf = 0.621, sup = 0.611
# {Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.655
# {2006, Apr} ---> {Not Arrested}:  conf = 0.806, sup = 0.655
# {2006, Not Arrested} ---> {Apr}:  conf = 0.92, sup = 0.655
# {Apr} ---> {2006, Not Arrested}:  conf = 0.805, sup = 0.655
# {Not Arrested} ---> {2006, Apr}:  conf = 0.902, sup = 0.655
# {2006} ---> {Not Arrested, Apr}:  conf = 0.666, sup = 0.655
# {Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.899, sup = 0.56
# {Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.808, sup = 0.56
# {Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.854, sup = 0.56
# {Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.643, sup = 0.56
# {Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.771, sup = 0.56
# {Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.688, sup = 0.56
# {Night, Not Domestic} ---> {2006}:  conf = 0.983, sup = 0.301
# {2006, Night} ---> {Not Domestic}:  conf = 0.849, sup = 0.301
# {Night} ---> {2006, Not Domestic}:  conf = 0.835, sup = 0.301
# {Night, Not Arrested} ---> {2006}:  conf = 0.98, sup = 0.253
# {2006, Night} ---> {Not Arrested}:  conf = 0.713, sup = 0.253
# {Night} ---> {2006, Not Arrested}:  conf = 0.702, sup = 0.253
# {Night, Not Domestic} ---> {Not Arrested}:  conf = 0.702, sup = 0.215
# {Night, Not Arrested} ---> {Not Domestic}:  conf = 0.833, sup = 0.215
# {Night} ---> {Not Arrested, Not Domestic}:  conf = 0.596, sup = 0.215
# {Night, Apr} ---> {Not Arrested}:  conf = 0.817, sup = 0.237
# {Night, Not Arrested} ---> {Apr}:  conf = 0.918, sup = 0.237
# {Night} ---> {Not Arrested, Apr}:  conf = 0.657, sup = 0.237
# {Night, Apr} ---> {2006}:  conf = 1.0, sup = 0.29
# {2006, Night} ---> {Apr}:  conf = 0.818, sup = 0.29
# {Night} ---> {2006, Apr}:  conf = 0.804, sup = 0.29
# {Night, Not Domestic} ---> {Apr}:  conf = 0.78, sup = 0.239
# {Night, Apr} ---> {Not Domestic}:  conf = 0.824, sup = 0.239
# {Night} ---> {Not Domestic, Apr}:  conf = 0.663, sup = 0.239
# {Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.693
# {2006, Not Domestic} ---> {Apr}:  conf = 0.809, sup = 0.693
# {2006, Apr} ---> {Not Domestic}:  conf = 0.852, sup = 0.693
# {Not Domestic} ---> {2006, Apr}:  conf = 0.795, sup = 0.693
# {Apr} ---> {2006, Not Domestic}:  conf = 0.851, sup = 0.693
# {2006} ---> {Not Domestic, Apr}:  conf = 0.704, sup = 0.693
# {Evening, Not Domestic} ---> {2006}:  conf = 0.989, sup = 0.187
# {2006, Evening} ---> {Not Domestic}:  conf = 0.892, sup = 0.187
# {Evening} ---> {2006, Not Domestic}:  conf = 0.882, sup = 0.187
# {Evening, Apr} ---> {2006}:  conf = 1.0, sup = 0.178
# {2006, Evening} ---> {Apr}:  conf = 0.849, sup = 0.178
# {Evening} ---> {2006, Apr}:  conf = 0.84, sup = 0.178
# {Evening, Not Domestic} ---> {Apr}:  conf = 0.827, sup = 0.157
# {Evening, Apr} ---> {Not Domestic}:  conf = 0.878, sup = 0.157
# {Evening} ---> {Not Domestic, Apr}:  conf = 0.738, sup = 0.157
# {Not Arrested, Evening} ---> {2006}:  conf = 0.987, sup = 0.15
# {2006, Evening} ---> {Not Arrested}:  conf = 0.715, sup = 0.15
# {Evening} ---> {2006, Not Arrested}:  conf = 0.707, sup = 0.15
# {Evening, Not Domestic} ---> {Not Arrested}:  conf = 0.71, sup = 0.135
# {Not Arrested, Evening} ---> {Not Domestic}:  conf = 0.884, sup = 0.135
# {Evening} ---> {Not Arrested, Not Domestic}:  conf = 0.633, sup = 0.135
# {Evening, Apr} ---> {Not Arrested}:  conf = 0.794, sup = 0.142
# {Not Arrested, Evening} ---> {Apr}:  conf = 0.93, sup = 0.142
# {Evening} ---> {Not Arrested, Apr}:  conf = 0.667, sup = 0.142
# {BATTERY, Not Domestic} ---> {2006}:  conf = 0.984, sup = 0.124
# {2006, BATTERY} ---> {Not Domestic}:  conf = 0.622, sup = 0.124
# {BATTERY} ---> {2006, Not Domestic}:  conf = 0.613, sup = 0.124
# {BATTERY, Apr} ---> {2006}:  conf = 0.999, sup = 0.193
# {2006, BATTERY} ---> {Apr}:  conf = 0.964, sup = 0.193
# {BATTERY} ---> {2006, Apr}:  conf = 0.95, sup = 0.193
# {BATTERY, Not Domestic} ---> {Apr}:  conf = 0.942, sup = 0.119
# {BATTERY, Apr} ---> {Not Domestic}:  conf = 0.618, sup = 0.119
# {BATTERY} ---> {Not Domestic, Apr}:  conf = 0.587, sup = 0.119
# {Not Arrested, BATTERY} ---> {2006}:  conf = 0.982, sup = 0.153
# {2006, BATTERY} ---> {Not Arrested}:  conf = 0.765, sup = 0.153
# {BATTERY} ---> {2006, Not Arrested}:  conf = 0.753, sup = 0.153
# {BATTERY, Apr} ---> {Not Arrested}:  conf = 0.762, sup = 0.147
# {Not Arrested, BATTERY} ---> {Apr}:  conf = 0.944, sup = 0.147
# {BATTERY} ---> {Not Arrested, Apr}:  conf = 0.724, sup = 0.147
# {RESIDENCE, Not Domestic} ---> {2006}:  conf = 0.97, sup = 0.111
# {2006, RESIDENCE} ---> {Not Domestic}:  conf = 0.699, sup = 0.111
# {RESIDENCE} ---> {2006, Not Domestic}:  conf = 0.681, sup = 0.111
# {RESIDENCE, Apr} ---> {2006}:  conf = 0.999, sup = 0.14
# {2006, RESIDENCE} ---> {Apr}:  conf = 0.88, sup = 0.14
# {RESIDENCE} ---> {2006, Apr}:  conf = 0.857, sup = 0.14
# {RESIDENCE, Not Arrested} ---> {2006}:  conf = 0.973, sup = 0.138
# {2006, RESIDENCE} ---> {Not Arrested}:  conf = 0.868, sup = 0.138
# {RESIDENCE} ---> {2006, Not Arrested}:  conf = 0.846, sup = 0.138
# {RESIDENCE, Not Domestic} ---> {Not Arrested}:  conf = 0.883, sup = 0.101
# {RESIDENCE, Not Arrested} ---> {Not Domestic}:  conf = 0.713, sup = 0.101
# {RESIDENCE} ---> {Not Arrested, Not Domestic}:  conf = 0.62, sup = 0.101
# {RESIDENCE, Apr} ---> {Not Arrested}:  conf = 0.881, sup = 0.123
# {RESIDENCE, Not Arrested} ---> {Apr}:  conf = 0.87, sup = 0.123
# {RESIDENCE} ---> {Not Arrested, Apr}:  conf = 0.756, sup = 0.123
# {SIMPLE, Not Domestic} ---> {2006}:  conf = 0.983, sup = 0.104
# {2006, SIMPLE} ---> {Not Domestic}:  conf = 0.908, sup = 0.104
# {SIMPLE} ---> {2006, Not Domestic}:  conf = 0.894, sup = 0.104
# {SIMPLE, Apr} ---> {2006}:  conf = 0.999, sup = 0.109
# {2006, SIMPLE} ---> {Apr}:  conf = 0.953, sup = 0.109
# {SIMPLE} ---> {2006, Apr}:  conf = 0.938, sup = 0.109
# {Morning, Not Domestic} ---> {2006}:  conf = 0.981, sup = 0.204
# {2006, Morning} ---> {Not Domestic}:  conf = 0.882, sup = 0.204
# {Morning} ---> {2006, Not Domestic}:  conf = 0.867, sup = 0.204
# {Morning, Apr} ---> {2006}:  conf = 0.999, sup = 0.189
# {2006, Morning} ---> {Apr}:  conf = 0.815, sup = 0.189
# {Morning} ---> {2006, Apr}:  conf = 0.8, sup = 0.189
# {Morning, Not Domestic} ---> {Apr}:  conf = 0.787, sup = 0.164
# {Morning, Apr} ---> {Not Domestic}:  conf = 0.867, sup = 0.164
# {Morning} ---> {Not Domestic, Apr}:  conf = 0.695, sup = 0.164
# {Morning, Not Arrested} ---> {2006}:  conf = 0.979, sup = 0.171
# {2006, Morning} ---> {Not Arrested}:  conf = 0.738, sup = 0.171
# {Morning} ---> {2006, Not Arrested}:  conf = 0.725, sup = 0.171
# {Morning, Not Domestic} ---> {Not Arrested}:  conf = 0.735, sup = 0.153
# {Morning, Not Arrested} ---> {Not Domestic}:  conf = 0.876, sup = 0.153
# {Morning} ---> {Not Arrested, Not Domestic}:  conf = 0.649, sup = 0.153
# {Morning, Apr} ---> {Not Arrested}:  conf = 0.803, sup = 0.152
# {Morning, Not Arrested} ---> {Apr}:  conf = 0.869, sup = 0.152
# {Morning} ---> {Not Arrested, Apr}:  conf = 0.644, sup = 0.152
# {STREET, Not Domestic} ---> {2006}:  conf = 0.987, sup = 0.244
# {2006, STREET} ---> {Not Domestic}:  conf = 0.93, sup = 0.244
# {STREET} ---> {2006, Not Domestic}:  conf = 0.918, sup = 0.244
# {STREET, Apr} ---> {2006}:  conf = 0.999, sup = 0.211
# {2006, STREET} ---> {Apr}:  conf = 0.807, sup = 0.211
# {STREET} ---> {2006, Apr}:  conf = 0.796, sup = 0.211
# {STREET, Not Domestic} ---> {Apr}:  conf = 0.787, sup = 0.194
# {STREET, Apr} ---> {Not Domestic}:  conf = 0.917, sup = 0.194
# {STREET} ---> {Not Domestic, Apr}:  conf = 0.731, sup = 0.194
# {STREET, Not Arrested} ---> {2006}:  conf = 0.987, sup = 0.191
# {2006, STREET} ---> {Not Arrested}:  conf = 0.73, sup = 0.191
# {STREET} ---> {2006, Not Arrested}:  conf = 0.72, sup = 0.191
# {STREET, Not Domestic} ---> {Not Arrested}:  conf = 0.726, sup = 0.179
# {STREET, Not Arrested} ---> {Not Domestic}:  conf = 0.924, sup = 0.179
# {STREET} ---> {Not Arrested, Not Domestic}:  conf = 0.674, sup = 0.179
# {STREET, Apr} ---> {Not Arrested}:  conf = 0.859, sup = 0.182
# {STREET, Not Arrested} ---> {Apr}:  conf = 0.939, sup = 0.182
# {STREET} ---> {Not Arrested, Apr}:  conf = 0.685, sup = 0.182
# {Night, STREET} ---> {2006}:  conf = 0.986, sup = 0.109
# {2006, STREET} ---> {Night}:  conf = 0.417, sup = 0.109
# {STREET} ---> {2006, Night}:  conf = 0.411, sup = 0.109
# {STREET, Not Domestic} ---> {Night}:  conf = 0.421, sup = 0.104
# {Night, STREET} ---> {Not Domestic}:  conf = 0.939, sup = 0.104
# {THEFT, Not Domestic} ---> {2006}:  conf = 0.98, sup = 0.185
# {2006, THEFT} ---> {Not Domestic}:  conf = 0.973, sup = 0.185
# {THEFT} ---> {2006, Not Domestic}:  conf = 0.954, sup = 0.185
# {THEFT, Apr} ---> {2006}:  conf = 0.999, sup = 0.172
# {2006, THEFT} ---> {Apr}:  conf = 0.905, sup = 0.172
# {THEFT} ---> {2006, Apr}:  conf = 0.888, sup = 0.172
# {THEFT, Not Domestic} ---> {Apr}:  conf = 0.89, sup = 0.168
# {THEFT, Apr} ---> {Not Domestic}:  conf = 0.976, sup = 0.168
# {THEFT} ---> {Not Domestic, Apr}:  conf = 0.866, sup = 0.168
# {THEFT, Not Arrested} ---> {2006}:  conf = 0.978, sup = 0.167
# {2006, THEFT} ---> {Not Arrested}:  conf = 0.877, sup = 0.167
# {THEFT} ---> {2006, Not Arrested}:  conf = 0.86, sup = 0.167
# {THEFT, Not Domestic} ---> {Not Arrested}:  conf = 0.878, sup = 0.166
# {THEFT, Not Arrested} ---> {Not Domestic}:  conf = 0.971, sup = 0.166
# {THEFT} ---> {Not Arrested, Not Domestic}:  conf = 0.854, sup = 0.166
# {THEFT, Apr} ---> {Not Arrested}:  conf = 0.87, sup = 0.15
# {THEFT, Not Arrested} ---> {Apr}:  conf = 0.879, sup = 0.15
# {THEFT} ---> {Not Arrested, Apr}:  conf = 0.773, sup = 0.15
# {Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.12
# {2006, Domestic} ---> {Apr}:  conf = 0.947, sup = 0.12
# {Domestic} ---> {2006, Apr}:  conf = 0.935, sup = 0.12
# {Domestic, Not Arrested} ---> {2006}:  conf = 0.986, sup = 0.102
# {2006, Domestic} ---> {Not Arrested}:  conf = 0.797, sup = 0.102
# {Domestic} ---> {2006, Not Arrested}:  conf = 0.787, sup = 0.102
# {CRIMINAL DAMAGE, Not Domestic} ---> {2006}:  conf = 0.994, sup = 0.129
# {2006, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.931, sup = 0.129
# {CRIMINAL DAMAGE} ---> {2006, Not Domestic}:  conf = 0.926, sup = 0.129
# {CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.133
# {2006, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.958, sup = 0.133
# {CRIMINAL DAMAGE} ---> {2006, Apr}:  conf = 0.953, sup = 0.133
# {CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.951, sup = 0.124
# {CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.929, sup = 0.124
# {CRIMINAL DAMAGE} ---> {Not Domestic, Apr}:  conf = 0.885, sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE} ---> {2006}:  conf = 0.995, sup = 0.129
# {2006, CRIMINAL DAMAGE} ---> {Not Arrested}:  conf = 0.932, sup = 0.129
# {CRIMINAL DAMAGE} ---> {2006, Not Arrested}:  conf = 0.926, sup = 0.129
# {CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested}:  conf = 0.933, sup = 0.121
# {Not Arrested, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.933, sup = 0.121
# {CRIMINAL DAMAGE} ---> {Not Arrested, Not Domestic}:  conf = 0.869, sup = 0.121
# {CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.929, sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.951, sup = 0.124
# {CRIMINAL DAMAGE} ---> {Not Arrested, Apr}:  conf = 0.885, sup = 0.124
# {Not Domestic, Arrested, Apr} ---> {2006}:  conf = 0.998, sup = 0.133
# {2006, Arrested, Not Domestic} ---> {Apr}:  conf = 0.541, sup = 0.133
# {2006, Arrested, Apr} ---> {Not Domestic}:  conf = 0.842, sup = 0.133
# {Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.537, sup = 0.133
# {Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.841, sup = 0.133
# {2006, Arrested} ---> {Not Domestic, Apr}:  conf = 0.49, sup = 0.133
# {Arrested} ---> {2006, Not Domestic, Apr}:  conf = 0.486, sup = 0.133
# {Noon, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.134
# {2006, Noon, Not Domestic} ---> {Apr}:  conf = 0.818, sup = 0.134
# {2006, Noon, Apr} ---> {Not Domestic}:  conf = 0.856, sup = 0.134
# {Noon, Not Domestic} ---> {2006, Apr}:  conf = 0.8, sup = 0.134
# {Noon, Apr} ---> {2006, Not Domestic}:  conf = 0.855, sup = 0.134
# {2006, Noon} ---> {Not Domestic, Apr}:  conf = 0.715, sup = 0.134
# {Noon} ---> {2006, Not Domestic, Apr}:  conf = 0.699, sup = 0.134
# {Not Arrested, Noon, Not Domestic} ---> {2006}:  conf = 0.975, sup = 0.118
# {2006, Noon, Not Domestic} ---> {Not Arrested}:  conf = 0.721, sup = 0.118
# {2006, Not Arrested, Noon} ---> {Not Domestic}:  conf = 0.854, sup = 0.118
# {Noon, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.705, sup = 0.118
# {Not Arrested, Noon} ---> {2006, Not Domestic}:  conf = 0.834, sup = 0.118
# {2006, Noon} ---> {Not Arrested, Not Domestic}:  conf = 0.63, sup = 0.118
# {Noon} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.616, sup = 0.118
# {Not Arrested, Noon, Apr} ---> {2006}:  conf = 0.999, sup = 0.126
# {2006, Noon, Apr} ---> {Not Arrested}:  conf = 0.802, sup = 0.126
# {2006, Not Arrested, Noon} ---> {Apr}:  conf = 0.907, sup = 0.126
# {Noon, Apr} ---> {2006, Not Arrested}:  conf = 0.8, sup = 0.126
# {Not Arrested, Noon} ---> {2006, Apr}:  conf = 0.886, sup = 0.126
# {2006, Noon} ---> {Not Arrested, Apr}:  conf = 0.669, sup = 0.126
# {Noon} ---> {2006, Not Arrested, Apr}:  conf = 0.655, sup = 0.126
# {Not Arrested, Noon, Not Domestic} ---> {Apr}:  conf = 0.879, sup = 0.106
# {Noon, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.794, sup = 0.106
# {Not Arrested, Noon, Apr} ---> {Not Domestic}:  conf = 0.848, sup = 0.106
# {Noon, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.636, sup = 0.106
# {Not Arrested, Noon} ---> {Not Domestic, Apr}:  conf = 0.752, sup = 0.106
# {Noon, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.679, sup = 0.106
# {Noon} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.556, sup = 0.106
# {Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.56
# {2006, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.808, sup = 0.56
# {2006, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.917, sup = 0.56
# {2006, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.854, sup = 0.56
# {Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.807, sup = 0.56
# {Not Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.898, sup = 0.56
# {Not Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.854, sup = 0.56
# {2006, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.654, sup = 0.56
# {2006, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.688, sup = 0.56
# {2006, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.786, sup = 0.56
# {Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.643, sup = 0.56
# {Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.688, sup = 0.56
# {Not Arrested} ---> {2006, Not Domestic, Apr}:  conf = 0.771, sup = 0.56
# {2006} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.569, sup = 0.56
# {Night, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.98, sup = 0.211
# {2006, Night, Not Domestic} ---> {Not Arrested}:  conf = 0.699, sup = 0.211
# {2006, Not Arrested, Night} ---> {Not Domestic}:  conf = 0.832, sup = 0.211
# {Night, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.688, sup = 0.211
# {Night, Not Arrested} ---> {2006, Not Domestic}:  conf = 0.816, sup = 0.211
# {2006, Night} ---> {Not Arrested, Not Domestic}:  conf = 0.594, sup = 0.211
# {Night} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.584, sup = 0.211
# {Night, Not Arrested, Apr} ---> {2006}:  conf = 1.0, sup = 0.237
# {2006, Night, Apr} ---> {Not Arrested}:  conf = 0.817, sup = 0.237
# {2006, Not Arrested, Night} ---> {Apr}:  conf = 0.936, sup = 0.237
# {Night, Apr} ---> {2006, Not Arrested}:  conf = 0.817, sup = 0.237
# {Night, Not Arrested} ---> {2006, Apr}:  conf = 0.918, sup = 0.237
# {2006, Night} ---> {Not Arrested, Apr}:  conf = 0.668, sup = 0.237
# {Night} ---> {2006, Not Arrested, Apr}:  conf = 0.657, sup = 0.237
# {Night, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.914, sup = 0.197
# {Night, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.823, sup = 0.197
# {Night, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.83, sup = 0.197
# {Night, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.642, sup = 0.197
# {Night, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.762, sup = 0.197
# {Night, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.678, sup = 0.197
# {Night} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.545, sup = 0.197
# {Night, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.239
# {2006, Night, Not Domestic} ---> {Apr}:  conf = 0.793, sup = 0.239
# {2006, Night, Apr} ---> {Not Domestic}:  conf = 0.823, sup = 0.239
# {Night, Not Domestic} ---> {2006, Apr}:  conf = 0.78, sup = 0.239
# {Night, Apr} ---> {2006, Not Domestic}:  conf = 0.823, sup = 0.239
# {2006, Night} ---> {Not Domestic, Apr}:  conf = 0.673, sup = 0.239
# {Night} ---> {2006, Not Domestic, Apr}:  conf = 0.662, sup = 0.239
# {Evening, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.157
# {2006, Evening, Not Domestic} ---> {Apr}:  conf = 0.836, sup = 0.157
# {2006, Evening, Apr} ---> {Not Domestic}:  conf = 0.878, sup = 0.157
# {Evening, Not Domestic} ---> {2006, Apr}:  conf = 0.827, sup = 0.157
# {Evening, Apr} ---> {2006, Not Domestic}:  conf = 0.878, sup = 0.157
# {2006, Evening} ---> {Not Domestic, Apr}:  conf = 0.745, sup = 0.157
# {Evening} ---> {2006, Not Domestic, Apr}:  conf = 0.738, sup = 0.157
# {Not Arrested, Evening, Not Domestic} ---> {2006}:  conf = 0.987, sup = 0.133
# {2006, Evening, Not Domestic} ---> {Not Arrested}:  conf = 0.708, sup = 0.133
# {2006, Not Arrested, Evening} ---> {Not Domestic}:  conf = 0.883, sup = 0.133
# {Evening, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.701, sup = 0.133
# {Not Arrested, Evening} ---> {2006, Not Domestic}:  conf = 0.872, sup = 0.133
# {2006, Evening} ---> {Not Arrested, Not Domestic}:  conf = 0.631, sup = 0.133
# {Evening} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.625, sup = 0.133
# {Not Arrested, Evening, Apr} ---> {2006}:  conf = 1.0, sup = 0.142
# {2006, Evening, Apr} ---> {Not Arrested}:  conf = 0.794, sup = 0.142
# {2006, Not Arrested, Evening} ---> {Apr}:  conf = 0.943, sup = 0.142
# {Evening, Apr} ---> {2006, Not Arrested}:  conf = 0.794, sup = 0.142
# {Not Arrested, Evening} ---> {2006, Apr}:  conf = 0.93, sup = 0.142
# {2006, Evening} ---> {Not Arrested, Apr}:  conf = 0.674, sup = 0.142
# {Evening} ---> {2006, Not Arrested, Apr}:  conf = 0.667, sup = 0.142
# {Not Arrested, Evening, Not Domestic} ---> {Apr}:  conf = 0.931, sup = 0.125
# {Evening, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.799, sup = 0.125
# {Not Arrested, Evening, Apr} ---> {Not Domestic}:  conf = 0.884, sup = 0.125
# {Evening, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.661, sup = 0.125
# {Not Arrested, Evening} ---> {Not Domestic, Apr}:  conf = 0.823, sup = 0.125
# {Evening, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.702, sup = 0.125
# {Evening} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.589, sup = 0.125
# {BATTERY, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.119
# {2006, BATTERY, Not Domestic} ---> {Apr}:  conf = 0.957, sup = 0.119
# {2006, BATTERY, Apr} ---> {Not Domestic}:  conf = 0.618, sup = 0.119
# {BATTERY, Not Domestic} ---> {2006, Apr}:  conf = 0.941, sup = 0.119
# {BATTERY, Apr} ---> {2006, Not Domestic}:  conf = 0.617, sup = 0.119
# {2006, BATTERY} ---> {Not Domestic, Apr}:  conf = 0.595, sup = 0.119
# {BATTERY} ---> {2006, Not Domestic, Apr}:  conf = 0.587, sup = 0.119
# {Not Arrested, BATTERY, Apr} ---> {2006}:  conf = 0.999, sup = 0.147
# {2006, BATTERY, Apr} ---> {Not Arrested}:  conf = 0.762, sup = 0.147
# {2006, Not Arrested, BATTERY} ---> {Apr}:  conf = 0.96, sup = 0.147
# {BATTERY, Apr} ---> {2006, Not Arrested}:  conf = 0.761, sup = 0.147
# {Not Arrested, BATTERY} ---> {2006, Apr}:  conf = 0.943, sup = 0.147
# {2006, BATTERY} ---> {Not Arrested, Apr}:  conf = 0.734, sup = 0.147
# {BATTERY} ---> {2006, Not Arrested, Apr}:  conf = 0.723, sup = 0.147
# {RESIDENCE, Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.123
# {2006, RESIDENCE, Apr} ---> {Not Arrested}:  conf = 0.881, sup = 0.123
# {2006, RESIDENCE, Not Arrested} ---> {Apr}:  conf = 0.893, sup = 0.123
# {RESIDENCE, Apr} ---> {2006, Not Arrested}:  conf = 0.88, sup = 0.123
# {RESIDENCE, Not Arrested} ---> {2006, Apr}:  conf = 0.869, sup = 0.123
# {2006, RESIDENCE} ---> {Not Arrested, Apr}:  conf = 0.775, sup = 0.123
# {RESIDENCE} ---> {2006, Not Arrested, Apr}:  conf = 0.755, sup = 0.123
# {Morning, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.163
# {2006, Morning, Not Domestic} ---> {Apr}:  conf = 0.801, sup = 0.163
# {2006, Morning, Apr} ---> {Not Domestic}:  conf = 0.867, sup = 0.163
# {Morning, Not Domestic} ---> {2006, Apr}:  conf = 0.786, sup = 0.163
# {Morning, Apr} ---> {2006, Not Domestic}:  conf = 0.866, sup = 0.163
# {2006, Morning} ---> {Not Domestic, Apr}:  conf = 0.706, sup = 0.163
# {Morning} ---> {2006, Not Domestic, Apr}:  conf = 0.694, sup = 0.163
# {Morning, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.977, sup = 0.149
# {2006, Morning, Not Domestic} ---> {Not Arrested}:  conf = 0.732, sup = 0.149
# {2006, Morning, Not Arrested} ---> {Not Domestic}:  conf = 0.875, sup = 0.149
# {Morning, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.718, sup = 0.149
# {Morning, Not Arrested} ---> {2006, Not Domestic}:  conf = 0.856, sup = 0.149
# {2006, Morning} ---> {Not Arrested, Not Domestic}:  conf = 0.645, sup = 0.149
# {Morning} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.634, sup = 0.149
# {Morning, Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.151
# {2006, Morning, Apr} ---> {Not Arrested}:  conf = 0.803, sup = 0.151
# {2006, Morning, Not Arrested} ---> {Apr}:  conf = 0.887, sup = 0.151
# {Morning, Apr} ---> {2006, Not Arrested}:  conf = 0.802, sup = 0.151
# {Morning, Not Arrested} ---> {2006, Apr}:  conf = 0.868, sup = 0.151
# {2006, Morning} ---> {Not Arrested, Apr}:  conf = 0.654, sup = 0.151
# {Morning} ---> {2006, Not Arrested, Apr}:  conf = 0.643, sup = 0.151
# {Morning, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.863, sup = 0.132
# {Morning, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.806, sup = 0.132
# {Morning, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.87, sup = 0.132
# {Morning, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.634, sup = 0.132
# {Morning, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.756, sup = 0.132
# {Morning, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.699, sup = 0.132
# {Morning} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.56, sup = 0.132
# {STREET, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.194
# {2006, STREET, Not Domestic} ---> {Apr}:  conf = 0.796, sup = 0.194
# {2006, STREET, Apr} ---> {Not Domestic}:  conf = 0.918, sup = 0.194
# {STREET, Not Domestic} ---> {2006, Apr}:  conf = 0.786, sup = 0.194
# {STREET, Apr} ---> {2006, Not Domestic}:  conf = 0.916, sup = 0.194
# {2006, STREET} ---> {Not Domestic, Apr}:  conf = 0.741, sup = 0.194
# {STREET} ---> {2006, Not Domestic, Apr}:  conf = 0.731, sup = 0.194
# {STREET, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.988, sup = 0.177
# {2006, STREET, Not Domestic} ---> {Not Arrested}:  conf = 0.726, sup = 0.177
# {2006, Not Arrested, STREET} ---> {Not Domestic}:  conf = 0.925, sup = 0.177
# {STREET, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.717, sup = 0.177
# {STREET, Not Arrested} ---> {2006, Not Domestic}:  conf = 0.913, sup = 0.177
# {2006, STREET} ---> {Not Arrested, Not Domestic}:  conf = 0.675, sup = 0.177
# {STREET} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.666, sup = 0.177
# {STREET, Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.182
# {2006, STREET, Apr} ---> {Not Arrested}:  conf = 0.86, sup = 0.182
# {2006, Not Arrested, STREET} ---> {Apr}:  conf = 0.951, sup = 0.182
# {STREET, Apr} ---> {2006, Not Arrested}:  conf = 0.859, sup = 0.182
# {STREET, Not Arrested} ---> {2006, Apr}:  conf = 0.938, sup = 0.182
# {2006, STREET} ---> {Not Arrested, Apr}:  conf = 0.694, sup = 0.182
# {STREET} ---> {2006, Not Arrested, Apr}:  conf = 0.685, sup = 0.182
# {STREET, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.939, sup = 0.168
# {STREET, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.866, sup = 0.168
# {STREET, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.925, sup = 0.168
# {STREET, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.681, sup = 0.168
# {STREET, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.868, sup = 0.168
# {STREET, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.795, sup = 0.168
# {STREET} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.633, sup = 0.168
# {Night, STREET, Not Domestic} ---> {2006}:  conf = 0.987, sup = 0.103
# {2006, STREET, Not Domestic} ---> {Night}:  conf = 0.421, sup = 0.103
# {2006, Night, STREET} ---> {Not Domestic}:  conf = 0.94, sup = 0.103
# {STREET, Not Domestic} ---> {2006, Night}:  conf = 0.415, sup = 0.103
# {Night, STREET} ---> {2006, Not Domestic}:  conf = 0.927, sup = 0.103
# {THEFT, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.168
# {2006, THEFT, Not Domestic} ---> {Apr}:  conf = 0.908, sup = 0.168
# {2006, THEFT, Apr} ---> {Not Domestic}:  conf = 0.976, sup = 0.168
# {THEFT, Not Domestic} ---> {2006, Apr}:  conf = 0.89, sup = 0.168
# {THEFT, Apr} ---> {2006, Not Domestic}:  conf = 0.975, sup = 0.168
# {2006, THEFT} ---> {Not Domestic, Apr}:  conf = 0.883, sup = 0.168
# {THEFT} ---> {2006, Not Domestic, Apr}:  conf = 0.866, sup = 0.168
# {THEFT, Not Arrested, Not Domestic} ---> {2006}:  conf = 0.978, sup = 0.162
# {2006, THEFT, Not Domestic} ---> {Not Arrested}:  conf = 0.876, sup = 0.162
# {2006, THEFT, Not Arrested} ---> {Not Domestic}:  conf = 0.971, sup = 0.162
# {THEFT, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.858, sup = 0.162
# {THEFT, Not Arrested} ---> {2006, Not Domestic}:  conf = 0.95, sup = 0.162
# {2006, THEFT} ---> {Not Arrested, Not Domestic}:  conf = 0.852, sup = 0.162
# {THEFT} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.835, sup = 0.162
# {THEFT, Not Arrested, Apr} ---> {2006}:  conf = 0.999, sup = 0.15
# {2006, THEFT, Apr} ---> {Not Arrested}:  conf = 0.87, sup = 0.15
# {2006, THEFT, Not Arrested} ---> {Apr}:  conf = 0.898, sup = 0.15
# {THEFT, Apr} ---> {2006, Not Arrested}:  conf = 0.869, sup = 0.15
# {THEFT, Not Arrested} ---> {2006, Apr}:  conf = 0.878, sup = 0.15
# {2006, THEFT} ---> {Not Arrested, Apr}:  conf = 0.788, sup = 0.15
# {THEFT} ---> {2006, Not Arrested, Apr}:  conf = 0.772, sup = 0.15
# {THEFT, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.881, sup = 0.146
# {THEFT, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.868, sup = 0.146
# {THEFT, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.973, sup = 0.146
# {THEFT, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.773, sup = 0.146
# {THEFT, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.855, sup = 0.146
# {THEFT, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.847, sup = 0.146
# {THEFT} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.752, sup = 0.146
# {Not Domestic, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.124
# {2006, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.957, sup = 0.124
# {2006, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.929, sup = 0.124
# {CRIMINAL DAMAGE, Not Domestic} ---> {2006, Apr}:  conf = 0.951, sup = 0.124
# {CRIMINAL DAMAGE, Apr} ---> {2006, Not Domestic}:  conf = 0.929, sup = 0.124
# {2006, CRIMINAL DAMAGE} ---> {Not Domestic, Apr}:  conf = 0.891, sup = 0.124
# {CRIMINAL DAMAGE} ---> {2006, Not Domestic, Apr}:  conf = 0.885, sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE, Not Domestic} ---> {2006}:  conf = 0.994, sup = 0.121
# {2006, CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested}:  conf = 0.933, sup = 0.121
# {2006, Not Arrested, CRIMINAL DAMAGE} ---> {Not Domestic}:  conf = 0.933, sup = 0.121
# {CRIMINAL DAMAGE, Not Domestic} ---> {2006, Not Arrested}:  conf = 0.928, sup = 0.121
# {Not Arrested, CRIMINAL DAMAGE} ---> {2006, Not Domestic}:  conf = 0.928, sup = 0.121
# {2006, CRIMINAL DAMAGE} ---> {Not Arrested, Not Domestic}:  conf = 0.869, sup = 0.121
# {CRIMINAL DAMAGE} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.864, sup = 0.121
# {Not Arrested, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.124
# {2006, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.929, sup = 0.124
# {2006, Not Arrested, CRIMINAL DAMAGE} ---> {Apr}:  conf = 0.956, sup = 0.124
# {CRIMINAL DAMAGE, Apr} ---> {2006, Not Arrested}:  conf = 0.929, sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE} ---> {2006, Apr}:  conf = 0.951, sup = 0.124
# {2006, CRIMINAL DAMAGE} ---> {Not Arrested, Apr}:  conf = 0.891, sup = 0.124
# {CRIMINAL DAMAGE} ---> {2006, Not Arrested, Apr}:  conf = 0.885, sup = 0.124
# {Not Arrested, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.949, sup = 0.115
# {Not Domestic, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.931, sup = 0.115
# {Not Arrested, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.931, sup = 0.115
# {CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.885, sup = 0.115
# {Not Arrested, CRIMINAL DAMAGE} ---> {Not Domestic, Apr}:  conf = 0.885, sup = 0.115
# {CRIMINAL DAMAGE, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.866, sup = 0.115
# {CRIMINAL DAMAGE} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.825, sup = 0.115
# {2006, Noon, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.795, sup = 0.106
# {Not Domestic, Not Arrested, Noon, Apr} ---> {2006}:  conf = 1.0, sup = 0.106
# {2006, Not Arrested, Noon, Not Domestic} ---> {Apr}:  conf = 0.902, sup = 0.106
# {2006, Not Arrested, Noon, Apr} ---> {Not Domestic}:  conf = 0.849, sup = 0.106
# {Noon, Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.794, sup = 0.106
# {2006, Noon, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.65, sup = 0.106
# {2006, Noon, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.681, sup = 0.106
# {Not Arrested, Noon, Not Domestic} ---> {2006, Apr}:  conf = 0.879, sup = 0.106
# {Not Arrested, Noon, Apr} ---> {2006, Not Domestic}:  conf = 0.848, sup = 0.106
# {2006, Not Arrested, Noon} ---> {Not Domestic, Apr}:  conf = 0.77, sup = 0.106
# {Noon, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.636, sup = 0.106
# {Noon, Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.679, sup = 0.106
# {2006, Noon} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.568, sup = 0.106
# {Not Arrested, Noon} ---> {2006, Not Domestic, Apr}:  conf = 0.752, sup = 0.106
# {Noon} ---> {2006, Not Arrested, Apr, Not Domestic}:  conf = 0.556, sup = 0.106
# {Night, 2006, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.823, sup = 0.197
# {Night, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.197
# {Night, 2006, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.933, sup = 0.197
# {Night, 2006, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.829, sup = 0.197
# {Night, Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.823, sup = 0.197
# {Night, 2006, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.653, sup = 0.197
# {Night, 2006, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.678, sup = 0.197
# {Night, Not Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.914, sup = 0.197
# {Night, Not Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.829, sup = 0.197
# {Night, 2006, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.777, sup = 0.197
# {Night, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.642, sup = 0.197
# {Night, Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.677, sup = 0.197
# {Night, 2006} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.554, sup = 0.197
# {Night, Not Arrested} ---> {2006, Not Domestic, Apr}:  conf = 0.761, sup = 0.197
# {Night} ---> {2006, Not Arrested, Apr, Not Domestic}:  conf = 0.545, sup = 0.197
# {2006, Evening, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.799, sup = 0.125
# {Not Arrested, Evening, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.125
# {2006, Not Arrested, Evening, Not Domestic} ---> {Apr}:  conf = 0.943, sup = 0.125
# {2006, Not Arrested, Evening, Apr} ---> {Not Domestic}:  conf = 0.884, sup = 0.125
# {Evening, Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.799, sup = 0.125
# {2006, Evening, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.668, sup = 0.125
# {2006, Evening, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.702, sup = 0.125
# {Not Arrested, Evening, Not Domestic} ---> {2006, Apr}:  conf = 0.931, sup = 0.125
# {Not Arrested, Evening, Apr} ---> {2006, Not Domestic}:  conf = 0.884, sup = 0.125
# {2006, Not Arrested, Evening} ---> {Not Domestic, Apr}:  conf = 0.834, sup = 0.125
# {Evening, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.661, sup = 0.125
# {Evening, Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.702, sup = 0.125
# {2006, Evening} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.596, sup = 0.125
# {Not Arrested, Evening} ---> {2006, Not Domestic, Apr}:  conf = 0.823, sup = 0.125
# {Evening} ---> {2006, Not Arrested, Apr, Not Domestic}:  conf = 0.589, sup = 0.125
# {2006, Morning, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.806, sup = 0.132
# {Morning, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 0.998, sup = 0.132
# {2006, Morning, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.882, sup = 0.132
# {2006, Morning, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.87, sup = 0.132
# {Morning, Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.805, sup = 0.132
# {2006, Morning, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.645, sup = 0.132
# {2006, Morning, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.699, sup = 0.132
# {Morning, Not Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.862, sup = 0.132
# {Morning, Not Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.869, sup = 0.132
# {2006, Morning, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.772, sup = 0.132
# {Morning, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.633, sup = 0.132
# {Morning, Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.698, sup = 0.132
# {2006, Morning} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.569, sup = 0.132
# {Morning, Not Arrested} ---> {2006, Not Domestic, Apr}:  conf = 0.755, sup = 0.132
# {Morning} ---> {2006, Not Arrested, Apr, Not Domestic}:  conf = 0.559, sup = 0.132
# {STREET, 2006, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.867, sup = 0.168
# {STREET, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 1.0, sup = 0.168
# {STREET, 2006, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.951, sup = 0.168
# {STREET, 2006, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.925, sup = 0.168
# {STREET, Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.866, sup = 0.168
# {STREET, 2006, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.69, sup = 0.168
# {STREET, 2006, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.796, sup = 0.168
# {STREET, Not Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.939, sup = 0.168
# {STREET, Not Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.925, sup = 0.168
# {STREET, 2006, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.88, sup = 0.168
# {STREET, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.681, sup = 0.168
# {STREET, Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.795, sup = 0.168
# {STREET, 2006} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.642, sup = 0.168
# {STREET, Not Arrested} ---> {2006, Not Domestic, Apr}:  conf = 0.868, sup = 0.168
# {STREET} ---> {2006, Not Arrested, Apr, Not Domestic}:  conf = 0.633, sup = 0.168
# {2006, THEFT, Not Domestic, Apr} ---> {Not Arrested}:  conf = 0.868, sup = 0.146
# {THEFT, Not Arrested, Not Domestic, Apr} ---> {2006}:  conf = 0.999, sup = 0.146
# {2006, THEFT, Not Arrested, Not Domestic} ---> {Apr}:  conf = 0.9, sup = 0.146
# {2006, THEFT, Not Arrested, Apr} ---> {Not Domestic}:  conf = 0.973, sup = 0.146
# {THEFT, Not Domestic, Apr} ---> {2006, Not Arrested}:  conf = 0.867, sup = 0.146
# {2006, THEFT, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.788, sup = 0.146
# {2006, THEFT, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.847, sup = 0.146
# {THEFT, Not Arrested, Not Domestic} ---> {2006, Apr}:  conf = 0.88, sup = 0.146
# {THEFT, Not Arrested, Apr} ---> {2006, Not Domestic}:  conf = 0.973, sup = 0.146
# {2006, THEFT, Not Arrested} ---> {Not Domestic, Apr}:  conf = 0.874, sup = 0.146
# {THEFT, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.772, sup = 0.146
# {THEFT, Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.846, sup = 0.146
# {2006, THEFT} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.767, sup = 0.146
# {THEFT, Not Arrested} ---> {2006, Not Domestic, Apr}:  conf = 0.855, sup = 0.146
# {THEFT} ---> {2006, Not Arrested, Apr, Not Domestic}:  conf = 0.752, sup = 0.146
# {2006, Not Domestic, CRIMINAL DAMAGE, Apr} ---> {Not Arrested}:  conf = 0.931, sup = 0.115
# {Not Arrested, Not Domestic, CRIMINAL DAMAGE, Apr} ---> {2006}:  conf = 1.0, sup = 0.115
# {2006, Not Arrested, CRIMINAL DAMAGE, Not Domestic} ---> {Apr}:  conf = 0.954, sup = 0.115
# {2006, Not Arrested, CRIMINAL DAMAGE, Apr} ---> {Not Domestic}:  conf = 0.931, sup = 0.115
# {Not Domestic, CRIMINAL DAMAGE, Apr} ---> {2006, Not Arrested}:  conf = 0.931, sup = 0.115
# {2006, CRIMINAL DAMAGE, Not Domestic} ---> {Not Arrested, Apr}:  conf = 0.891, sup = 0.115
# {2006, CRIMINAL DAMAGE, Apr} ---> {Not Arrested, Not Domestic}:  conf = 0.866, sup = 0.115
# {Not Arrested, CRIMINAL DAMAGE, Not Domestic} ---> {2006, Apr}:  conf = 0.949, sup = 0.115
# {Not Arrested, CRIMINAL DAMAGE, Apr} ---> {2006, Not Domestic}:  conf = 0.931, sup = 0.115
# {2006, Not Arrested, CRIMINAL DAMAGE} ---> {Not Domestic, Apr}:  conf = 0.89, sup = 0.115
# {CRIMINAL DAMAGE, Not Domestic} ---> {2006, Not Arrested, Apr}:  conf = 0.885, sup = 0.115
# {CRIMINAL DAMAGE, Apr} ---> {2006, Not Arrested, Not Domestic}:  conf = 0.866, sup = 0.115
# {2006, CRIMINAL DAMAGE} ---> {Not Arrested, Not Domestic, Apr}:  conf = 0.829, sup = 0.115
# {Not Arrested, CRIMINAL DAMAGE} ---> {2006, Not Domestic, Apr}:  conf = 0.885, sup = 0.115
# {CRIMINAL DAMAGE} ---> {2006, Not Arrested, Apr, Not Domestic}:  conf = 0.825, sup = 0.115
